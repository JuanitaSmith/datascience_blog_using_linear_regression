# %% [markdown]
# ### Udacity Data Science Nanodegree
# ### Project 1: Writing a Data Scientist Blog Post
# ---
#
# # Notebook 1 of 4: London Airbnb
# # Data Wrangling
#
# ## by Juanita Smith
#
#
# - [Introduction](#intro)
# - [Step 1: Data Gathering](#datagathering)
# - [Step 2: Assessing](#assessing)
#    - [Summary of assessment](#summary_of_assessment)
# - [Step 3: Data Cleaning](#clean)
# - [Step 4: Save cleaned data](#save)
# - [Summary](#summary)
# - [References](#references)
# - [Submission](#submission)

# %% [markdown]
# <a class="anchor" id='intro'></a>
# <span style="color:blue; font-size:25px; line-height:30px; font-family: Calibri;">Introduction</span>
#
# In this notebook, I have done initial EDA to assess the data to build business understanding to come with 4 business questions to answer.
#
# This notebook also contain the main data wrangling activities, to clean up the data in preparation to answer the 4 business questions outlined in the README file.
#
# Business questions will be analysed in subsequent notebooks 2-4.
# This notebook only focus on data wrangling and needs to be run before notebooks 2-4.
#
# Refer to the README file for data download instructions and metadata descriptions.
#
# A quick recap of the business questions:
#
# 1. Are some hosts running a business, and if so, what is the impact on price ?
# 2. Host Analysis: How does host excellence influence price ?
# 3. What effect does star ratings have on property price ?
# 4. Predict average daily listing price

# %%
# clear the garbage to free memory as we are working with huge datasets
import gc
import os
from datetime import datetime

import matplotlib.pyplot as plt
import missingno as msno
import numpy as np
import pandas as pd
import seaborn as sns

# Import custom modules
import project1_data_science_blog.src.visuals as vs
from project1_data_science_blog.src.utils import create_folder

# set plots to be embedded inline
# %matplotlib inline

# suppress matplotlib user warnings
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="matplotlib")

# Make your Jupyter Notebook wider
from IPython.display import display, HTML
display(HTML('<style>.container { width:80% !important; }</style>'))

# environment settings
# display all columns and rows during visual inspection
pd.options.display.max_columns = None
pd.options.display.max_rows = None
# Out:
# <style>.container { width:80% !important; }</style>

# %%
# set default plot formatting
BASE_COLOR, BASE_HIGHLIGHT_INTENSE, BASE_HIGHLIGHT, BASE_COMPLIMENTARY, BASE_GREY, BASE_COLOR_ARR, BASE_COLOR_DEP, SYMBOLS = vs.set_plot_defaults()

# %%
date_stamp = '060623'
# date_stamp = '060923'
FILE_PATH_RAW = '../data/raw/'
FILE_PATH_CLEAN = '../data/clean/'
FILE_NAME_CLEAN = FILE_PATH_CLEAN + 'listing_clean_' + date_stamp + '.pkl'

# %% [markdown]
# <a class="anchor" id='datagathering'></a>
# <span style="color:blue; font-size:25px; line-height:30px; font-family: Calibri;">Step 1: Data Gathering</span>

# %% [markdown]
# This dataset is part of Airbnb Inside, and the original source data can be found [here](http://insideairbnb.com/get-the-data/)

# %%
# get calendar data
filename = FILE_PATH_RAW + 'calendar/london/calendar_' + date_stamp + '.csv'
calendar = pd.read_csv(filename)
calendar.head()
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0       13913  2023-06-09         f  $79.00         $79.00             1.0
# 1       13913  2023-06-10         f  $79.00         $79.00             1.0
# 2       13913  2023-06-11         f  $79.00         $79.00             1.0
# 3       13913  2023-06-12         t  $79.00         $79.00             1.0
# 4       13913  2023-06-13         t  $79.00         $79.00             1.0
#
#    maximum_nights
# 0            29.0
# 1            29.0
# 2            29.0
# 3            29.0
# 4            29.0

# %%
# get review data
filename = FILE_PATH_RAW + 'reviews/london/reviews_' + date_stamp + '.csv'
review = pd.read_csv(filename)
review.head()
# Out:
#    listing_id         id        date  reviewer_id reviewer_name  \
# 0      306333  121679704  2016-12-18      8698767           Ben
# 1      154221   59561487  2016-01-12      1655084         Daria
# 2      306333  122121197  2016-12-21     72253091       Matthew
# 3      306333  123425430  2016-12-29     18523201           Kom
# 4      306333  126479992  2017-01-12      9940848        Marisa
#
#                                             comments
# 0  Great find, and great value!  <br/>Right in th...
# 1  Small and cosy flat with all goods you need in...
# 2  A quiet house in the Hoxton area. Felt very ho...
# 3  We had a great stay in London, and Rob's flat ...
# 4  This flat is perfect if you are interested in ...

# %%
# get listing data
filename = FILE_PATH_RAW + 'listings/london/listings_' + date_stamp + '.csv'
listing = pd.read_csv(filename)
listing.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  154221  https://www.airbnb.com/rooms/154221  20230608145305   2023-06-10
# 1  157714  https://www.airbnb.com/rooms/157714  20230608145305   2023-06-09
# 2   13913   https://www.airbnb.com/rooms/13913  20230608145305   2023-06-09
# 3   15400   https://www.airbnb.com/rooms/15400  20230608145305   2023-06-09
# 4  306333  https://www.airbnb.com/rooms/306333  20230608145305   2023-06-09
#
#             source                                               name  \
# 0  previous scrape  Rental unit in London · 2 bedrooms · 2 beds · ...
# 1      city scrape  Townhouse in Hammersmith · ★4.71 · 1 bedroom ·...
# 2      city scrape  Rental unit in Islington · ★4.80 · 1 bedroom ·...
# 3      city scrape  Rental unit in London · ★4.80 · 1 bedroom · 1 ...
# 4      city scrape  Rental unit in London · ★4.32 · 2 bedrooms · 3...
#
#                                          description  \
# 0  hi, i am renting my 2 bedroom flat in Pimlico ...
# 1  Large, light and spacious loft bedroom with a ...
# 2  My bright double bedroom with a large window h...
# 3  Lots of windows and light.  St Luke's Gardens ...
# 4  Welcome to my lovely 2-bedroom flat in Hoxton!...
#
#                                neighborhood_overview  \
# 0  a very save area of central London , Pimlico i...
# 1  The neighbourhood is extremely convenient for ...
# 2  Finsbury Park is a friendly melting pot commun...
# 3                                     It is Chelsea.
# 4  In Shoreditch, empty walls are future murals. ...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/3510524/72655...   211018
# 1  https://a0.muscache.com/pictures/4129744/10db5...   757377
# 2  https://a0.muscache.com/pictures/miso/Hosting-...    54730
# 3  https://a0.muscache.com/pictures/428392/462d26...    60302
# 4  https://a0.muscache.com/pictures/32c818d1-7762...  1573870
#
#                                     host_url host_name  host_since  \
# 0   https://www.airbnb.com/users/show/211018    Sylvia  2010-08-24
# 1   https://www.airbnb.com/users/show/757377    Eilinn  2011-06-29
# 2    https://www.airbnb.com/users/show/54730     Alina  2009-11-16
# 3    https://www.airbnb.com/users/show/60302  Philippa  2009-12-05
# 4  https://www.airbnb.com/users/show/1573870    Robert  2012-01-06
#
#                                        host_location  \
# 0                                        Rome, Italy
# 1                             London, United Kingdom
# 2                             London, United Kingdom
# 3  Royal Borough of Kensington and Chelsea, Unite...
# 4                             London, United Kingdom
#
#                                           host_about  host_response_time  \
# 0  i love to travel and therefor want to give my ...                 NaN
# 1  Eilinn, Yoon our daughters Surei and Sukyi wou...  within a few hours
# 2  I am a Multi-Media Visual Artist and Creative ...      within an hour
# 3  English, grandmother,  I have travelled quite ...        within a day
# 4  Hi my name is Rob,\r\n\r\nI am a software deve...        within a day
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                NaN                  NaN                 f
# 1                90%                  68%               NaN
# 2               100%                  78%               NaN
# 3               100%                  47%                 f
# 4               100%                 100%                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/211018/profil...
# 1  https://a0.muscache.com/im/users/757377/profil...
# 2  https://a0.muscache.com/im/users/54730/profile...
# 3  https://a0.muscache.com/im/users/60302/profile...
# 4  https://a0.muscache.com/im/users/1573870/profi...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/211018/profil...            Pimlico
# 1  https://a0.muscache.com/im/users/757377/profil...        Hammersmith
# 2  https://a0.muscache.com/im/users/54730/profile...    LB of Islington
# 3  https://a0.muscache.com/im/users/60302/profile...            Chelsea
# 4  https://a0.muscache.com/im/users/1573870/profi...         Shoreditch
#
#    host_listings_count  host_total_listings_count  host_verifications  \
# 0                  1.0                        5.0  ['email', 'phone']
# 1                  1.0                        2.0  ['email', 'phone']
# 2                  3.0                        4.0  ['email', 'phone']
# 3                  1.0                       12.0  ['email', 'phone']
# 4                  1.0                        3.0  ['email', 'phone']
#
#   host_has_profile_pic host_identity_verified  \
# 0                    t                      f
# 1                    t                      t
# 2                    t                      t
# 3                    t                      t
# 4                    t                      t
#
#                                neighbourhood  neighbourhood_cleansed  \
# 0            London, England, United Kingdom             Westminster
# 1       Hammersmith, England, United Kingdom  Hammersmith and Fulham
# 2  Islington, Greater London, United Kingdom               Islington
# 3                     London, United Kingdom  Kensington and Chelsea
# 4                     London, United Kingdom                 Hackney
#
#    neighbourhood_group_cleansed  latitude  longitude  \
# 0                           NaN  51.48970   -0.13911
# 1                           NaN  51.48974   -0.22208
# 2                           NaN  51.56861   -0.11270
# 3                           NaN  51.48780   -0.16813
# 4                           NaN  51.52748   -0.08172
#
#                  property_type        room_type  accommodates  bathrooms  \
# 0           Entire rental unit  Entire home/apt             3        NaN
# 1    Private room in townhouse     Private room             3        NaN
# 2  Private room in rental unit     Private room             1        NaN
# 3           Entire rental unit  Entire home/apt             2        NaN
# 4           Entire rental unit  Entire home/apt             5        NaN
#
#   bathrooms_text  bedrooms  beds  \
# 0         1 bath       2.0   2.0
# 1      1.5 baths       NaN   1.0
# 2  1 shared bath       NaN   1.0
# 3         1 bath       1.0   1.0
# 4         1 bath       2.0   3.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["TV", "Microwave", "Dishwasher", "Wifi", "Ref...   $83.00               2
# 1  ["Room-darkening shades", "Hot water", "Securi...   $69.00               4
# 2  ["Room-darkening shades", "Freezer", "Oven", "...   $79.00               1
# 3  ["Hot water", "Washer", "Smoke alarm", "Heatin...  $100.00               7
# 4  ["Room-darkening shades", "Freezer", "Oven", "...  $156.00               2
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0              30                     2.0                     2.0
# 1              21                     4.0                     4.0
# 2              29                     1.0                     1.0
# 3              30                     7.0                     7.0
# 4              60                     2.0                     2.0
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                    30.0                    30.0                     2.0
# 1                    21.0                    21.0                     4.0
# 2                    29.0                    29.0                     1.0
# 3                    30.0                    30.0                     7.0
# 4                    60.0                    60.0                     2.0
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                    30.0               NaN                t                0
# 1                    21.0               NaN                t               10
# 2                    29.0               NaN                t               23
# 3                    30.0               NaN                t                0
# 4                    60.0               NaN                t                4
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0                0                0                 0            2023-06-10
# 1               37               67                67            2023-06-09
# 2               48               78               353            2023-06-09
# 3                2                2                70            2023-06-09
# 4                4                4                 4            2023-06-09
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                  1                      0                       0
# 1                175                     10                       0
# 2                 41                     15                       0
# 3                 94                      5                       0
# 4                 20                      0                       0
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2016-01-12  2016-01-12                  5.00                    5.00
# 1   2011-07-13  2023-05-02                  4.71                    4.66
# 2   2010-08-18  2022-12-11                  4.80                    4.72
# 3   2009-12-21  2023-05-01                  4.80                    4.85
# 4   2016-12-18  2017-05-31                  4.32                    4.68
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       5.00                   5.00
# 1                       4.78                   4.84
# 2                       4.72                   4.74
# 3                       4.88                   4.88
# 4                       3.95                   4.26
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         5.00                    5.00                 5.00
# 1                         4.83                    4.76                 4.66
# 2                         4.82                    4.69                 4.69
# 3                         4.83                    4.93                 4.74
# 4                         4.84                    4.89                 4.53
#
#    license instant_bookable  calculated_host_listings_count  \
# 0      NaN                f                               1
# 1      NaN                f                               1
# 2      NaN                f                               2
# 3      NaN                f                               1
# 4      NaN                f                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            0
# 2                                            1
# 3                                            1
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             1
# 2                                             1
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.01
# 1                                            0               1.21
# 2                                            0               0.26
# 3                                            0               0.57
# 4                                            0               0.25

# %% [markdown]
# <a class="anchor" id='assessing'></a>
# <span style="color:blue; font-size:25px; line-height:30px; font-family: Calibri;">Step 2: Assessing</span>

# %%
# get listing summary data
filename = FILE_PATH_RAW + 'listings_summary/london/listings_summary_' + date_stamp + '.csv'
listing_summary = pd.read_csv(filename)
listing_summary.head(3)
# Out:
#        id                                               name  host_id  \
# 0  306333  Rental unit in London · ★4.32 · 2 bedrooms · 3...  1573870
# 1  154221  Rental unit in London · 2 bedrooms · 2 beds · ...   211018
# 2  306405  Rental unit in Dagenham · ★4.0 · 1 bedroom · 1...  1575800
#
#   host_name  neighbourhood_group         neighbourhood  latitude  longitude  \
# 0    Robert                  NaN               Hackney  51.52748   -0.08172
# 1    Sylvia                  NaN           Westminster  51.48970   -0.13911
# 2      Mary                  NaN  Barking and Dagenham  51.54072    0.15246
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    156               2                 20  2017-05-31
# 1  Entire home/apt     83               2                  1  2016-01-12
# 2     Private room     41               4                  3  2012-05-27
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.25                               1                 4
# 1               0.01                               1                 0
# 2               0.02                               1               365
#
#    number_of_reviews_ltm  license
# 0                      0      NaN
# 1                      0      NaN
# 2                      0      NaN

# %% [markdown]
# ### 2.1 Assessing `calendar` dataset

# %%
# visual inspection
calendar.head(10)
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0       13913  2023-06-09         f  $79.00         $79.00             1.0
# 1       13913  2023-06-10         f  $79.00         $79.00             1.0
# 2       13913  2023-06-11         f  $79.00         $79.00             1.0
# 3       13913  2023-06-12         t  $79.00         $79.00             1.0
# 4       13913  2023-06-13         t  $79.00         $79.00             1.0
# 5       13913  2023-06-14         t  $79.00         $79.00             1.0
# 6       13913  2023-06-15         t  $79.00         $79.00             1.0
# 7       13913  2023-06-16         t  $79.00         $79.00             1.0
# 8       13913  2023-06-17         f  $79.00         $79.00             1.0
# 9       13913  2023-06-18         t  $79.00         $79.00             1.0
#
#    maximum_nights
# 0            29.0
# 1            29.0
# 2            29.0
# 3            29.0
# 4            29.0
# 5            29.0
# 6            29.0
# 7            29.0
# 8            29.0
# 9            29.0

# %% [markdown]
# >**Observations from visual inspection:**
#
#       - Multiple records for each listing_id exist, let's explore that deeper to build data understanding

# %% [markdown]
# #### What is the structure of the dataset?

# %%
calendar.shape
# Out:
# (29853384, 7)

# %% [markdown]
# >**Observation:**
#
#       - Watchout dataset almost 30mil records, avoid row level coding

# %% [markdown]
# #### Inspect the data types and missing values

# %%
calendar.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29853384 entries, 0 to 29853383
# Data columns (total 7 columns):
#  #   Column          Non-Null Count     Dtype
# ---  ------          --------------     -----
#  0   listing_id      29853384 non-null  int64
#  1   date            29853384 non-null  object
#  2   available       29853384 non-null  object
#  3   price           29852291 non-null  object
#  4   adjusted_price  29852291 non-null  object
#  5   minimum_nights  29851239 non-null  float64
#  6   maximum_nights  29851239 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 1.6+ GB

# %% [markdown]
# >**Observation:**
#
#       - date field is a string
#       - price and adjusted price columns are strings
#       - there are no missing entries

# %% [markdown]
# ##### Inspect descriptive statistics

# %%
calendar.describe([0.25, 0.5, 0.75, 0.85, 0.9, 0.95, 0.99], include='all')
# Out:
#           listing_id        date available     price adjusted_price  \
# count   2.985338e+07    29853384  29853384  29852291       29852291
# unique           NaN         369         2      4716           4699
# top              NaN  2024-05-26         f   $100.00        $100.00
# freq             NaN       81791  20088147    859842         848475
# mean    2.974050e+17         NaN       NaN       NaN            NaN
# std     3.792191e+17         NaN       NaN       NaN            NaN
# min     1.391300e+04         NaN       NaN       NaN            NaN
# 25%     2.105300e+07         NaN       NaN       NaN            NaN
# 50%     4.312004e+07         NaN       NaN       NaN            NaN
# 75%     7.293144e+17         NaN       NaN       NaN            NaN
# 85%     8.215238e+17         NaN       NaN       NaN            NaN
# 90%     8.556881e+17         NaN       NaN       NaN            NaN
# 95%     8.845779e+17         NaN       NaN       NaN            NaN
# 99%     9.042940e+17         NaN       NaN       NaN            NaN
# max     9.092815e+17         NaN       NaN       NaN            NaN
#
#         minimum_nights  maximum_nights
# count     2.985124e+07    2.985124e+07
# unique             NaN             NaN
# top                NaN             NaN
# freq               NaN             NaN
# mean      7.974408e+00    5.221775e+05
# std       3.227839e+01    3.345379e+07
# min       1.000000e+00    1.000000e+00
# 25%       1.000000e+00    9.900000e+01
# 50%       2.000000e+00    1.125000e+03
# 75%       5.000000e+00    1.125000e+03
# 85%       7.000000e+00    1.125000e+03
# 90%       9.000000e+00    1.125000e+03
# 95%       2.100000e+01    1.125000e+03
# 99%       9.100000e+01    1.125000e+03
# max       1.125000e+03    2.147484e+09

# %%
calendar.loc[calendar['minimum_nights'] > 1000].nunique()
# Out:
# listing_id          4
# date              366
# available           2
# price               5
# adjusted_price      5
# minimum_nights      2
# maximum_nights      2
# dtype: int64

# %% [markdown]
# >**Observation:**
#
#       - There are 5 listings with minimum_nights > 1000 days which looks like long term rentals over 3 years
#       - 90% of listings have a minimum stay < 9 days, which signals holiday/short term rentals
#       - 1% of listings have minimum stays > 90 days, which indicates again long term rental

# %% [markdown]
# #### What are the date range of property listings?

# %%
print('Date range for listings: {} to {}'.format(calendar['date'].min(), calendar['date'].max()))
# Out:
# Date range for listings: 2023-06-08 to 2024-06-10

# %% [markdown]
# >**Observations:**
#
#       - Dataset contain data for just over a 1 year period looking forward into the next 12 months

# %% [markdown]
# ##### Inspect unique values

# %%
calendar.nunique()
# Out:
# listing_id        81791
# date                369
# available             2
# price              4716
# adjusted_price     4699
# minimum_nights      153
# maximum_nights      771
# dtype: int64

# %%
calendar['available'].unique()
# Out:
# array(['f', 't'], dtype=object)

# %% [markdown]
# >**Observations from unique values:**
#
#       - over 80k properties are listed for 2023/2024 period
#       - we have an entry for each day of the 1 year period for each listing
#       - `available` is a boolean field with f(false) and t(true) values

# %% [markdown]
# ##### Inspect the calendar entries for a single property to understand how the data is structured

# %%
# Analyse records for the first property listing

# get first property id
listing_id = calendar.iloc[0][0]

first_listing = calendar[calendar.listing_id == listing_id]
first_listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 365 entries, 0 to 364
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   listing_id      365 non-null    int64
#  1   date            365 non-null    object
#  2   available       365 non-null    object
#  3   price           365 non-null    object
#  4   adjusted_price  365 non-null    object
#  5   minimum_nights  365 non-null    float64
#  6   maximum_nights  365 non-null    float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 22.8+ KB
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/58997714.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   listing_id = calendar.iloc[0][0]

# %%
first_listing['available'].value_counts()
# Out:
# available
# t    353
# f     12
# Name: count, dtype: int64

# %%
first_listing
# Out:
#      listing_id        date available   price adjusted_price  minimum_nights  \
# 0         13913  2023-06-09         f  $79.00         $79.00             1.0
# 1         13913  2023-06-10         f  $79.00         $79.00             1.0
# 2         13913  2023-06-11         f  $79.00         $79.00             1.0
# 3         13913  2023-06-12         t  $79.00         $79.00             1.0
# 4         13913  2023-06-13         t  $79.00         $79.00             1.0
# 5         13913  2023-06-14         t  $79.00         $79.00             1.0
# 6         13913  2023-06-15         t  $79.00         $79.00             1.0
# 7         13913  2023-06-16         t  $79.00         $79.00             1.0
# 8         13913  2023-06-17         f  $79.00         $79.00             1.0
# 9         13913  2023-06-18         t  $79.00         $79.00             1.0
# 10        13913  2023-06-19         t  $79.00         $79.00             1.0
# 11        13913  2023-06-20         t  $79.00         $79.00             1.0
# 12        13913  2023-06-21         t  $79.00         $79.00             1.0
# 13        13913  2023-06-22         t  $79.00         $79.00             1.0
# 14        13913  2023-06-23         t  $79.00         $79.00             1.0
# 15        13913  2023-06-24         t  $79.00         $79.00             1.0
# 16        13913  2023-06-25         t  $79.00         $79.00             1.0
# 17        13913  2023-06-26         t  $79.00         $79.00             1.0
# 18        13913  2023-06-27         t  $79.00         $79.00             1.0
# 19        13913  2023-06-28         t  $79.00         $79.00             1.0
# 43168      264777  2023-06-19         f  $100.00        $100.00
# 43169      264777  2023-06-20         f  $100.00        $100.00
# 43170      264777  2023-06-21         f  $100.00        $100.00
# 43171      264777  2023-06-22         f  $100.00        $100.00
# 43172      264777  2023-06-23         f  $110.00        $110.00
# 43173      264777  2023-06-24         f  $110.00        $110.00
# 43174      264777  2023-06-25         f  $100.00        $100.00
# 43175      264777  2023-06-26         f  $100.00        $100.00
# 43176      264777  2023-06-27         f  $100.00        $100.00
# 43177      264777  2023-06-28         f  $100.00        $100.00
#
#        minimum_nights  maximum_nights
# 43158             3.0           365.0
# 43159             3.0           365.0
# 43160             3.0           365.0
# 43161             3.0           365.0
# 43162             3.0           365.0
# 43163             3.0           365.0
# 43164             3.0           365.0
# 43165             3.0           365.0
# 43166             3.0           365.0
# 43167             3.0           365.0
# 43168             3.0           365.0
# 43169             3.0           365.0
# 43170             3.0           365.0
# 43171             3.0           365.0
# 43172             3.0           365.0
# 43173             3.0           365.0
# 43174             3.0           365.0
# 43175             3.0           365.0
# 43176             3.0           365.0
# 43177             3.0           365.0

# %%
# what is daily price in the listing
listing[listing.id == listing_id_price]['price']
# Out:
# 167    $101.00
# Name: price, dtype: object

# %%
# how many records have price and adjusted price different ?
records_price_diff = len(calendar[calendar.price != calendar.adjusted_price])
print('Number of records with price and adjusted price differences are {} of {}'.format(records_price_diff, calendar.shape[0]))
# Out:
# Number of records with price and adjusted price differences are 853302 of 29853384

# %% [markdown]
# >**Observation**: The daily price for above example listing is £101 and that is how it appears on the listing advert on Airbnb. However, the price in calendar dataset fluctuate depending on season and demand. It is not clear what is the difference between price and adjusted price, I assume it's ok to ignore adjusted price.

# %% [markdown]
# ### 2.2 Assessing `listing` dataset

# %% [markdown]
# #### Visual inspection

# %%
listing.sample(5)
# Out:
#              id                            listing_url       scrape_id  \
# 39402  41583294  https://www.airbnb.com/rooms/41583294  20230608145305
# 47248  52083380  https://www.airbnb.com/rooms/52083380  20230608145305
# 16179  17810723  https://www.airbnb.com/rooms/17810723  20230608145305
# 35114  36824296  https://www.airbnb.com/rooms/36824296  20230608145305
# 47190  52065471  https://www.airbnb.com/rooms/52065471  20230608145305
#
#       last_scraped           source  \
# 39402   2023-06-10  previous scrape
# 47248   2023-06-08      city scrape
# 16179   2023-06-10  previous scrape
# 35114   2023-06-09      city scrape
# 47190   2023-06-09      city scrape
#
#                                                     name  \
# 39402  Rental unit in Greater London · ★4.50 · 2 bedr...
# 47248  Condo in Greater London · ★4.71 · 1 bedroom · ...
# 16179  Rental unit in London · 1 bedroom · 1 bed · 1 ...
# 35114  Home in Greater London · ★4.20 · 1 bedroom · 2...
# 47190  Condo in Greater London · ★5.0 · 1 bedroom · 1...
#
#                                              description  \
# 39402  Home sweet Home is a 2 bedroom flat near Strat...
# 47248  Entire one bedroom flat in a great Hounslow lo...
# 16179  Lovely 1 bedroom flat in the heart of Fitzrovi...
# 35114  Bright and Cozy Studio in the heart of Hackney...
# 47190  This beautiful garden flat is my home that I r...
#
#                                    neighborhood_overview  \
# 39402  It is a residential area so it is very quiet a...
# 47248                                                NaN
# 16179  The flat is located between Fitzrovia and Camd...
# 35114  I love this place, there is a magic energy com...
# 47190  The flat is located in the trendy Lower Clapto...
#
#                                              picture_url    host_id  \
# 39402  https://a0.muscache.com/pictures/a78c4ada-e364...  262840255
# 47248  https://a0.muscache.com/pictures/ded2ef39-4484...  307633178
# 16179  https://a0.muscache.com/pictures/0c653108-b8a5...    7807153
# 35114  https://a0.muscache.com/pictures/427d3237-d9d9...  215738142
# 47190  https://a0.muscache.com/pictures/ee034ea8-5ef5...    8080044
#
#                                           host_url host_name  host_since  \
# 39402  https://www.airbnb.com/users/show/262840255    Márcia  2019-05-19
# 47248  https://www.airbnb.com/users/show/307633178     Chris  2019-11-06
# 16179    https://www.airbnb.com/users/show/7807153    Thiago  2013-07-29
# 35114  https://www.airbnb.com/users/show/215738142   Alessia  2018-09-16
# 47190    https://www.airbnb.com/users/show/8080044    Zaïsha  2013-08-11
#
#                  host_location  \
# 39402  England, United Kingdom
# 47248  England, United Kingdom
# 16179   London, United Kingdom
# 35114   London, United Kingdom
# 47190   London, United Kingdom
#
#                                               host_about host_response_time  \
# 39402  Hi there my name is Marcia and I live with my ...                NaN
# 47248                                                NaN     within an hour
# 16179  Brazilian Linguist-Philosopher who works as a ...                NaN
# 35114                                                NaN     within an hour
# 47190                                                NaN     within an hour
#
#       host_response_rate host_acceptance_rate host_is_superhost  \
# 39402                NaN                  NaN               NaN
# 47248               100%                  79%                 f
# 16179                NaN                  NaN                 f
# 35114               100%                 100%                 f
# 47190               100%                  90%               NaN
#
#                                       host_thumbnail_url  \
# 39402  https://a0.muscache.com/im/pictures/user/61c88...
# 47248  https://a0.muscache.com/im/pictures/user/673d9...
# 16179  https://a0.muscache.com/im/users/7807153/profi...
# 35114  https://a0.muscache.com/im/pictures/user/73685...
# 47190  https://a0.muscache.com/im/pictures/user/adcc3...
#
#                                         host_picture_url   host_neighbourhood  \
# 39402  https://a0.muscache.com/im/pictures/user/61c88...         LB of Newham
# 47248  https://a0.muscache.com/im/pictures/user/673d9...                  NaN
# 16179  https://a0.muscache.com/im/users/7807153/profi...          Somers Town
# 35114  https://a0.muscache.com/im/pictures/user/73685...  LB of Tower Hamlets
# 47190  https://a0.muscache.com/im/pictures/user/adcc3...        Lower Clapton
#
#        host_listings_count  host_total_listings_count  \
# 39402                  1.0                        1.0
# 47248                  1.0                        1.0
# 16179                  1.0                        1.0
# 35114                  1.0                        1.0
# 47190                  2.0                       10.0
#
#                      host_verifications host_has_profile_pic  \
# 39402                ['email', 'phone']                    t
# 47248                         ['phone']                    t
# 16179  ['email', 'phone', 'work_email']                    t
# 35114                ['email', 'phone']                    t
# 47190           ['phone', 'work_email']                    t
#
#       host_identity_verified                            neighbourhood  \
# 39402                      f  Greater London, England, United Kingdom
# 47248                      f                                      NaN
# 16179                      t          London, England, United Kingdom
# 35114                      f  Greater London, England, United Kingdom
# 47190                      t  Greater London, England, United Kingdom
#
#       neighbourhood_cleansed  neighbourhood_group_cleansed  latitude  \
# 39402                 Newham                           NaN  51.54670
# 47248               Hounslow                           NaN  51.46399
# 16179                 Camden                           NaN  51.52544
# 35114          Tower Hamlets                           NaN  51.54294
# 47190                Hackney                           NaN  51.55146
#
#        longitude                property_type        room_type  accommodates  \
# 39402    0.02265  Private room in rental unit     Private room             2
# 47248   -0.36716                 Entire condo  Entire home/apt             2
# 16179   -0.14402           Entire rental unit  Entire home/apt             4
# 35114   -0.02384                  Entire home  Entire home/apt             2
# 47190   -0.04694                 Entire condo  Entire home/apt             2
#
#        bathrooms bathrooms_text  bedrooms  beds  \
# 39402        NaN  1 shared bath       NaN   2.0
# 47248        NaN         1 bath       1.0   1.0
# 16179        NaN         1 bath       1.0   1.0
# 35114        NaN         1 bath       1.0   2.0
# 47190        NaN         1 bath       1.0   1.0
#
#                                                amenities    price  \
# 39402  ["TV", "Free parking on premises", "Hot water"...   $15.00
# 47248  ["TV", "Self check-in", "Refrigerator", "Iron"...   $90.00
# 16179  ["TV", "Wifi", "Iron", "Washer", "Kitchen", "E...   $87.00
# 35114  ["Wifi", "Hot water", "Washer", "Hangers", "Sm...   $80.00
# 47190  ["Room-darkening shades", "Sound system with B...  $144.00
#
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# 39402               1              14                     1.0
# 47248               1             365                     1.0
# 16179               2            1125                     2.0
# 35114               3              30                     3.0
# 47190              28             100                    28.0
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 39402                     1.0                    14.0                    14.0
# 47248                     1.0                   365.0                   365.0
# 16179                     2.0                  1125.0                  1125.0
# 35114                     3.0                    30.0                    30.0
# 47190                    28.0                  1125.0                  1125.0
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 39402                     1.0                    14.0               NaN
# 47248                     1.0                   365.0               NaN
# 16179                     2.0                  1125.0               NaN
# 35114                     3.0                    30.0               NaN
# 47190                    28.0                  1125.0               NaN
#
#       has_availability  availability_30  availability_60  availability_90  \
# 39402                t                0                0                0
# 47248                t               10               27               37
# 16179                t                0                0                0
# 35114                t                5               10               10
# 47190                t               27               57               87
#
#        availability_365 calendar_last_scraped  number_of_reviews  \
# 39402                 0            2023-06-10                  4
# 47248               303            2023-06-08                  7
# 16179                 0            2023-06-10                  2
# 35114                10            2023-06-09                  5
# 47190               177            2023-06-09                  6
#
#        number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 39402                      0                       0   2020-01-26  2020-02-18
# 47248                      3                       3   2021-11-14  2023-06-04
# 16179                      0                       0   2017-03-28  2017-04-11
# 35114                      5                       0   2022-08-18  2023-05-08
# 47190                      4                       1   2022-04-11  2023-05-28
#
#        review_scores_rating  review_scores_accuracy  \
# 39402                  4.50                    4.75
# 47248                  4.71                    4.86
# 16179                  5.00                    4.00
# 35114                  4.20                    4.40
# 47190                  5.00                    5.00
#
#        review_scores_cleanliness  review_scores_checkin  \
# 39402                       5.00                    4.5
# 47248                       4.71                    5.0
# 16179                       4.00                    5.0
# 35114                       4.20                    4.8
# 47190                       4.67                    4.5
#
#        review_scores_communication  review_scores_location  \
# 39402                          4.5                    5.00
# 47248                          5.0                    4.57
# 16179                          5.0                    5.00
# 35114                          4.0                    4.60
# 47190                          5.0                    4.83
#
#        review_scores_value  license instant_bookable  \
# 39402                 4.75      NaN                f
# 47248                 4.57      NaN                f
# 16179                 5.00      NaN                t
# 35114                 4.20      NaN                f
# 47190                 4.83      NaN                f
#
#        calculated_host_listings_count  \
# 39402                               1
# 47248                               1
# 16179                               1
# 35114                               1
# 47190                               2
#
#        calculated_host_listings_count_entire_homes  \
# 39402                                            0
# 47248                                            1
# 16179                                            1
# 35114                                            1
# 47190                                            1
#
#        calculated_host_listings_count_private_rooms  \
# 39402                                             1
# 47248                                             0
# 16179                                             0
# 35114                                             0
# 47190                                             1
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 39402                                            0               0.10
# 47248                                            0               0.37
# 16179                                            0               0.03
# 35114                                            0               0.51
# 47190                                            0               0.42

# %% [markdown]
# >**Observations from visual inspection:**
#
#       - column name `id` in the listings dataset is the same as column `listing_id` in the calendar dataset
#       - `bathroom` field is missing, whilst the number of bathrooms are present in a text field `bathrooms_text`
#       - `amenities` have multiple values
#       - `price` is a string containing '$'
#       - when `bedrooms` are missing, `beds` are filled
#       - when `bedrooms` are missing, the number of bedrooms are contained in text field `name`

# %% [markdown]
# #### What is the structure of the listing vs listing_summary dataset?

# %%
listing.shape, listing_summary.shape
# Out:
# ((81791, 75), (81792, 18))

# %% [markdown]
# #### Inspect the data types and missing values of both listing and listing_summary to compare the difference

# %%
listing.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81791 entries, 0 to 81790
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            81791 non-null  int64
#  1   listing_url                                   81791 non-null  object
#  2   scrape_id                                     81791 non-null  int64
#  3   last_scraped                                  81791 non-null  object
#  4   source                                        81791 non-null  object
#  5   name                                          81791 non-null  object
#  6   description                                   80460 non-null  object
#  7   neighborhood_overview                         44633 non-null  object
#  8   picture_url                                   81790 non-null  object
#  9   host_id                                       81791 non-null  int64
#  10  host_url                                      81791 non-null  object
#  11  host_name                                     81786 non-null  object
#  12  host_since                                    81786 non-null  object
#  13  host_location                                 64928 non-null  object
#  14  host_about                                    42991 non-null  object
#  15  host_response_time                            52751 non-null  object
#  16  host_response_rate                            52751 non-null  object
#  17  host_acceptance_rate                          56353 non-null  object
#  18  host_is_superhost                             52572 non-null  object
#  19  host_thumbnail_url                            81786 non-null  object
#  20  host_picture_url                              81786 non-null  object
#  21  host_neighbourhood                            46472 non-null  object
#  22  host_listings_count                           81786 non-null  float64
#  23  host_total_listings_count                     81786 non-null  float64
#  24  host_verifications                            81786 non-null  object
#  25  host_has_profile_pic                          81786 non-null  object
#  26  host_identity_verified                        81786 non-null  object
#  27  neighbourhood                                 44634 non-null  object
#  28  neighbourhood_cleansed                        81791 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      81791 non-null  float64
#  31  longitude                                     81791 non-null  float64
#  32  property_type                                 81791 non-null  object
#  33  room_type                                     81791 non-null  object
#  34  accommodates                                  81791 non-null  int64
#  35  bathrooms                                     0 non-null      float64
#  36  bathrooms_text                                81689 non-null  object
#  37  bedrooms                                      50991 non-null  float64
#  38  beds                                          80646 non-null  float64
#  39  amenities                                     81791 non-null  object
#  40  price                                         81791 non-null  object
#  41  minimum_nights                                81791 non-null  int64
#  42  maximum_nights                                81791 non-null  int64
#  43  minimum_minimum_nights                        81790 non-null  float64
#  44  maximum_minimum_nights                        81790 non-null  float64
#  45  minimum_maximum_nights                        81790 non-null  float64
#  46  maximum_maximum_nights                        81790 non-null  float64
#  47  minimum_nights_avg_ntm                        81790 non-null  float64
#  48  maximum_nights_avg_ntm                        81790 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              81791 non-null  object
#  51  availability_30                               81791 non-null  int64
#  52  availability_60                               81791 non-null  int64
#  53  availability_90                               81791 non-null  int64
#  54  availability_365                              81791 non-null  int64
#  55  calendar_last_scraped                         81791 non-null  object
#  56  number_of_reviews                             81791 non-null  int64
#  57  number_of_reviews_ltm                         81791 non-null  int64
#  58  number_of_reviews_l30d                        81791 non-null  int64
#  59  first_review                                  61189 non-null  object
#  60  last_review                                   61189 non-null  object
#  61  review_scores_rating                          61189 non-null  float64
#  62  review_scores_accuracy                        60252 non-null  float64
#  63  review_scores_cleanliness                     60264 non-null  float64
#  64  review_scores_checkin                         60222 non-null  float64
#  65  review_scores_communication                   60249 non-null  float64
#  66  review_scores_location                        60222 non-null  float64
#  67  review_scores_value                           60220 non-null  float64
#  68  license                                       0 non-null      float64
#  69  instant_bookable                              81791 non-null  object
#  70  calculated_host_listings_count                81791 non-null  int64
#  71  calculated_host_listings_count_entire_homes   81791 non-null  int64
#  72  calculated_host_listings_count_private_rooms  81791 non-null  int64
#  73  calculated_host_listings_count_shared_rooms   81791 non-null  int64
#  74  reviews_per_month                             61189 non-null  float64
# dtypes: float64(24), int64(17), object(34)
# memory usage: 46.8+ MB

# %%
listing_summary.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81792 entries, 0 to 81791
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              81792 non-null  int64
#  1   name                            81792 non-null  object
#  2   host_id                         81792 non-null  int64
#  3   host_name                       81786 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   81792 non-null  object
#  6   latitude                        81792 non-null  float64
#  7   longitude                       81792 non-null  float64
#  8   room_type                       81792 non-null  object
#  9   price                           81792 non-null  int64
#  10  minimum_nights                  81792 non-null  int64
#  11  number_of_reviews               81792 non-null  int64
#  12  last_review                     61190 non-null  object
#  13  reviews_per_month               61190 non-null  float64
#  14  calculated_host_listings_count  81792 non-null  int64
#  15  availability_365                81792 non-null  int64
#  16  number_of_reviews_ltm           81792 non-null  int64
#  17  license                         0 non-null      float64
# dtypes: float64(5), int64(8), object(5)
# memory usage: 11.2+ MB

# %% [markdown]
# >**Observation:** `listing_summary` is a reduced version of `listing` containing less features, however `listing` have very interesting fields that could be useful for predictions. Let's rather focus on the listings dataset

# %% [markdown]
# ##### Inspect unique values

# %%
listing.nunique()
# Out:
# id                                              81791
# listing_url                                     81791
# scrape_id                                           1
# last_scraped                                        3
# source                                              2
# name                                            20766
# description                                     74519
# neighborhood_overview                           36423
# picture_url                                     79624
# host_id                                         50501
# host_url                                        50501
# host_name                                       14334
# host_since                                       4658
# host_location                                    1615
# host_about                                      23216
# host_response_time                                  4
# host_response_rate                                 90
# host_acceptance_rate                              100
# host_is_superhost                                   2
# host_thumbnail_url                              49039
# host_picture_url                                49039
# host_neighbourhood                                610
# host_listings_count                               117
# host_total_listings_count                         174
# host_verifications                                  8
# host_has_profile_pic                                2
# host_identity_verified                              2
# neighbourhood                                     855
# neighbourhood_cleansed                             33
# neighbourhood_group_cleansed                        0
# latitude                                        37636
# longitude                                       47375
# property_type                                     103
# room_type                                           4
# accommodates                                       17
# bathrooms                                           0
# bathrooms_text                                     48
# bedrooms                                           17
# beds                                               21
# amenities                                       71532
# price                                            1513
# minimum_nights                                    116
# maximum_nights                                    291
# minimum_minimum_nights                            121
# maximum_minimum_nights                            135
# minimum_maximum_nights                            276
# maximum_maximum_nights                            297
# minimum_nights_avg_ntm                            748
# maximum_nights_avg_ntm                           1631
# calendar_updated                                    0
# has_availability                                    2
# availability_30                                    31
# availability_60                                    61
# availability_90                                    91
# availability_365                                  366
# calendar_last_scraped                               3
# number_of_reviews                                 473
# number_of_reviews_ltm                             155
# number_of_reviews_l30d                             22
# first_review                                     3871
# last_review                                      2944
# review_scores_rating                              200
# review_scores_accuracy                            198
# review_scores_cleanliness                         217
# review_scores_checkin                             183
# review_scores_communication                       174
# review_scores_location                            171
# review_scores_value                               202
# license                                             0
# instant_bookable                                    2
# calculated_host_listings_count                     90
# calculated_host_listings_count_entire_homes        84
# calculated_host_listings_count_private_rooms       41
# calculated_host_listings_count_shared_rooms        11
# reviews_per_month                                 899
# dtype: int64

# %% [markdown]
# ##### How many unique values are present in categorical variables

# %%
# get a list of categorical features
cat_cols = list(listing.select_dtypes(include=['object']).columns)


# get columns with 50 or less unique values and feature is categorical
# cols = set(listing.columns[(listing.nunique().between(2, 50)) & listing.columns.isin(cat_cols)])
cols = set(listing.columns[listing.nunique().between(2, 50)])

# print column unique values in a subplot grid
ncols = 3
nrows = len(cols) // ncols

fig, axs = plt.subplots(nrows, ncols, constrained_layout=True, figsize=(10,14))
for col, ax in zip(cols, axs.T.ravel()):
    sns.countplot(data=listing, x=col, ax=ax, color=BASE_COLOR, orient='h')
    
    # rotate the xtick labels
    labels = ax.get_xticklabels()
    ax.set_xticklabels(labels, rotation=90)
    ax.set_title(col)
    ax.set_xlabel('')

plt.suptitle('UNIQUE VALUES FOR CATEGORICAL VARIABLES')
plt.show()
# Out:
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/309653150.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/309653150.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/309653150.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/309653150.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/309653150.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/309653150.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/309653150.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/309653150.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/309653150.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/309653150.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/309653150.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/309653150.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/309653150.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/309653150.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/309653150.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/309653150.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/309653150.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/309653150.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)

# %%
# understand deeper the possible values of bathrooms_text
listing.bathrooms_text.value_counts()
# Out:
# bathrooms_text
# 1 bath               36300
# 1 shared bath        12062
# 2 baths               9838
# 1 private bath        6690
# 1.5 baths             6236
# 1.5 shared baths      3360
# 2.5 baths             2393
# 3 baths               1248
# 2 shared baths        1238
# 3.5 baths              658
# 2.5 shared baths       381
# 4 baths                237
# 3 shared baths         187
# Half-bath              149
# 4.5 baths              131
# 5 baths                119
# 0 shared baths         106
# 0 baths                 85
# Shared half-bath        59
# 3.5 shared baths        44
# 5.5 baths               32
# 6 baths                 19
# 4.5 shared baths        17
# 6.5 baths               15
# Private half-bath       14
# 4 shared baths          14
# 12 baths                 9
# 5 shared baths           7
# 7.5 baths                5
# 7 baths                  4
# 5.5 shared baths         4
# 9 baths                  4
# 23 baths                 3
# 8 shared baths           2
# 7 shared baths           2
# 10.5 baths               2
# 6 shared baths           2
# 8.5 baths                2
# 12.5 baths               2
# 22 baths                 1
# 10 shared baths          1
# 8 baths                  1
# 50 baths                 1
# 10 baths                 1
# 8.5 shared baths         1
# 13 baths                 1
# 17 baths                 1
# 9.5 baths                1
# Name: count, dtype: int64

# %% [markdown]
# >**Observations from info and unique values:**
#
#       - boolean fields have values 'f' and 't'
#       - `host_verifications` have multiple values (email, phone, etc)
#       - `host_since` is a date with type string
#       - `host_response_rate` and `host_acceptance_rate` are numeric fields as type string with text '%' present
#       - `neighbourhood` column is a duplicate of improved `neighbourhood_cleansed`
#       - columns `neighbourhood_group_cleansed`, `calendar_updated` and `license ` have all values missing
#       - calendar_last_scraped is a date field
#       - first_review and last_review are date fields
#       - beds and bedrooms are right skewed
#       - `bedrooms` is sometimes missing when `beds` are filled
#       - bathrooms are missing when bathrooms_text are filled

# %% [markdown]
# ##### Missing data in columns

# %%
# plot columns with missing values > 25%
missing_columns = round(listing.isna().mean() * 100, 2).sort_values(ascending=False)
missing_columns = missing_columns[missing_columns > 25]
df_missing_values = pd.DataFrame(missing_columns,
                                        columns=['missing%'],
                                        index=missing_columns.index)

df_missing_values.plot(kind="bar",
                           figsize=(16, 6),
                           title='% Missing values',
                           width=1,
                           color=BASE_COLOR)


yticks = np.arange(0, 101, 20)
ylabels = ['{}%'.format(v) for v in yticks]
plt.ylabel('Missing values')
plt.title('% Missing values in columns')
plt.yticks(yticks, ylabels)
plt.xlabel = 'Features'
plt.title('% Missing values in columns', fontsize=14)
plt.show()

# %% [markdown]
# **Observations:**
#    - some columns contain 100% missing values and are thus meaningless
#    - columns `host_about` and `neighbourhood` contains long free text descriptions and are missing more than 40%

# %% [markdown]
# #### Missing data in rows

# %%
missing_data_in_rows = listing.isna().mean(axis=1) * 100

# %%
sns.histplot(missing_data_in_rows, binwidth=1, color=BASE_COLOR)
plt.title('% missing data in rows')
plt.ylabel('Number of rows')
plt.show()

# %%
# missing value percentiles
missing_data_in_rows.describe([0.25, 0.5, 0.75, 0.85, 0.9, 0.95, 0.99])
# Out:
# count    81791.000000
# mean        13.862210
# std          7.284154
# min          5.333333
# 25%          8.000000
# 50%         10.666667
# 75%         18.666667
# 85%         24.000000
# 90%         26.666667
# 95%         28.000000
# 99%         30.666667
# max         44.000000
# dtype: float64

# %%
# Investigate deeper the rows with missing values > 30%
missing_rows = missing_data_in_rows.loc[(missing_data_in_rows > 30)]
print('missing rows {}'.format(len(missing_rows)))
listing.loc[missing_rows.index].sample(5)
# Out:
# missing rows 1598
#              id                            listing_url       scrape_id  \
# 43293  46633508  https://www.airbnb.com/rooms/46633508  20230608145305
# 15868  17476845  https://www.airbnb.com/rooms/17476845  20230608145305
# 33513  35118043  https://www.airbnb.com/rooms/35118043  20230608145305
# 12316  13892185  https://www.airbnb.com/rooms/13892185  20230608145305
# 10915  12895423  https://www.airbnb.com/rooms/12895423  20230608145305
#
#       last_scraped           source  \
# 43293   2023-06-10  previous scrape
# 15868   2023-06-10  previous scrape
# 33513   2023-06-09  previous scrape
# 12316   2023-06-10  previous scrape
# 10915   2023-06-10  previous scrape
#
#                                                     name  \
# 43293  Rental unit in Greater London · 2 bedrooms · 3...
# 15868   Home in London · Studio · 1 bed · 1 private bath
# 33513  Rental unit in Greater London · 1 bedroom · 1 ...
# 12316  Rental unit in London · 1 bedroom · 1 bed · 1 ...
# 10915  Rental unit in London · 1 bedroom · 1 bed · 1 ...
#
#                                              description  \
# 43293  Luxury 2 bedroom en suite bedroom, with video ...
# 15868  Very cosy studio with separate kitchen, bedroo...
# 33513                                                NaN
# 12316  My place is conveniently located on the tube l...
# 10915  My place is close to Northcote Rd, Numero Uno,...
#
#       neighborhood_overview  \
# 43293                   NaN
# 15868                   NaN
# 33513                   NaN
# 12316                   NaN
# 10915                   NaN
#
#                                              picture_url    host_id  \
# 43293  https://a0.muscache.com/pictures/03b6bcf6-cbf1...  218256499
# 15868  https://a0.muscache.com/pictures/0623d619-8814...   65839155
# 33513  https://a0.muscache.com/pictures/287a7819-6fee...   39177528
# 12316  https://a0.muscache.com/pictures/25f518b2-86c1...   82284538
# 10915  https://a0.muscache.com/pictures/9bf9b694-e454...   12698011
#
#                                           host_url host_name  host_since  \
# 43293  https://www.airbnb.com/users/show/218256499    Fatima  2018-10-01
# 15868   https://www.airbnb.com/users/show/65839155      Juju  2016-04-05
# 33513   https://www.airbnb.com/users/show/39177528     Simon  2015-07-21
# 12316   https://www.airbnb.com/users/show/82284538       Mia  2016-07-07
# 10915   https://www.airbnb.com/users/show/12698011     Susie  2014-03-01
#
#                 host_location  \
# 43293                     NaN
# 15868                     NaN
# 33513  London, United Kingdom
# 12316                     NaN
# 10915  London, United Kingdom
#
#                                               host_about host_response_time  \
# 43293                                                NaN                NaN
# 15868                                                NaN                NaN
# 33513                                                NaN                NaN
# 12316  I love traveling exploring new places and thin...                NaN
# 10915                                                NaN                NaN
#
#       host_response_rate host_acceptance_rate host_is_superhost  \
# 43293                NaN                  NaN                 f
# 15868                NaN                  NaN               NaN
# 33513                NaN                  NaN               NaN
# 12316                NaN                  NaN               NaN
# 10915                NaN                  NaN               NaN
#
#                                       host_thumbnail_url  \
# 43293  https://a0.muscache.com/im/pictures/user/e83d7...
# 15868  https://a0.muscache.com/im/pictures/user/9199a...
# 33513  https://a0.muscache.com/im/pictures/user/cde10...
# 12316  https://a0.muscache.com/im/pictures/user/d1633...
# 10915  https://a0.muscache.com/im/users/12698011/prof...
#
#                                         host_picture_url host_neighbourhood  \
# 43293  https://a0.muscache.com/im/pictures/user/e83d7...                NaN
# 15868  https://a0.muscache.com/im/pictures/user/9199a...                NaN
# 33513  https://a0.muscache.com/im/pictures/user/cde10...             Balham
# 12316  https://a0.muscache.com/im/pictures/user/d1633...                NaN
# 10915  https://a0.muscache.com/im/users/12698011/prof...                NaN
#
#        host_listings_count  host_total_listings_count  host_verifications  \
# 43293                  3.0                        5.0  ['email', 'phone']
# 15868                  1.0                        1.0           ['phone']
# 33513                  1.0                        1.0           ['phone']
# 12316                  1.0                        1.0  ['email', 'phone']
# 10915                  1.0                        1.0           ['phone']
#
#       host_has_profile_pic host_identity_verified neighbourhood  \
# 43293                    t                      f           NaN
# 15868                    t                      f           NaN
# 33513                    t                      f           NaN
# 12316                    t                      f           NaN
# 10915                    t                      f           NaN
#
#       neighbourhood_cleansed  neighbourhood_group_cleansed  latitude  \
# 43293              Redbridge                           NaN  51.59611
# 15868                  Brent                           NaN  51.55050
# 33513             Wandsworth                           NaN  51.44421
# 12316               Haringey                           NaN  51.58775
# 10915             Wandsworth                           NaN  51.45716
#
#        longitude                property_type        room_type  accommodates  \
# 43293    0.02025           Entire rental unit  Entire home/apt             4
# 15868   -0.22930         Private room in home     Private room             2
# 33513   -0.15541  Private room in rental unit     Private room             2
# 12316   -0.11286  Private room in rental unit     Private room             2
# 10915   -0.16029  Private room in rental unit     Private room             2
#
#        bathrooms  bathrooms_text  bedrooms  beds  \
# 43293        NaN       3.5 baths       2.0   NaN
# 15868        NaN  1 private bath       NaN   1.0
# 33513        NaN   1 shared bath       NaN   1.0
# 12316        NaN          1 bath       NaN   1.0
# 10915        NaN          1 bath       NaN   1.0
#
#                                                amenities    price  \
# 43293  ["Free parking on premises", "Hot water", "Was...  $150.00
# 15868  ["TV", "Wifi", "Iron", "Washer", "Hangers", "S...   $60.00
# 33513  ["TV", "Elevator", "Wifi", "Hot water", "Iron"...  $125.00
# 12316  ["Elevator", "Wifi", "Iron", "Washer", "Hanger...   $46.00
# 10915  ["Wifi", "Washer", "Hangers", "Heating", "Kitc...   $50.00
#
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# 43293              30            1125                    30.0
# 15868               2               6                     2.0
# 33513               1            1125                     1.0
# 12316               2              10                     2.0
# 10915               2               7                     2.0
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 43293                    30.0                  1125.0                  1125.0
# 15868                     2.0                     6.0                     6.0
# 33513                     1.0                  1125.0                  1125.0
# 12316                     2.0                    10.0                    10.0
# 10915                     2.0                     7.0                     7.0
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 43293                    30.0                  1125.0               NaN
# 15868                     2.0                     6.0               NaN
# 33513                     1.0                  1125.0               NaN
# 12316                     2.0                    10.0               NaN
# 10915                     2.0                     7.0               NaN
#
#       has_availability  availability_30  availability_60  availability_90  \
# 43293                t                0                0                0
# 15868                t                0                0                0
# 33513                t                0                0                0
# 12316                t                0                0                0
# 10915                t                0                0                0
#
#        availability_365 calendar_last_scraped  number_of_reviews  \
# 43293                 0            2023-06-10                  0
# 15868                 0            2023-06-10                  0
# 33513                 0            2023-06-09                  0
# 12316                 0            2023-06-10                  0
# 10915                 0            2023-06-10                  0
#
#        number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 43293                      0                       0          NaN         NaN
# 15868                      0                       0          NaN         NaN
# 33513                      0                       0          NaN         NaN
# 12316                      0                       0          NaN         NaN
# 10915                      0                       0          NaN         NaN
#
#        review_scores_rating  review_scores_accuracy  \
# 43293                   NaN                     NaN
# 15868                   NaN                     NaN
# 33513                   NaN                     NaN
# 12316                   NaN                     NaN
# 10915                   NaN                     NaN
#
#        review_scores_cleanliness  review_scores_checkin  \
# 43293                        NaN                    NaN
# 15868                        NaN                    NaN
# 33513                        NaN                    NaN
# 12316                        NaN                    NaN
# 10915                        NaN                    NaN
#
#        review_scores_communication  review_scores_location  \
# 43293                          NaN                     NaN
# 15868                          NaN                     NaN
# 33513                          NaN                     NaN
# 12316                          NaN                     NaN
# 10915                          NaN                     NaN
#
#        review_scores_value  license instant_bookable  \
# 43293                  NaN      NaN                t
# 15868                  NaN      NaN                t
# 33513                  NaN      NaN                t
# 12316                  NaN      NaN                f
# 10915                  NaN      NaN                f
#
#        calculated_host_listings_count  \
# 43293                               3
# 15868                               1
# 33513                               1
# 12316                               1
# 10915                               1
#
#        calculated_host_listings_count_entire_homes  \
# 43293                                            3
# 15868                                            0
# 33513                                            0
# 12316                                            0
# 10915                                            0
#
#        calculated_host_listings_count_private_rooms  \
# 43293                                             0
# 15868                                             1
# 33513                                             1
# 12316                                             1
# 10915                                             1
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 43293                                            0                NaN
# 15868                                            0                NaN
# 33513                                            0                NaN
# 12316                                            0                NaN
# 10915                                            0                NaN

# %% [markdown]
# >**Observations:**
# >- Rows with missing data exceeding 30%, are listings that have never been reviewed and/or have missing host data

# %% [markdown]
# ##### Explore missing values with missingno

# %%
# Where in the dataset do missing values appear? Are there relationships between missing data in columns ?

msno.matrix(listing, filter="bottom", n=50, sort="descending");

# %% [markdown]
# >**Observations**:
# >- There are 4 columns that have **all values missing** (neighborhood, bathrooms, calendar_updated and license)
# >- There are 10 columns related to **host information** that have lots of missing values, and it seems like lots of relationships could exist between those host columns, if one value is missing others are most likely missing as well
# >- **Bedrooms** have a lot of missing values, whilst **beds** are well populated
# >- Towards the end of the file, there are 10 columns related to **reviews** with lots of missing values with a clear relationship. If one of these columns are missing, all columns is missing.

# %%
# Investigate deeper the relationships in the amount of missing data in each column
# The top line shows the highest relationships and correlations

msno.dendrogram(listing, filter="bottom", n=30, figsize=(20,6));

# %% [markdown]
# >**Observations**:
# >- When host response_rate is missing, host_response_time and host_acceptance_rate are also missing
# >- If review_scores_rating is missing, the sub categories for reviews are also missing
# >- If superhost is missing, number of bedrooms are probably missing as well
# >- Looks like superhost describes their properties better ?

# %% [markdown]
# #### Lets take a deeper look at missing values in reviews and its relationships

# %%
review_cols = ['first_review', 'last_review', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness',
              'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value',
              'reviews_per_month']

# %%
listing[review_cols].head()
# Out:
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2016-01-12  2016-01-12                  5.00                    5.00
# 1   2011-07-13  2023-05-02                  4.71                    4.66
# 2   2010-08-18  2022-12-11                  4.80                    4.72
# 3   2009-12-21  2023-05-01                  4.80                    4.85
# 4   2016-12-18  2017-05-31                  4.32                    4.68
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       5.00                   5.00
# 1                       4.78                   4.84
# 2                       4.72                   4.74
# 3                       4.88                   4.88
# 4                       3.95                   4.26
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         5.00                    5.00                 5.00
# 1                         4.83                    4.76                 4.66
# 2                         4.82                    4.69                 4.69
# 3                         4.83                    4.93                 4.74
# 4                         4.84                    4.89                 4.53
#
#    reviews_per_month
# 0               0.01
# 1               1.21
# 2               0.26
# 3               0.57
# 4               0.25

# %%
# missing values for reviews was mostly present at the end of the file
listing[review_cols].tail()
# Out:
#       first_review last_review  review_scores_rating  review_scores_accuracy  \
# 81786          NaN         NaN                   NaN                     NaN
# 81787          NaN         NaN                   NaN                     NaN
# 81788          NaN         NaN                   NaN                     NaN
# 81789          NaN         NaN                   NaN                     NaN
# 81790          NaN         NaN                   NaN                     NaN
#
#        review_scores_cleanliness  review_scores_checkin  \
# 81786                        NaN                    NaN
# 81787                        NaN                    NaN
# 81788                        NaN                    NaN
# 81789                        NaN                    NaN
# 81790                        NaN                    NaN
#
#        review_scores_communication  review_scores_location  \
# 81786                          NaN                     NaN
# 81787                          NaN                     NaN
# 81788                          NaN                     NaN
# 81789                          NaN                     NaN
# 81790                          NaN                     NaN
#
#        review_scores_value  reviews_per_month
# 81786                  NaN                NaN
# 81787                  NaN                NaN
# 81788                  NaN                NaN
# 81789                  NaN                NaN
# 81790                  NaN                NaN

# %%
# inspect a record with missing review columns
listing.iloc[81786]
# Out:
# id                                                                             908448542533162051
# listing_url                                       https://www.airbnb.com/rooms/908448542533162051
# scrape_id                                                                          20230608145305
# last_scraped                                                                           2023-06-10
# source                                                                                city scrape
# name                                            Rental unit in Greater London · ★New · 1 bedro...
# description                                     Show up and start living from day one in Londo...
# neighborhood_overview                           With leafy, green pathways and large, lavish m...
# picture_url                                     https://a0.muscache.com/pictures/prohost-api/H...
# host_id                                                                                 314162972
# host_url                                              https://www.airbnb.com/users/show/314162972
# host_name                                                                              Blueground
# host_since                                                                             2019-12-03
# host_location                                                              London, United Kingdom
# host_about                                      We’re Blueground, a global proptech company wi...
# host_response_time                                                                 within an hour
# host_response_rate                                                                           100%
# host_acceptance_rate                                                                          97%
# host_is_superhost                                                                               f
# host_thumbnail_url                              https://a0.muscache.com/im/pictures/user/94176...
# host_picture_url                                https://a0.muscache.com/im/pictures/user/94176...
# host_neighbourhood                                                                     Shoreditch
# host_listings_count                                                                         280.0
# host_total_listings_count                                                                   303.0
# host_verifications                                               ['email', 'phone', 'work_email']
# host_has_profile_pic                                                                            t
# host_identity_verified                                                                          t
# neighbourhood                                             Greater London, England, United Kingdom
# neighbourhood_cleansed                                                                Westminster
# neighbourhood_group_cleansed                                                                  NaN
# latitude                                                                                51.531046
# longitude                                                                               -0.176821
# property_type                                                                  Entire rental unit
# room_type                                                                         Entire home/apt
# accommodates                                                                                    2
# bathrooms                                                                                     NaN
# bathrooms_text                                                                             1 bath
# bedrooms                                                                                      1.0
# beds                                                                                          1.0
# amenities                                       ["Oven", "Hot water", "Smoke alarm", "Heating"...
# price                                                                                     $169.00
# minimum_nights                                                                                 90
# maximum_nights                                                                               1125
# minimum_minimum_nights                                                                       90.0
# maximum_minimum_nights                                                                      366.0
# minimum_maximum_nights                                                                     1125.0
# maximum_maximum_nights                                                                     1125.0
# minimum_nights_avg_ntm                                                                      350.9
# maximum_nights_avg_ntm                                                                     1125.0
# calendar_updated                                                                              NaN
# has_availability                                                                                t
# availability_30                                                                                 1
# availability_60                                                                                 1
# availability_90                                                                                 1
# availability_365                                                                                1
# calendar_last_scraped                                                                  2023-06-10
# number_of_reviews                                                                               0
# number_of_reviews_ltm                                                                           0
# number_of_reviews_l30d                                                                          0
# first_review                                                                                  NaN
# last_review                                                                                   NaN
# review_scores_rating                                                                          NaN
# review_scores_accuracy                                                                        NaN
# review_scores_cleanliness                                                                     NaN
# review_scores_checkin                                                                         NaN
# review_scores_communication                                                                   NaN
# review_scores_location                                                                        NaN
# review_scores_value                                                                           NaN
# license                                                                                       NaN
# instant_bookable                                                                                f
# calculated_host_listings_count                                                                280
# calculated_host_listings_count_entire_homes                                                   280
# calculated_host_listings_count_private_rooms                                                    0
# calculated_host_listings_count_shared_rooms                                                     0
# reviews_per_month                                                                             NaN
# Name: 81786, dtype: object

# %% [markdown]
# >**Observation**
# >- If `number_of_reviews` = 0, all the review fields are missing
# >- This is long term rental with minimum rental days = 90 days. It's a more commercial listing than short term holiday rental

# %%
# are the review fields only missing when number of reviews = 0?
listing[(listing.number_of_reviews > 0) & (listing.review_scores_rating.isna())].any().any()
# Out:
# False

# %%
#### Lets take a deeper look at missing values in features describing the host

# %%
host_columns = ['host_url', 'host_name', 'host_since', 'host_location', 'host_about', 
                'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 
                'host_picture_url', 'host_thumbnail_url', 'host_neighbourhood', 'host_listings_count', 
                'host_total_listings_count', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 
                'number_of_reviews', 'availability_365']

# %%
listing[host_columns].head()
# Out:
#                                     host_url host_name  host_since  \
# 0   https://www.airbnb.com/users/show/211018    Sylvia  2010-08-24
# 1   https://www.airbnb.com/users/show/757377    Eilinn  2011-06-29
# 2    https://www.airbnb.com/users/show/54730     Alina  2009-11-16
# 3    https://www.airbnb.com/users/show/60302  Philippa  2009-12-05
# 4  https://www.airbnb.com/users/show/1573870    Robert  2012-01-06
#
#                                        host_location  \
# 0                                        Rome, Italy
# 1                             London, United Kingdom
# 2                             London, United Kingdom
# 3  Royal Borough of Kensington and Chelsea, Unite...
# 4                             London, United Kingdom
#
#                                           host_about  host_response_time  \
# 0  i love to travel and therefor want to give my ...                 NaN
# 1  Eilinn, Yoon our daughters Surei and Sukyi wou...  within a few hours
# 2  I am a Multi-Media Visual Artist and Creative ...      within an hour
# 3  English, grandmother,  I have travelled quite ...        within a day
# 4  Hi my name is Rob,\r\n\r\nI am a software deve...        within a day
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                NaN                  NaN                 f
# 1                90%                  68%               NaN
# 2               100%                  78%               NaN
# 3               100%                  47%                 f
# 4               100%                 100%                 f
#
#                                     host_picture_url  \
# 0  https://a0.muscache.com/im/users/211018/profil...
# 1  https://a0.muscache.com/im/users/757377/profil...
# 2  https://a0.muscache.com/im/users/54730/profile...
# 3  https://a0.muscache.com/im/users/60302/profile...
# 4  https://a0.muscache.com/im/users/1573870/profi...
#
#                                   host_thumbnail_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/211018/profil...            Pimlico
# 1  https://a0.muscache.com/im/users/757377/profil...        Hammersmith
# 2  https://a0.muscache.com/im/users/54730/profile...    LB of Islington
# 3  https://a0.muscache.com/im/users/60302/profile...            Chelsea
# 4  https://a0.muscache.com/im/users/1573870/profi...         Shoreditch
#
#    host_listings_count  host_total_listings_count  host_verifications  \
# 0                  1.0                        5.0  ['email', 'phone']
# 1                  1.0                        2.0  ['email', 'phone']
# 2                  3.0                        4.0  ['email', 'phone']
# 3                  1.0                       12.0  ['email', 'phone']
# 4                  1.0                        3.0  ['email', 'phone']
#
#   host_has_profile_pic host_identity_verified  number_of_reviews  \
# 0                    t                      f                  1
# 1                    t                      t                175
# 2                    t                      t                 41
# 3                    t                      t                 94
# 4                    t                      t                 20
#
#    availability_365
# 0                 0
# 1                67
# 2               353
# 3                70
# 4                 4

# %%
# It's strange that host_response_rate is not filled sometimes
listing[listing['host_response_rate'].isna()][:20]
# Out:
#         id                          listing_url       scrape_id last_scraped  \
# 0   154221  https://www.airbnb.com/rooms/154221  20230608145305   2023-06-10
# 6   306405  https://www.airbnb.com/rooms/306405  20230608145305   2023-06-08
# 7   306677  https://www.airbnb.com/rooms/306677  20230608145305   2023-06-10
# 11  168359  https://www.airbnb.com/rooms/168359  20230608145305   2023-06-10
# 13   25123   https://www.airbnb.com/rooms/25123  20230608145305   2023-06-09
# 14  306737  https://www.airbnb.com/rooms/306737  20230608145305   2023-06-09
# 16  170702  https://www.airbnb.com/rooms/170702  20230608145305   2023-06-10
# 19  310665  https://www.airbnb.com/rooms/310665  20230608145305   2023-06-10
# 20   33332   https://www.airbnb.com/rooms/33332  20230608145305   2023-06-09
# 21  172807  https://www.airbnb.com/rooms/172807  20230608145305   2023-06-10
# 24  172811  https://www.airbnb.com/rooms/172811  20230608145305   2023-06-10
# 28  179312  https://www.airbnb.com/rooms/179312  20230608145305   2023-06-10
# 38   39387   https://www.airbnb.com/rooms/39387  20230608145305   2023-06-10
# 39   41311   https://www.airbnb.com/rooms/41311  20230608145305   2023-06-09
# 40  313710  https://www.airbnb.com/rooms/313710  20230608145305   2023-06-10
# 41  186682  https://www.airbnb.com/rooms/186682  20230608145305   2023-06-10
# 42   41445   https://www.airbnb.com/rooms/41445  20230608145305   2023-06-09
# 43  190015  https://www.airbnb.com/rooms/190015  20230608145305   2023-06-10
# 47  314985  https://www.airbnb.com/rooms/314985  20230608145305   2023-06-10
# 51   41870   https://www.airbnb.com/rooms/41870  20230608145305   2023-06-10
#
#              source                                               name  \
# 0   previous scrape  Rental unit in London · 2 bedrooms · 2 beds · ...
# 6       city scrape  Rental unit in Dagenham · ★4.0 · 1 bedroom · 1...
# 7   previous scrape  Rental unit in London · ★4.56 · 2 bedrooms · 3...
# 11  previous scrape  Rental unit in Greater London · ★4.63 · 2 bedr...
# 13      city scrape  Home in Barnet · ★4.78 · 1 bedroom · 1 bed · 1...
# 14      city scrape  Rental unit in London · ★4.92 · 5 bedrooms · 4...
# 16  previous scrape  Rental unit in London · ★4.95 · 1 bedroom · 1 ...
# 19  previous scrape  Townhouse in London · ★4.89 · 5 bedrooms · 4 b...
# 20      city scrape  Home in  St Margaret's, Isleworth · ★4.40 · 1 ...
# 21  previous scrape  Rental unit in Paddington · ★4.75 · 2 bedrooms...
# 24  previous scrape    Rental unit in Camden Town · 2 bedrooms · 1 bed
# 28  previous scrape  Condo in Greater London · ★5.0 · 1 bedroom · 1...
# 38  previous scrape  Condo in London · ★4.50 · 1 bedroom · 1 bed · ...
# 39      city scrape  Home in Barnet · ★4.90 · 1 bedroom · 1 bed · 1...
# 40  previous scrape  Rental unit in London · ★4.88 · 1 bedroom · 1 ...
# 41  previous scrape  Rental unit in London · ★4.83 · 1 bedroom · 1 ...
# 42      city scrape  Rental unit in London · ★4.56 · 2 bedrooms · 3...
# 43  previous scrape  Rental unit in London · ★4.82 · 2 bedrooms · 3...
# 47  previous scrape  Home in London · ★4.80 · 1 bedroom · 1 bed · 0...
# 51  previous scrape  Home in Walthamstow · 2 bedrooms · 1 bed · 2.5...
#
#                                           description  \
# 0   hi, i am renting my 2 bedroom flat in Pimlico ...
# 6   <b>The space</b><br />It is suitable for solo ...
# 7   Non smoking apartment worth uk£600k (US$900k) ...
# 11  This 2 bedroom flat is in a brilliantly conven...
# 13  Big room with double bed/ clean sheets/ clean ...
# 14  <b>The space</b><br />4 bedroom (+ nursery) st...
# 16  <b>The space</b><br />The Appartment is on the...
# 19  5 bedroom family home in the heart of Stoke Ne...
# 19  https://www.airbnb.com/users/show/1460505  Catherine  2011-12-01
# 20   https://www.airbnb.com/users/show/144444    Chi-Chi  2010-06-14
# 21   https://www.airbnb.com/users/show/824591       Anna  2011-07-15
# 24   https://www.airbnb.com/users/show/806983     Elinor  2011-07-11
# 28   https://www.airbnb.com/users/show/858555    Larissa  2011-07-23
# 38   https://www.airbnb.com/users/show/168920       Alec  2010-07-17
# 39   https://www.airbnb.com/users/show/103583      Grace  2010-04-05
# 40  https://www.airbnb.com/users/show/1612623       Alex  2012-01-16
# 41   https://www.airbnb.com/users/show/897316      Emily  2011-07-31
# 42   https://www.airbnb.com/users/show/180838       Sean  2010-07-26
# 43   https://www.airbnb.com/users/show/917148       Sara  2011-08-03
# 47  https://www.airbnb.com/users/show/1617885      Roger  2012-01-17
# 51   https://www.airbnb.com/users/show/182993      Bimpe  2010-07-27
#
#                   host_location  \
# 0                   Rome, Italy
# 6        London, United Kingdom
# 7        London, United Kingdom
# 11       London, United Kingdom
# 13       London, United Kingdom
# 14       London, United Kingdom
# 16       London, United Kingdom
# 19       London, United Kingdom
# 20    Isleworth, United Kingdom
# 21              Berlin, Germany
# 24  Camden Town, United Kingdom
# 28       London, United Kingdom
# 38       London, United Kingdom
# 39       London, United Kingdom
# 40       London, United Kingdom
# 41       London, United Kingdom
# 42      Edgware, United Kingdom
# 43       London, United Kingdom
# 47       London, United Kingdom
# 51       London, United Kingdom
#
#                                            host_about host_response_time  \
# 0   i love to travel and therefor want to give my ...                NaN
# 6                                  Hi my name is ruby                NaN
# 7                      Live life travel see the world                NaN
# 11  Hi my name is Michele. I am a citizen of the w...                NaN
# 13  Easy going, friendly\n\nAttentive to detail an...                NaN
# 14  We have a beautiful home in the heart of Belsi...                NaN
# 16  I am Grandmother enjoying my retirement with a...                NaN
# 19  Karl and Catherine from London. Catherine is o...                NaN
# 20  Quite busy and often in a different place ever...                NaN
# 21  I am a German photographer based in London and...                NaN
# 24  A couple from London who works in the travel i...                NaN
# 28  Hello! I'm a TV Producer living in this great ...                NaN
# 38  Relaxed and mature kinda guy into creative art...                NaN
# 39  Easy going, friendly\n\nAttentive to detail an...                NaN
# 40  I have lived in North London most of my adult ...                NaN
# 41  I am a fun, quirky, open-minded, professional ...                NaN
# 42  I am originally from Dublin Ireland, I have li...                NaN
# 43  I am an academic, working in a technology fiel...                NaN
# 47  Your very welcome to come and  stay at this be...                NaN
# 51  Hi, \r\n\r\nI am a friendly mum of three grown...                NaN
#
#    host_response_rate host_acceptance_rate host_is_superhost  \
# 0                 NaN                  NaN                 f
# 6                 NaN                  NaN               NaN
# 7                 NaN                  NaN                 f
# 11                NaN                  NaN                 f
# 13                NaN                  NaN               NaN
# 14                NaN                  NaN                 f
# 16                NaN                  NaN               NaN
# 19                NaN                  NaN                 f
# 20                NaN                  68%               NaN
# 21                NaN                  NaN                 f
# 24                NaN                  NaN                 f
# 28                NaN                  NaN                 f
# 38                NaN                  NaN               NaN
# 39                NaN                  NaN               NaN
# 51                   Stratford                  1.0
#
#     host_total_listings_count                host_verifications  \
# 0                         5.0                ['email', 'phone']
# 6                         1.0                ['email', 'phone']
# 7                        14.0                ['email', 'phone']
# 11                        2.0                         ['phone']
# 13                        3.0                ['email', 'phone']
# 14                        1.0                ['email', 'phone']
# 16                        1.0                ['email', 'phone']
# 19                        1.0                ['email', 'phone']
# 20                        2.0                ['email', 'phone']
# 21                        2.0  ['email', 'phone', 'work_email']
# 24                        5.0                ['email', 'phone']
# 28                        1.0                ['email', 'phone']
# 38                        1.0                ['email', 'phone']
# 39                        3.0                ['email', 'phone']
# 40                        1.0                ['email', 'phone']
# 41                        1.0                ['email', 'phone']
# 42                        3.0  ['email', 'phone', 'work_email']
# 43                        3.0                ['email', 'phone']
# 47                        1.0                ['email', 'phone']
# 51                        1.0                ['email', 'phone']
#
#    host_has_profile_pic host_identity_verified  \
# 0                     t                      f
# 6                     t                      f
# 7                     t                      t
# 11                    t                      f
# 13                    t                      t
# 14                    t                      t
# 16                    t                      t
# 19                    t                      t
# 20                    t                      f
# 21                    t                      f
# 24                    t                      t
# 28                    t                      t
# 38                    t                      t
# 39                    t                      t
# 40                    t                      t
# 41                    t                      t
# 42                    t                      t
# 43                    t                      t
# 47                    t                      f
# 51                    t                      f
#
#                                         neighbourhood neighbourhood_cleansed  \
# 0                     London, England, United Kingdom            Westminster
# 6                                                 NaN   Barking and Dagenham
# 7                              London, United Kingdom              Southwark
# 11            Greater London, England, United Kingdom              Southwark
# 13                    Barnet, England, United Kingdom                 Barnet
# 14                                                NaN                 Camden
# 16                                                NaN          Tower Hamlets
# 19                             London, United Kingdom                Hackney
# 20   St Margaret's, Isleworth, Middlesex, United K...   Richmond upon Thames
# 21                                                NaN            Westminster
# 24                                                NaN                 Camden
# 28            Greater London, England, United Kingdom              Islington
# 38                    London, England, United Kingdom            Westminster
# 39                    Barnet, England, United Kingdom                 Barnet
# 40                                                NaN                  Brent
# 41                    London, England, United Kingdom                  Brent
# 42                             London, United Kingdom                 Barnet
# 43                             London, United Kingdom                Hackney
# 47                                                NaN                 Newham
# 51        Walthamstow, Greater London, United Kingdom         Waltham Forest
#
#     neighbourhood_group_cleansed  latitude  longitude  \
# 0                            NaN  51.48970   -0.13911
# 6                            NaN  51.54072    0.15246
# 7                            NaN  51.49739   -0.10146
# 11                           NaN  51.49185   -0.08823
# 13                           NaN  51.57438   -0.21081
# 14                           NaN  51.54655   -0.16495
# 16                           NaN  51.49686   -0.02627
# 19                           NaN  51.56099   -0.07740
# 20                           NaN  51.46410   -0.32498
# 21                           NaN  51.51789   -0.15800
# 24                           NaN  51.54710   -0.17981
# 28                           NaN  51.55191   -0.11497
# 38                           NaN  51.52605   -0.19942
# 39                           NaN  51.57400   -0.21058
# 40                           NaN  51.53347   -0.23292
# 41                           NaN  51.54209   -0.20200
# 42                           NaN  51.61492   -0.25632
# 43                           NaN  51.53715   -0.06418
# 47                           NaN  51.52626    0.02904
# 51                           NaN  51.55840    0.00258
#
#                   property_type        room_type  accommodates  bathrooms  \
# 0            Entire rental unit  Entire home/apt             3        NaN
# 6   Private room in rental unit     Private room             1        NaN
# 7            Entire rental unit  Entire home/apt             5        NaN
# 11           Entire rental unit  Entire home/apt             4        NaN
# 13         Private room in home     Private room             2        NaN
# 14           Entire rental unit  Entire home/apt             7        NaN
# 16  Private room in rental unit     Private room             2        NaN
# 19             Entire townhouse  Entire home/apt             8        NaN
# 20         Private room in home     Private room             2        NaN
# 21           Entire rental unit  Entire home/apt             2        NaN
# 24           Entire rental unit  Entire home/apt             2        NaN
# 28                 Entire condo  Entire home/apt             2        NaN
# 38        Private room in condo     Private room             1        NaN
# 39         Private room in home     Private room             2        NaN
# 40           Entire rental unit  Entire home/apt             3        NaN
# 41           Entire rental unit  Entire home/apt             3        NaN
# 42           Entire rental unit  Entire home/apt             4        NaN
# 43           Entire rental unit  Entire home/apt             5        NaN
# 47         Private room in home     Private room             2        NaN
# 51         Private room in home     Private room             1        NaN
#
#       bathrooms_text  bedrooms  beds  \
# 0             1 bath       2.0   2.0
# 6            0 baths       NaN   1.0
# 7             1 bath       2.0   3.0
# 11            1 bath       2.0   3.0
# 13  1.5 shared baths       NaN   1.0
# 14         2.5 baths       5.0   4.0
# 16            1 bath       NaN   1.0
# 19         2.5 baths       5.0   4.0
# 20    1 private bath       NaN   1.0
# 21            1 bath       2.0   1.0
# 24               NaN       2.0   1.0
# 28            1 bath       1.0   1.0
# 38     1 shared bath       NaN   1.0
# 39         1.5 baths       NaN   1.0
# 40            1 bath       1.0   1.0
# 41            1 bath       1.0   1.0
# 42            1 bath       2.0   3.0
# 43         1.5 baths       2.0   3.0
# 47           0 baths       NaN   1.0
# 51  2.5 shared baths       NaN   1.0
#
#                                             amenities    price  \
# 0   ["TV", "Microwave", "Dishwasher", "Wifi", "Ref...   $83.00
# 6   ["Wifi", "Washer", "Heating", "Kitchen", "TV w...   $41.00
# 7   ["TV", "Elevator", "Wifi", "Hot water", "Iron"...  $132.00
# 11  ["Oven", "Free parking on premises", "Hot wate...  $111.00
# 13  ["Wifi", "Iron", "Lock on bedroom door", "Wash...   $29.00
# 14  ["Room-darkening shades", "Oven", "Hot water",...  $457.00
# 16  ["TV", "Wifi", "Breakfast", "Smoke alarm", "He...   $60.00
# 19  ["Room-darkening shades", "Oven", "Hot water",...  $190.00
# 20  ["Oven", "Self check-in", "Wifi", "Building st...  $140.00
# 21  ["TV", "Wifi", "Washer", "Smoke alarm", "Heati...  $205.00
# 24  ["TV with standard cable", "Wifi", "Heating", ...  $229.00
# 28  ["Oven", "Hot water", "Washer", "Extra pillows...   $45.00
# 38  ["Room-darkening shades", "Freezer", "Oven", "...   $42.00
# 39  ["Wifi", "Iron", "Lock on bedroom door", "Wash...   $25.00
# 40  ["TV", "Wifi", "Washer", "Heating", "Kitchen",...   $89.00
# 41  ["Oven", "Microwave", "Dishwasher", "Wifi", "R...   $69.00
# 42  ["Oven", "Free parking on premises", "Hot wate...  $550.00
# 43  ["Canal view", "Freezer", "Oven", "Hot water",...  $240.00
# 47  ["Free parking on premises", "Wifi", "Washer",...   $32.00
# 51               ["Breakfast", "Free street parking"]   $37.00
#
#     minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0                2              30                     2.0
# 6                4             365                     4.0
# 7                5              90                     5.0
# 11               2            1125                     2.0
# 13              10            1120                    10.0
# 14               4            1125                     4.0
# 16               3             365                     3.0
# 19               3               7                     3.0
# 20               2              21                     2.0
# 21               3              20                     2.0
# 24              21             365                    21.0
# 28               2            1125                     2.0
# 38               5              10                     5.0
# 39              10            1124                    10.0
# 40               2              14                     2.0
# 41               2            1125                     2.0
# 42              14            1125                    14.0
# 43               4             365                     4.0
# 47               2               7                     2.0
# 51               2             730                     2.0
#
#     maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                      2.0                    30.0                    30.0
# 6                      4.0                   365.0                   365.0
# 7                      5.0                  1125.0                  1125.0
# 11                     3.0                  1125.0                  1125.0
# 13                    10.0                  1125.0                  1125.0
# 14                     7.0                  1125.0                  1125.0
# 16                     3.0                   365.0                   365.0
# 19                     3.0                     7.0                     7.0
# 20                     2.0                    21.0                    21.0
# 21                     3.0                    20.0                    20.0
# 24                    21.0                   365.0                   365.0
# 28                     2.0                  1125.0                  1125.0
# 38                     5.0                    10.0                    10.0
# 39                    10.0                  1125.0                  1125.0
# 40                     2.0                    14.0                    14.0
# 41                     2.0                  1125.0                  1125.0
# 42                    14.0                  1125.0                  1125.0
# 43                     4.0                   365.0                   365.0
# 47                     2.0                     7.0                     7.0
# 51                     2.0                   730.0                   730.0
#
#     minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                      2.0                    30.0               NaN
# 6                      4.0                   365.0               NaN
# 7                      5.0                  1125.0               NaN
# 11                     2.4                  1125.0               NaN
# 13                    10.0                  1125.0               NaN
# 14                     4.2                  1125.0               NaN
# 16                     3.0                   365.0               NaN
# 19                     3.0                     7.0               NaN
# 20                     2.0                    21.0               NaN
# 21                     2.7                    20.0               NaN
# 24                    21.0                   365.0               NaN
# 28                     2.0                  1125.0               NaN
# 38                     5.0                    10.0               NaN
# 39                    10.0                  1125.0               NaN
# 40                     2.0                    14.0               NaN
# 41                     2.0                  1125.0               NaN
# 42                    14.0                  1125.0               NaN
# 43                     4.0                   365.0               NaN
# 47                     2.0                     7.0               NaN
# 51                     2.0                   730.0               NaN
#
#    has_availability  availability_30  availability_60  availability_90  \
# 0                 t                0                0                0
# 6                 t               30               60               90
# 7                 t                0                0                0
# 11                t                0                0                0
# 13                t                0                0                0
# 14                t                1               16               24
# 16                t                0                0                0
# 19                t                0                0                0
# 20                t               28               58               88
# 21                t                0                0                0
# 24                t                0                0                0
# 28                t                0                0                0
# 38                t                0                0                0
# 39                t                0                0                0
# 40                t                0                0                0
# 41                t                0                0                0
# 42                t               23               53               83
# 43                t                0                0                0
# 47                t                0                0                0
# 51                t                0                0                0
#
#     availability_365 calendar_last_scraped  number_of_reviews  \
# 0                  0            2023-06-10                  1
# 6                365            2023-06-08                  3
# 7                  0            2023-06-10                218
# 11                 0            2023-06-10                 10
# 13                 0            2023-06-09                129
# 14               172            2023-06-09                 26
# 16                 0            2023-06-10                136
# 19                 0            2023-06-10                 22
# 19                    4.83                 5.00      NaN                f
# 20                    4.68                 4.26      NaN                f
# 21                    4.88                 4.75      NaN                f
# 24                     NaN                  NaN      NaN                f
# 28                    5.00                 5.00      NaN                f
# 38                    4.50                 4.30      NaN                f
# 39                    4.51                 4.81      NaN                t
# 40                    4.56                 4.67      NaN                f
# 41                    4.73                 4.83      NaN                f
# 42                    4.53                 4.26      NaN                f
# 43                    4.71                 4.65      NaN                f
# 47                    4.17                 4.33      NaN                f
# 51                    4.00                 4.00      NaN                t
#
#     calculated_host_listings_count  \
# 0                                1
# 6                                1
# 7                                6
# 11                               1
# 13                               3
# 14                               1
# 16                               1
# 19                               1
# 20                               2
# 21                               1
# 24                               1
# 28                               1
# 38                               1
# 39                               3
# 40                               1
# 41                               1
# 42                               1
# 43                               1
# 47                               1
# 51                               1
#
#     calculated_host_listings_count_entire_homes  \
# 0                                             1
# 6                                             0
# 7                                             6
# 11                                            1
# 13                                            0
# 14                                            1
# 16                                            0
# 19                                            1
# 20                                            0
# 21                                            1
# 24                                            1
# 28                                            1
# 38                                            0
# 39                                            0
# 40                                            1
# 41                                            1
# 42                                            1
# 43                                            1
# 47                                            0
# 51                                            0
#
#     calculated_host_listings_count_private_rooms  \
# 0                                              0
# 6                                              1
# 7                                              0
# 11                                             0
# 13                                             3
# 14                                             0
# 16                                             1
# 19                                             0
# 20                                             2
# 21                                             0
# 24                                             0
# 28                                             0
# 38                                             1
# 39                                             3
# 40                                             0
# 41                                             0
# 42                                             0
# 43                                             0
# 47                                             1
# 51                                             1
#
#     calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                             0               0.01
# 6                                             0               0.02
# 7                                             0               1.58
# 11                                            0               0.07
# 13                                            0               0.81
# 14                                            0               0.20
# 16                                            0               0.94
# 19                                            0               0.17
# 20                                            0               0.13
# 21                                            0               0.12
# 24                                            0                NaN
# 28                                            0               0.10
# 38                                            0               0.09
# 39                                            0               0.54
# 40                                            0               0.07
# 41                                            0               0.39
# 42                                            0               0.16
# 43                                            0               0.13
# 47                                            0               0.05
# 51                                            0               0.01

# %% [markdown]
# **Observations**:
# - `has_availability` is sometimes true, but the availability for next 365 days = 0
# - host_since is a date field not a string
# - host is hosting a long time, but in last year no reviews and availabily next 365 years sometimes 0. Could it be that hosts took the property off the market, and the response rate fields are missing due to this ?

# %% [markdown]
# #### Can we identify possible inactive properties ?

# %%
# extract what we think could be inactive properties, no availability and reviews 
inactive_test = listing[(listing['has_availability'] == 't') & 
                        (listing['availability_365'] == 0) & 
                        (listing['number_of_reviews_ltm'] == 0)]
inactive_test.sample(10)
# Out:
#                        id                                      listing_url  \
# 40290            42490686            https://www.airbnb.com/rooms/42490686
# 3689              4944705             https://www.airbnb.com/rooms/4944705
# 24072            23995717            https://www.airbnb.com/rooms/23995717
# 27837            28252320            https://www.airbnb.com/rooms/28252320
# 15899            17618864            https://www.airbnb.com/rooms/17618864
# 23208            23067650            https://www.airbnb.com/rooms/23067650
# 29006            29607635            https://www.airbnb.com/rooms/29607635
# 6358              7794160             https://www.airbnb.com/rooms/7794160
# 72999  851402818243710479  https://www.airbnb.com/rooms/851402818243710479
# 29317            30100445            https://www.airbnb.com/rooms/30100445
#
#             scrape_id last_scraped           source  \
# 40290  20230608145305   2023-06-10  previous scrape
# 3689   20230608145305   2023-06-09  previous scrape
# 24072  20230608145305   2023-06-10  previous scrape
# 27837  20230608145305   2023-06-09  previous scrape
# 15899  20230608145305   2023-06-10  previous scrape
# 23208  20230608145305   2023-06-10  previous scrape
# 29006  20230608145305   2023-06-09  previous scrape
# 6358   20230608145305   2023-06-10  previous scrape
# 72999  20230608145305   2023-06-10  previous scrape
# 29317  20230608145305   2023-06-09  previous scrape
#
#                                                     name  \
# 40290  Rental unit in Greater London · 1 bedroom · 1 ...
# 3689   Rental unit in London · 2 bedrooms · 1 bed · 1...
# 24072  Home in Greater London · 1 bedroom · 1 bed · 1...
# 27837  Townhouse in Greater London · ★4.95 · 1 bedroo...
# 15899  Home in London · ★5.0 · 3 bedrooms · 3 beds · ...
# 23208  Home in Greater London · ★4.50 · 1 bedroom · 1...
# 29006  Rental unit in Greater London · ★4.94 · 1 bedr...
# 6358   Home in Twickenham · ★5.0 · 1 bedroom · 1 bed ...
# 72999  Rental unit in Greater London · 1 bedroom · 1 ...
# 29317  Rental unit in Greater London · ★5.0 · 1 bedro...
#
#                                              description  \
# 40290  Está maravilhosa acomodação fica em Wood Green...
# 3689   We have a fantastic large double bedroom, with...
# 24072                           Nice room is available !
# 27837  We renovated our lovely home in 2018 and are l...
# 15899  Our house offers a lovely, quiet and spacious ...
# 23208  This property is very close to Brixton undergr...
# 29006  A comfortable apartment in Clapham, South Lond...
# 6358   One double and/or two single rooms available i...
# 72999  I'm subleting my place for a short term from M...
# 29317  * We are increasing the time between guests an...
#
#                                    neighborhood_overview  \
# 40290  Bairro genuinamente Londrino, com pubs, restau...
# 3689   Quite street with friendly neighbours. We are ...
# 24072                                                NaN
# 27837  .<br />Our house is located in the peaceful ne...
# 15899  Muswell Hill is green, quiet, safe and friendl...
# 23208                                                NaN
# 29006  Clapham is based around Clapham Common, a larg...
# 6358   Good location in a quiet residential road but ...
# 72999                                                NaN
# 29317  However central, the neighbourhood is lovely a...
#
#                                              picture_url    host_id  \
# 40290  https://a0.muscache.com/pictures/e7c55ff9-d056...  112521536
# 3689   https://a0.muscache.com/pictures/61986596/169f...    3854232
# 24072  https://a0.muscache.com/pictures/44d1deb8-f787...   57145280
# 27837  https://a0.muscache.com/pictures/7e49e729-efe4...    1620613
# 15899  https://a0.muscache.com/pictures/ece34c2b-d3f7...   35074534
# 23208  https://a0.muscache.com/pictures/68b2baae-d2d4...  171252593
# 29006  https://a0.muscache.com/pictures/6e829429-00c9...   12894813
# 6358   https://a0.muscache.com/pictures/100161487/f7f...   41024325
# 72999  https://a0.muscache.com/pictures/45deb131-440f...   68373830
# 29317  https://a0.muscache.com/pictures/e39eb44e-54ae...   17733834
#
#                                           host_url        host_name  \
# 40290  https://www.airbnb.com/users/show/112521536  Vanessa Tischer
# 3689     https://www.airbnb.com/users/show/3854232           Evelyn
# 40290                LB of Haringey                  2.0
# 3689                Stoke Newington                  1.0
# 24072                LB of Haringey                  2.0
# 27837                     Wimbledon                  3.0
# 15899                  LB of Barnet                  1.0
# 23208                    Herne Hill                  1.0
# 29006                     Stockwell                  1.0
# 6358     LB of Richmond upon Thames                  1.0
# 72999                           NaN                  1.0
# 29317  RB of Kensington and Chelsea                  1.0
#
#        host_total_listings_count                host_verifications  \
# 40290                        2.0                ['email', 'phone']
# 3689                         2.0  ['email', 'phone', 'work_email']
# 24072                        2.0  ['email', 'phone', 'work_email']
# 27837                        5.0                ['email', 'phone']
# 15899                        1.0                ['email', 'phone']
# 23208                        1.0                ['email', 'phone']
# 29006                        1.0                ['email', 'phone']
# 6358                         1.0                ['email', 'phone']
# 72999                        2.0                ['email', 'phone']
# 29317                        2.0                ['email', 'phone']
#
#       host_has_profile_pic host_identity_verified  \
# 40290                    t                      t
# 3689                     t                      t
# 24072                    t                      t
# 27837                    t                      t
# 15899                    t                      t
# 23208                    t                      f
# 29006                    t                      t
# 6358                     t                      f
# 72999                    t                      t
# 29317                    t                      t
#
#                                  neighbourhood  neighbourhood_cleansed  \
# 40290  Greater London, England, United Kingdom                Haringey
# 3689                    London, United Kingdom                 Hackney
# 24072                                      NaN                Haringey
# 27837  Greater London, England, United Kingdom                  Merton
# 15899          London, England, United Kingdom                  Barnet
# 23208                                      NaN                 Lambeth
# 29006  Greater London, England, United Kingdom                 Lambeth
# 6358                Twickenham, United Kingdom    Richmond upon Thames
# 72999                                      NaN                Lewisham
# 29317  Greater London, England, United Kingdom  Kensington and Chelsea
#
#        neighbourhood_group_cleansed   latitude  longitude  \
# 40290                           NaN  51.600120  -0.111280
# 3689                            NaN  51.556100  -0.075480
# 24072                           NaN  51.591530  -0.080830
# 27837                           NaN  51.430750  -0.195500
# 15899                           NaN  51.599560  -0.151960
# 23208                           NaN  51.462030  -0.111120
# 29006                           NaN  51.466250  -0.126260
# 6358                            NaN  51.450030  -0.354270
# 72999                           NaN  51.474168  -0.025039
# 29317                           NaN  51.526850  -0.213450
#
#                      property_type        room_type  accommodates  bathrooms  \
# 40290  Private room in rental unit     Private room             2        NaN
# 3689   Private room in rental unit     Private room             2        NaN
# 24072         Private room in home     Private room             2        NaN
# 27837    Private room in townhouse     Private room             2        NaN
# 15899                  Entire home  Entire home/apt             4        NaN
# 23208                  Entire home  Entire home/apt             4        NaN
# 29006           Entire rental unit  Entire home/apt             2        NaN
# 6358          Private room in home     Private room             2        NaN
# 72999           Entire rental unit  Entire home/apt             2        NaN
# 29317           Entire rental unit  Entire home/apt             3        NaN
#
#          bathrooms_text  bedrooms  beds  \
# 40290     1 shared bath       NaN   1.0
# 3689   1.5 shared baths       NaN   1.0
# 24072     1 shared bath       NaN   1.0
# 27837         1.5 baths       NaN   1.0
# 15899         2.5 baths       3.0   3.0
# 23208            1 bath       1.0   1.0
# 29006            1 bath       1.0   1.0
# 6358             1 bath       NaN   1.0
# 72999            1 bath       1.0   1.0
# 29317            1 bath       1.0   2.0
# 24072                  4.00                     2.0
# 27837                  4.95                     5.0
# 15899                  5.00                     5.0
# 23208                  4.50                     4.7
# 29006                  4.94                     5.0
# 6358                   5.00                     5.0
# 72999                   NaN                     NaN
# 29317                  5.00                     4.8
#
#        review_scores_cleanliness  review_scores_checkin  \
# 40290                        NaN                    NaN
# 3689                         NaN                    NaN
# 24072                        3.0                   4.00
# 27837                        5.0                   4.98
# 15899                        5.0                   5.00
# 23208                        4.4                   4.30
# 29006                        5.0                   4.94
# 6358                         5.0                   5.00
# 72999                        NaN                    NaN
# 29317                        4.4                   4.80
#
#        review_scores_communication  review_scores_location  \
# 40290                          NaN                     NaN
# 3689                           NaN                     NaN
# 24072                         3.00                    2.00
# 27837                         5.00                    4.84
# 15899                         5.00                    4.67
# 23208                         4.40                    4.40
# 29006                         4.94                    5.00
# 6358                          5.00                    5.00
# 72999                          NaN                     NaN
# 29317                         5.00                    4.80
#
#        review_scores_value  license instant_bookable  \
# 40290                  NaN      NaN                f
# 3689                   NaN      NaN                f
# 24072                 3.00      NaN                f
# 27837                 4.89      NaN                f
# 15899                 5.00      NaN                t
# 23208                 4.50      NaN                f
# 29006                 5.00      NaN                f
# 6358                  5.00      NaN                f
# 72999                  NaN      NaN                t
# 29317                 4.80      NaN                f
#
#        calculated_host_listings_count  \
# 40290                               2
# 3689                                1
# 24072                               2
# 27837                               2
# 15899                               1
# 23208                               1
# 29006                               1
# 6358                                1
# 72999                               1
# 29317                               1
#
#        calculated_host_listings_count_entire_homes  \
# 40290                                            0
# 3689                                             0
# 24072                                            0
# 27837                                            0
# 15899                                            1
# 23208                                            1
# 29006                                            1
# 6358                                             0
# 72999                                            1
# 29317                                            1
#
#        calculated_host_listings_count_private_rooms  \
# 40290                                             2
# 3689                                              1
# 24072                                             2
# 27837                                             2
# 15899                                             0
# 23208                                             0
# 29006                                             0
# 6358                                              1
# 72999                                             0
# 29317                                             0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 40290                                            0                NaN
# 3689                                             0                NaN
# 24072                                            0               0.02
# 27837                                            0               0.78
# 15899                                            0               0.09
# 23208                                            0               0.17
# 29006                                            0               0.29
# 6358                                             0               0.03
# 72999                                            0                NaN
# 29317                                            0               0.09

# %% [markdown]
# >**Observation**
# >- There definetely seem to be quite a lot of properties in the dataset that seems inactive, it looks like the host are no longer renting them out

# %%
# since when was inactive listings on the market ?
inactive_test.host_since.str[:4].astype(float).plot(kind='hist', bins=10, color=BASE_COLOR)
plt.title('Inactive listings - host_since summary')
plt.show()

# %%
# minimum rental nights for 'inactive' records
inactive_test.minimum_nights_avg_ntm.describe()
# Out:
# count    24166.000000
# mean         5.004221
# std         24.323286
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          4.000000
# max       1125.000000
# Name: minimum_nights_avg_ntm, dtype: float64

# %%
# how many properties does hosts have ?
inactive_test.host_listings_count.describe()
# Out:
# count    24162.000000
# mean        19.998965
# std        165.231221
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max       2747.000000
# Name: host_listings_count, dtype: float64

# %%
# how many total properties does hosts have ?
inactive_test.host_total_listings_count.describe()
# Out:
# count    24162.000000
# mean        32.907748
# std        283.011461
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          3.000000
# max       4724.000000
# Name: host_total_listings_count, dtype: float64

# %%
# display an 'inactive' listing that was introduced only in the current year
inactive_test[inactive_test.host_since == '2023-03-09']
# Out:
#                        id                                      listing_url  \
# 72042  843945826445757806  https://www.airbnb.com/rooms/843945826445757806
#
#             scrape_id last_scraped           source  \
# 72042  20230608145305   2023-06-10  previous scrape
#
#                                                     name  \
# 72042  Home in Greater London · 3 bedrooms · 3 beds ·...
#
#                                              description  \
# 72042  Beautiful period house next to London fields a...
#
#                                    neighborhood_overview  \
# 72042  London fields park is just around the corner a...
#
#                                              picture_url    host_id  \
# 72042  https://a0.muscache.com/pictures/miso/Hosting-...  504659671
#
#                                           host_url host_name  host_since  \
# 72042  https://www.airbnb.com/users/show/504659671    Petros  2023-03-09
#
#                 host_location  \
# 72042  London, United Kingdom
#
#                                               host_about host_response_time  \
# 72042  Hello am Petros , I live by London fields for ...                NaN
#
#       host_response_rate host_acceptance_rate host_is_superhost  \
# 72042                NaN                  NaN                 f
#
#                                       host_thumbnail_url  \
# 72042  https://a0.muscache.com/im/pictures/user/1fde6...
#
#                                         host_picture_url host_neighbourhood  \
# 72042  https://a0.muscache.com/im/pictures/user/1fde6...                NaN
#
#        host_listings_count  host_total_listings_count  host_verifications  \
# 72042                  1.0                        1.0  ['email', 'phone']
#
#       host_has_profile_pic host_identity_verified  \
# 72042                    t                      t
#
#                                  neighbourhood neighbourhood_cleansed  \
# 72042  Greater London, England, United Kingdom                Hackney
#
#        neighbourhood_group_cleansed  latitude  longitude property_type  \
# 72042                           NaN  51.54077   -0.06416   Entire home
#
#              room_type  accommodates  bathrooms bathrooms_text  bedrooms  \
# 72042  Entire home/apt             6        NaN        2 baths       3.0
#
#        beds                                          amenities    price  \
# 72042   3.0  ["Freezer", "Oven", "Hot water", "Paid parking...  $350.00
#
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# 72042               3             365                     3.0
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 72042                     3.0                   365.0                   365.0
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 72042                     3.0                   365.0               NaN
#
#       has_availability  availability_30  availability_60  availability_90  \
# 72042                t                0                0                0
#
#        availability_365 calendar_last_scraped  number_of_reviews  \
# 72042                 0            2023-06-10                  0
#
#        number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 72042                      0                       0          NaN         NaN
#
#        review_scores_rating  review_scores_accuracy  \
# 72042                   NaN                     NaN
#
#        review_scores_cleanliness  review_scores_checkin  \
# 72042                        NaN                    NaN
#
#        review_scores_communication  review_scores_location  \
# 72042                          NaN                     NaN
#
#        review_scores_value  license instant_bookable  \
# 72042                  NaN      NaN                f
#
#        calculated_host_listings_count  \
# 72042                               1
#
#        calculated_host_listings_count_entire_homes  \
# 72042                                            1
#
#        calculated_host_listings_count_private_rooms  \
# 72042                                             0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 72042                                            0                NaN

# %% [markdown]
# **Observation**:
#
# *Think about it...*
#
# If a property is really so popular that it's booked out for the whole year ahead, there would be lots of active reviews present.
# I think it's safe to assume if no availability and no reviews, when we had lots of reviews in the past, we can assume the listing is no longer on the market. It introduces lots of missing values, and could contain prices no longer matching to the current market.
#
# BUT be careful to remove long term rentals as then it make sense no availability, no reviews....
#
# Think about only removing where number of listing = 1 (private person), and minimum nights < 4 nights
#
# I think these records should be dropped instead, but only do this when host_since is in the past

# %%
# updated rule - how many listings are affected
inactive_test_2 = listing[(listing['has_availability'] == 't') & 
                          (listing['availability_365'] == 0) & 
                          (listing['number_of_reviews_ltm'] == 0) &
                          (listing['host_listings_count'] <= 3) &
                          (listing['minimum_nights_avg_ntm'] <= 30)]
len(inactive_test_2)
# Out:
# 21350

# %%
inactive_test_2.sample(5)
# Out:
#              id                            listing_url       scrape_id  \
# 13710  15445674  https://www.airbnb.com/rooms/15445674  20230608145305
# 7630    9235940   https://www.airbnb.com/rooms/9235940  20230608145305
# 35239  37015443  https://www.airbnb.com/rooms/37015443  20230608145305
# 12354  13934999  https://www.airbnb.com/rooms/13934999  20230608145305
# 26453  26658384  https://www.airbnb.com/rooms/26658384  20230608145305
#
#       last_scraped           source  \
# 13710   2023-06-10  previous scrape
# 7630    2023-06-10  previous scrape
# 35239   2023-06-09  previous scrape
# 12354   2023-06-10  previous scrape
# 26453   2023-06-10  previous scrape
#
#                                                     name  \
# 13710        Home in London · 1 bedroom · 1 bed · 1 bath
# 7630   Home in London · ★4.54 · 1 bedroom · 1 bed · 1...
# 35239  Home in Greater London · 5 bedrooms · 7 beds ·...
# 12354      Home in London · 3 bedrooms · 3 beds · 1 bath
# 26453  Home in Greater London · ★5.0 · 1 bedroom · 1 ...
#
#                                              description  \
# 13710  My place is close to Tottenham Marshes, Marmal...
# 7630   Clean double with en suite bathroom & lock. It...
# 35239  A wonderful 5 bedroom house in leafy East Dulw...
# 12354  Welcome to our comfortable home in the heart o...
# 26453  Someone who loves to travel and explore new pl...
#
#                                    neighborhood_overview  \
# 13710                                                NaN
# 7630                                                 NaN
# 35239  The neighbourhood<br /><br />East Dulwich is o...
# 12354                                                NaN
# 26453  You are in the heart of it all for commuting (...
#
#                                              picture_url    host_id  \
# 13710  https://a0.muscache.com/pictures/5ccb9b4a-b311...   99062915
# 7630   https://a0.muscache.com/pictures/a128b815-6bfd...   48006363
# 35239  https://a0.muscache.com/pictures/98cfda1a-1a4d...  228740538
# 12354  https://a0.muscache.com/pictures/c63901fa-a3fd...    5123095
# 26453  https://a0.muscache.com/pictures/2d6b4096-c316...   34242023
#
#                                           host_url host_name  host_since  \
# 13710   https://www.airbnb.com/users/show/99062915      John  2016-10-10
# 7630    https://www.airbnb.com/users/show/48006363    Jackie  2015-11-02
# 35239  https://www.airbnb.com/users/show/228740538       Sue  2018-12-02
# 12354    https://www.airbnb.com/users/show/5123095       Dee  2013-02-17
# 26453   https://www.airbnb.com/users/show/34242023    Taelon  2015-05-26
#
#                 host_location  \
# 13710  London, United Kingdom
# 7630   London, United Kingdom
# 35239                     NaN
# 12354  London, United Kingdom
# 26453    Chiang Mai, Thailand
#
#                                               host_about host_response_time  \
# 13710                                                NaN                NaN
# 7630                                                 NaN                NaN
# 35239                                                NaN                NaN
# 12354  Dublin-born, London-based, works in public pol...                NaN
# 26453  Full Stack Marketing Consultant and Digital No...                NaN
#
#       host_response_rate host_acceptance_rate host_is_superhost  \
# 13710                NaN                  NaN               NaN
# 7630                 NaN                  NaN               NaN
# 35239                NaN                  NaN                 f
# 12354                NaN                  NaN                 f
# 26453                NaN                  NaN                 f
#
#                                       host_thumbnail_url  \
# 13710  https://a0.muscache.com/im/pictures/user/66765...
# 7630   https://a0.muscache.com/im/pictures/user/4b46d...
# 35239  https://a0.muscache.com/im/pictures/user/fdc11...
# 12354  https://a0.muscache.com/im/pictures/user/ebb55...
# 26453  https://a0.muscache.com/im/pictures/user/5350e...
#
#                                         host_picture_url host_neighbourhood  \
# 13710  https://a0.muscache.com/im/pictures/user/66765...                NaN
# 7630   https://a0.muscache.com/im/pictures/user/4b46d...       LB of Newham
# 35239  https://a0.muscache.com/im/pictures/user/fdc11...       East Dulwich
# 12354  https://a0.muscache.com/im/pictures/user/ebb55...                Bow
# 26453  https://a0.muscache.com/im/pictures/user/5350e...                NaN
#
#        host_listings_count  host_total_listings_count  \
# 13710                  1.0                        1.0
# 7630                   1.0                        1.0
# 35239                  1.0                        1.0
# 12354                  1.0                        4.0
# 26453                  1.0                        1.0
#
#                      host_verifications host_has_profile_pic  \
# 13710                ['email', 'phone']                    t
# 7630                 ['email', 'phone']                    t
# 35239                ['email', 'phone']                    t
# 12354                ['email', 'phone']                    t
# 26453  ['email', 'phone', 'work_email']                    t
#
#       host_identity_verified                            neighbourhood  \
# 13710                      f                                      NaN
# 7630                       f                                      NaN
# 35239                      f  Greater London, England, United Kingdom
# 12354                      t                                      NaN
# 26453                      t  Greater London, England, United Kingdom
#
#       neighbourhood_cleansed  neighbourhood_group_cleansed  latitude  \
# 13710               Haringey                           NaN  51.59686
# 7630                  Newham                           NaN  51.51173
# 35239              Southwark                           NaN  51.45035
# 12354          Tower Hamlets                           NaN  51.52921
# 26453                 Merton                           NaN  51.40465
#
#        longitude         property_type        room_type  accommodates  \
# 13710   -0.05754  Private room in home     Private room             1
# 7630     0.02098  Private room in home     Private room             2
# 35239   -0.07016           Entire home  Entire home/apt             9
# 12354   -0.03138           Entire home  Entire home/apt             6
# 26453   -0.16795           Entire home  Entire home/apt             4
#
#        bathrooms bathrooms_text  bedrooms  beds  \
# 13710        NaN         1 bath       NaN   1.0
# 7630         NaN         1 bath       NaN   1.0
# 35239        NaN      1.5 baths       5.0   7.0
# 12354        NaN         1 bath       3.0   3.0
# 26453        NaN         1 bath       1.0   1.0
#
#                                                amenities    price  \
# 13710  ["TV", "Wifi", "Washer", "Hangers", "Breakfast...   $25.00
# 7630   ["Free parking on premises", "Wifi", "Lock on ...   $62.00
# 35239  ["TV", "Wifi", "Hot water", "Bed linens", "Iro...  $150.00
# 12354  ["TV", "Wifi", "Iron", "Washer", "Smoke alarm"...  $109.00
# 26453  ["Oven", "Free parking on premises", "Hot wate...   $50.00
#
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# 13710               5              14                     5.0
# 7630                2            1125                     2.0
# 35239               5            1125                     5.0
# 12354               3            1125                     3.0
# 26453               2              16                     2.0
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 13710                     5.0                    14.0                    14.0
# 7630                      2.0                  1125.0                  1125.0
# 35239                     5.0                  1125.0                  1125.0
# 12354                     3.0                  1125.0                  1125.0
# 26453                     2.0                    16.0                    16.0
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 13710                     5.0                    14.0               NaN
# 7630                      2.0                  1125.0               NaN
# 35239                     5.0                  1125.0               NaN
# 12354                     3.0                  1125.0               NaN
# 26453                     2.0                    16.0               NaN
#
#       has_availability  availability_30  availability_60  availability_90  \
# 13710                t                0                0                0
# 7630                 t                0                0                0
# 35239                t                0                0                0
# 12354                t                0                0                0
# 26453                t                0                0                0
#
#        availability_365 calendar_last_scraped  number_of_reviews  \
# 13710                 0            2023-06-10                  0
# 7630                  0            2023-06-10                 13
# 35239                 0            2023-06-09                  1
# 12354                 0            2023-06-10                  2
# 26453                 0            2023-06-10                 15
#
#        number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 13710                      0                       0          NaN         NaN
# 7630                       0                       0   2016-01-22  2018-10-11
# 35239                      0                       0   2019-10-25  2019-10-25
# 12354                      0                       0   2016-08-03  2016-09-11
# 26453                      0                       0   2018-07-16  2018-11-05
#
#        review_scores_rating  review_scores_accuracy  \
# 13710                   NaN                     NaN
# 7630                   4.54                    4.75
# 35239                  5.00                    5.00
# 12354                  5.00                    5.00
# 26453                  5.00                    5.00
#
#        review_scores_cleanliness  review_scores_checkin  \
# 13710                        NaN                    NaN
# 7630                        4.69                   5.00
# 35239                       5.00                   5.00
# 12354                       5.00                   5.00
# 26453                       4.92                   4.92
#
#        review_scores_communication  review_scores_location  \
# 13710                          NaN                     NaN
# 7630                           5.0                    4.55
# 35239                          5.0                    5.00
# 12354                          5.0                    5.00
# 26453                          5.0                    5.00
#
#        review_scores_value  license instant_bookable  \
# 13710                  NaN      NaN                f
# 7630                  4.55      NaN                f
# 35239                 5.00      NaN                f
# 12354                 5.00      NaN                f
# 26453                 5.00      NaN                t
#
#        calculated_host_listings_count  \
# 13710                               1
# 7630                                1
# 35239                               1
# 12354                               1
# 26453                               1
#
#        calculated_host_listings_count_entire_homes  \
# 13710                                            0
# 7630                                             0
# 35239                                            1
# 12354                                            1
# 26453                                            1
#
#        calculated_host_listings_count_private_rooms  \
# 13710                                             1
# 7630                                              1
# 35239                                             0
# 12354                                             0
# 26453                                             0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 13710                                            0                NaN
# 7630                                             0               0.14
# 35239                                            0               0.02
# 12354                                            0               0.02
# 26453                                            0               0.25

# %% [markdown]
# #### Inspect how the daily price in the listing dataset correspond to the price in calendar dataset. Is listing price the mean daily price from calendar?

# %%
# first make a temp copy
calendar_tmp = calendar[['listing_id', 'price']].copy()
listing_tmp = listing[['id', 'price']].copy()

# convert price to numeric field, so we can compare the datasets
calendar_tmp['calendar_price'] = calendar_tmp['price'].str.replace('[%$,]','', regex=True).astype('float32', copy=True)
calendar_tmp.drop(['price'], axis=1, inplace=True)

listing_tmp['listing_price'] = listing_tmp['price'].str.replace('[%$,]','', regex=True).astype('float32', copy=True)
listing_tmp.drop(['price'], axis=1, inplace=True)

listing_tmp.rename(columns={'id':'listing_id'}, inplace=True)

# %%
sns.boxplot(data=calendar_tmp, x='calendar_price')
plt.title('Calendar dataset: Daily Price Distributions')
plt.show()

# %%
sns.boxplot(data=listing_tmp, x='listing_price')
plt.title('Listing dataset: Daily Price Distributions')
plt.show()

# %% [markdown]
# >**Observation:** Accessive daily prices over 10k exist, which deserves a deeper look

# %%
df_prices = listing_tmp.merge(calendar_tmp, on='listing_id', how='inner')
df_prices.describe([0.25, 0.5, 0.75, 0.90, 0.99])
# Out:
#          listing_id  listing_price  calendar_price
# count  2.985302e+07   2.985302e+07    2.985193e+07
# mean   2.974086e+17   1.875387e+02    2.019983e+02
# std    3.792200e+17   4.774427e+02    5.265903e+02
# min    1.391300e+04   0.000000e+00    0.000000e+00
# 25%    2.105300e+07   6.100000e+01    6.500000e+01
# 50%    4.312004e+07   1.100000e+02    1.150000e+02
# 75%    7.293144e+17   1.980000e+02    2.050000e+02
# 90%    8.556898e+17   3.430000e+02    3.880000e+02
# 99%    9.042940e+17   1.570000e+03    1.570000e+03
# max    9.092815e+17   5.856400e+04    8.010000e+04

# %% [markdown]
# >**Observation:** Huge maximum prices over 50k exist at 99 percentile ! Look suspisious...

# %%
# display listings with the biggest differences between base rate in listing vs mean price from calendar dataset
calendar_grouped = df_prices.groupby('listing_id', as_index=False).agg({'listing_price':'mean', 
                                                                        'calendar_price':'mean'})
calendar_grouped['diff'] = abs(calendar_grouped['calendar_price'] - calendar_grouped['listing_price'])
calendar_grouped.sort_values('diff', ascending=False, inplace=True)
calendar_grouped.head()
# Out:
#                listing_id  listing_price  calendar_price          diff
# 36566            38452677          100.0    28365.699219  28265.699219
# 55781  658361293784718707        27579.0      927.945190  26651.054688
# 47053            51839279        24000.0     5659.394531  18340.605469
# 41968            44696103         8583.0      710.909607   7872.090332
# 30675            31622680         7580.0      571.575317   7008.424805

# %%
calendar_grouped.describe([0.5, 0.8, 0.9,  0.99])
# Out:
#          listing_id  listing_price  calendar_price          diff
# count  8.179000e+04   81790.000000    81790.000000  81790.000000
# mean   2.974054e+17     187.538788      201.996826     28.166512
# std    3.792215e+17     477.442902      470.395782    194.476959
# min    1.391300e+04       0.000000        0.000000      0.000000
# 50%    4.311966e+07     110.000000      115.445206      0.867123
# 80%    7.765786e+17     225.000000      250.000000     20.339722
# 90%    8.556883e+17     343.000000      392.627682     55.516438
# 99%    9.042934e+17    1570.000000     1570.000000    428.958932
# max    9.092815e+17   58564.000000    58420.273438  28265.699219

# %%
# Number of properties where listing daily price != mean calendar price
len(calendar_grouped[calendar_grouped['diff'] > 100])
# Out:
# 4834

# %%
# properties with biggest differences
calendar_grouped[:300]
# Out:
#                listing_id  listing_price  calendar_price          diff
# 36566            38452677          100.0    28365.699219  28265.699219
# 55781  658361293784718707        27579.0      927.945190  26651.054688
# 47053            51839279        24000.0     5659.394531  18340.605469
# 41968            44696103         8583.0      710.909607   7872.090332
# 30675            31622680         7580.0      571.575317   7008.424805
# 41988            44734906         7206.0      649.731506   6556.268555
# 79283  894034192184656301         2789.0     9046.575195   6257.575195
# 30684            31634469         6067.0      295.032867   5771.967285
# 450                450460         5565.0      390.517822   5174.482422
# 11042            13050998         6073.0      943.208191   5129.791992
# 41990            44735899         5944.0      924.695862   5019.304199
# 41290            43883561         5017.0      359.000000   4658.000000
# 18119            19421692         6557.0     1966.865723   4590.134277
# 50280  546975263383722688         3949.0      165.424652   3783.575439
# 41981            44725409         4006.0      250.000000   3756.000000
# 54583  642298668518738732         4549.0      839.937012   3709.062988
# 41289            43883551         3931.0      279.000000   3652.000000
# 45663            50413819         3827.0      318.000000   3509.000000
# 41294            43884357         3721.0      242.000000   3479.000000
# 71516  838229684515886467          180.0     3588.082275   3408.082275
# 60725  720210451696591212         3975.0      756.682190   3218.317871
# 45662            50413593         3227.0      245.000000   2982.000000
# 41291            43883562         3176.0      270.000000   2906.000000
# 75798  871585627545618807          241.0      987.969849    746.969849
# 76521  876756955491956620          242.0      988.345215    746.345215
# 73941  857836084794965448          666.0     1402.676758    736.676758
# 79309  894136689821415281          334.0     1070.260254    736.260254
# 62144  739681061214498085          237.0      969.389038    732.389038
# 67495  801451811645121204          238.0      969.895874    731.895874
# 61286  728826169175635995         2324.0     1594.520508    729.479492
# 61290  728827789598787326         2324.0     1594.520508    729.479492
# 28399            28856823          275.0     1004.397278    729.397278
# 54572  642063432178207862          272.0     1000.000000    728.000000
# 25835            25991368          350.0     1075.915039    725.915039
# 52935  615671607173232062         1712.0     2436.172607    724.172607
# 41314            43914720          338.0     1060.567139    722.567139
# 72415  846291312917673559          150.0      871.917786    721.917786
# 21070            21521806          637.0     1354.901367    717.901367
# 33385            34964677          632.0     1349.852051    717.852051
# 6570              8018895          269.0      983.813721    714.813721
# 59748  706965316479101591          276.0      990.567139    714.567139
# 47478            52271987          269.0      981.112305    712.112305
# 31640            32842178          730.0     1440.172607    710.172607
# 29843            30496994          267.0      976.915039    709.915039
# 70448  828092083787995455          267.0      976.915039    709.915039
# 21297            21638212         1031.0      324.852051    706.147949
# 33426            35017851          652.0     1357.441040    705.441040
# 56064  660977779245998518          108.0      812.400024    704.400024
# 71737  840539797689039998          386.0     1087.378052    701.378052
# 67479  801335956247862242          227.0      928.062988    701.062988
# 37028            39019858         1626.0      925.627380    700.372620
# 66364  786185166083946537          362.0     1061.728760    699.728760
# 77602  883900904227474658          351.0     1049.542480    698.542480
# 49453            53803174         2709.0     2012.498657    696.501343
# 9292             11044045          263.0      958.252075    695.252075
# 73854  857133894338067400          792.0     1485.597290    693.597290
# 76508  876706601517822854          632.0     1325.424683    693.424683
# 46328            51159672         1494.0      800.698608    693.301392
# 30435            31318778          110.0      802.087646    692.087646
# 56866  671387864731837463          385.0     1076.465698    691.465698
# 40354            42555072          260.0      949.304138    689.304138
# 73336  853438073992049149           81.0      767.931519    686.931519
# 70522  828860054996920211          273.0      959.443848    686.443848
# 24766            24712566         1471.0      788.424683    682.575317
# 72636  847700736232131548          756.0     1437.635620    681.635620

# %%
# records where listing price is mean calendar price, as expected
calendar_grouped.tail(10)
# Out:
#                listing_id  listing_price  calendar_price  diff
# 33081            34604619          330.0           330.0   0.0
# 33082            34605872          100.0           100.0   0.0
# 33083            34608588          185.0           185.0   0.0
# 33088            34618194          170.0           170.0   0.0
# 33093            34622090          776.0           776.0   0.0
# 33094            34622125          916.0           916.0   0.0
# 33095            34622145          846.0           846.0   0.0
# 33097            34622998          120.0           120.0   0.0
# 33100            34624383          180.0           180.0   0.0
# 81789  909281506879757665          135.0           135.0   0.0

# %%
listing[listing.id == 658361293784718707]
# Out:
#                        id                                      listing_url  \
# 55761  658361293784718707  https://www.airbnb.com/rooms/658361293784718707
#
#             scrape_id last_scraped       source  \
# 55761  20230608145305   2023-06-09  city scrape
#
#                                                     name  \
# 55761  Home in Greater London · 2 bedrooms · 4 beds ·...
#
#                                              description  \
# 55761  This unique place has a style all of its own.<...
#
#       neighborhood_overview  \
# 55761                   NaN
#
#                                              picture_url    host_id  \
# 55761  https://a0.muscache.com/pictures/26784fb9-b85b...  149053970
#
#                                           host_url host_name  host_since  \
# 55761  https://www.airbnb.com/users/show/149053970     Julie  2017-09-04
#
#                 host_location     host_about  host_response_time  \
# 55761  London, United Kingdom  Professional   within a few hours
#
#       host_response_rate host_acceptance_rate host_is_superhost  \
# 55761               100%                  84%               NaN
#
#                                       host_thumbnail_url  \
# 55761  https://a0.muscache.com/im/pictures/user/e95fd...
#
#                                         host_picture_url host_neighbourhood  \
# 55761  https://a0.muscache.com/im/pictures/user/e95fd...    LB of Redbridge
#
#        host_listings_count  host_total_listings_count  host_verifications  \
# 55761                 13.0                       16.0  ['email', 'phone']
#
#       host_has_profile_pic host_identity_verified neighbourhood  \
# 55761                    t                      t           NaN
#
#       neighbourhood_cleansed  neighbourhood_group_cleansed  latitude  \
# 55761              Redbridge                           NaN  51.57684
#
#        longitude         property_type     room_type  accommodates  bathrooms  \
# 55761    0.12416  Private room in home  Private room             7        NaN
#
#          bathrooms_text  bedrooms  beds  \
# 55761  1.5 shared baths       2.0   4.0
#
#                                                amenities       price  \
# 55761  ["Freezer", "Oven", "Hot water", "Washer", "Ex...  $27,579.00
#
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# 55761               1             365                     1.0
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 55761                     1.0                   365.0                   365.0
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 55761                     1.0                   365.0               NaN
#
#       has_availability  availability_30  availability_60  availability_90  \
# 55761                t                1                2                2
#
#        availability_365 calendar_last_scraped  number_of_reviews  \
# 55761               224            2023-06-09                  0
#
#        number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 55761                      0                       0          NaN         NaN
#
#        review_scores_rating  review_scores_accuracy  \
# 55761                   NaN                     NaN
#
#        review_scores_cleanliness  review_scores_checkin  \
# 55761                        NaN                    NaN
#
#        review_scores_communication  review_scores_location  \
# 55761                          NaN                     NaN
#
#        review_scores_value  license instant_bookable  \
# 55761                  NaN      NaN                f
#
#        calculated_host_listings_count  \
# 55761                               3
#
#        calculated_host_listings_count_entire_homes  \
# 55761                                            0
#
#        calculated_host_listings_count_private_rooms  \
# 55761                                             3
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 55761                                            0                NaN

# %% [markdown]
# >**Observation**: There are listings in the calendar dataset where prices increase significantly from one day to the next, distorting the average daily base price in the listings dataset

# %% [markdown]
# #### Understand the difference between host_listings_count, host_total_listings_count and calculated_host_listings_count

# %%
listing.loc[listing['calculated_host_listings_count'] > 5, ['id', 'host_id', 'host_listings_count', 'host_total_listings_count', 'calculated_host_listings_count']][:5]
# Out:
#         id  host_id  host_listings_count  host_total_listings_count  \
# 7   306677  1577254                  8.0                       14.0
# 8    17402    67564                 10.0                       32.0
# 18  308005    67564                 10.0                       32.0
# 57  203163   460272                  9.0                       12.0
# 76   47687   216660                 12.0                       12.0
#
#     calculated_host_listings_count
# 7                                6
# 8                                9
# 18                               9
# 57                               9
# 76                              12

# %%
listing[listing.host_id == 1577254]
# Out:
#              id                            listing_url       scrape_id  \
# 7        306677    https://www.airbnb.com/rooms/306677  20230608145305
# 1628    1538921   https://www.airbnb.com/rooms/1538921  20230608145305
# 2147    2635019   https://www.airbnb.com/rooms/2635019  20230608145305
# 14186  15900139  https://www.airbnb.com/rooms/15900139  20230608145305
# 14190  15900290  https://www.airbnb.com/rooms/15900290  20230608145305
# 15356  17040000  https://www.airbnb.com/rooms/17040000  20230608145305
#
#       last_scraped           source  \
# 7       2023-06-10  previous scrape
# 1628    2023-06-10  previous scrape
# 2147    2023-06-10  previous scrape
# 14186   2023-06-10  previous scrape
# 14190   2023-06-10  previous scrape
# 15356   2023-06-10  previous scrape
#
#                                                     name  \
# 7      Rental unit in London · ★4.56 · 2 bedrooms · 3...
# 1628   Rental unit in London · ★4.52 · 2 bedrooms · 3...
# 2147   Rental unit in London · ★4.42 · 2 bedrooms · 2...
# 14186  Rental unit in London · ★4.43 · 2 bedrooms · 3...
# 14190  Rental unit in London · ★4.52 · 2 bedrooms · 3...
# 15356  Rental unit in London · ★4.58 · 2 bedrooms · 3...
#
#                                              description  \
# 7      Non smoking apartment worth uk£600k (US$900k) ...
# 1628   Non smoking apartment worth uk£600k (US$900k) ...
# 2147   non smoking apartment worth UK £570k (US$860k)...
# 14186  non smoking apartment worth UK £570k (US$860k)...
# 14190  non smoking apartment worth UK £570k (US$860k)...
# 15356  Non smoking apartment worth uk£600k (US$900k) ...
#
#                                    neighborhood_overview  \
# 7      Fantastic location to access all tourist attra...
# 1628   Fantastic location to access all tourist attra...
# 2147   I love the fact that you are a short undergrou...
# 14186  I love the fact that you are a short undergrou...
# 14190  I love the fact that you are a short undergrou...
# 15356  Fantastic location to access all tourist attra...
#
#                                              picture_url  host_id  \
# 7      https://a0.muscache.com/pictures/3419083/e5533...  1577254
# 1628   https://a0.muscache.com/pictures/22533617/d371...  1577254
# 2147   https://a0.muscache.com/pictures/50829555/17ae...  1577254
# 14186  https://a0.muscache.com/pictures/480698b6-4014...  1577254
# 14190  https://a0.muscache.com/pictures/7175600e-68ee...  1577254
# 15356  https://a0.muscache.com/pictures/c84fab00-7c0e...  1577254
#
#                                         host_url host_name  host_since  \
# 7      https://www.airbnb.com/users/show/1577254        Pm  2012-01-07
# 1628   https://www.airbnb.com/users/show/1577254        Pm  2012-01-07
# 2147   https://www.airbnb.com/users/show/1577254        Pm  2012-01-07
# 14186  https://www.airbnb.com/users/show/1577254        Pm  2012-01-07
# 14190  https://www.airbnb.com/users/show/1577254        Pm  2012-01-07
# 15356  https://www.airbnb.com/users/show/1577254        Pm  2012-01-07
#
#                 host_location                      host_about  \
# 7      London, United Kingdom  Live life travel see the world
# 1628   London, United Kingdom  Live life travel see the world
# 2147   London, United Kingdom  Live life travel see the world
# 14186  London, United Kingdom  Live life travel see the world
# 14190  London, United Kingdom  Live life travel see the world
# 15356  London, United Kingdom  Live life travel see the world
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 7                    NaN                NaN                  NaN
# 1628                 NaN                NaN                  NaN
# 2147                 NaN                NaN                  NaN
# 14186                NaN                NaN                  NaN
# 14190                NaN                NaN                  NaN
# 15356                NaN                NaN                  NaN
#
#       host_is_superhost                                 host_thumbnail_url  \
# 7                     f  https://a0.muscache.com/im/pictures/user/74e33...
# 1628                  f  https://a0.muscache.com/im/pictures/user/74e33...
# 2147                  f  https://a0.muscache.com/im/pictures/user/74e33...
# 14186                 f  https://a0.muscache.com/im/pictures/user/74e33...
# 14190                 f  https://a0.muscache.com/im/pictures/user/74e33...
# 15356                 f  https://a0.muscache.com/im/pictures/user/74e33...
#
#                                         host_picture_url host_neighbourhood  \
# 7      https://a0.muscache.com/im/pictures/user/74e33...          Southwark
# 1628   https://a0.muscache.com/im/pictures/user/74e33...          Southwark
# 2147   https://a0.muscache.com/im/pictures/user/74e33...          Southwark
# 14186  https://a0.muscache.com/im/pictures/user/74e33...          Southwark
# 14190  https://a0.muscache.com/im/pictures/user/74e33...          Southwark
# 15356  https://a0.muscache.com/im/pictures/user/74e33...          Southwark
#
#        host_listings_count  host_total_listings_count  host_verifications  \
# 7                      8.0                       14.0  ['email', 'phone']
# 1628                   8.0                       14.0  ['email', 'phone']
# 2147                   8.0                       14.0  ['email', 'phone']
# 14186                  8.0                       14.0  ['email', 'phone']
# 14190                  8.0                       14.0  ['email', 'phone']
# 15356                  8.0                       14.0  ['email', 'phone']
#
#       host_has_profile_pic host_identity_verified  \
# 7                        t                      t
# 1628                     t                      t
# 2147                     t                      t
# 14186                    t                      t
# 14190                    t                      t
# 15356                    t                      t
#
#                          neighbourhood neighbourhood_cleansed  \
# 7               London, United Kingdom              Southwark
# 1628            London, United Kingdom              Southwark
# 2147            London, United Kingdom              Southwark
# 14186  London, England, United Kingdom              Southwark
# 14190  London, England, United Kingdom              Southwark
# 15356  London, England, United Kingdom              Southwark
#
#        neighbourhood_group_cleansed  latitude  longitude       property_type  \
# 7                               NaN  51.49739   -0.10146  Entire rental unit
# 1628                            NaN  51.49696   -0.10108  Entire rental unit
# 2147                            NaN  51.49723   -0.10090  Entire rental unit
# 14186                           NaN  51.49424   -0.09782  Entire rental unit
# 14190                           NaN  51.49467   -0.09910  Entire rental unit
# 15356                           NaN  51.49466   -0.09853  Entire rental unit
#
#              room_type  accommodates  bathrooms bathrooms_text  bedrooms  \
# 7      Entire home/apt             5        NaN         1 bath       2.0
# 1628   Entire home/apt             5        NaN         1 bath       2.0
# 2147   Entire home/apt             5        NaN         1 bath       2.0
# 14186  Entire home/apt             5        NaN         1 bath       2.0
# 14190  Entire home/apt             5        NaN         1 bath       2.0
# 15356  Entire home/apt             5        NaN         1 bath       2.0
#
#        beds                                          amenities    price  \
# 7       3.0  ["TV", "Elevator", "Wifi", "Hot water", "Iron"...  $132.00
# 1628    3.0  ["TV", "Elevator", "Wifi", "Hot water", "Bed l...  $127.00
# 2147    2.0  ["TV", "Elevator", "Wifi", "Hot water", "Iron"...  $139.00
# 14186   3.0  ["TV", "Elevator", "Wifi", "Hot water", "Iron"...  $112.00
# 14190   3.0  ["TV", "Elevator", "Wifi", "Hot water", "Iron"...  $108.00
# 15356   3.0  ["TV", "Elevator", "Wifi", "Hot water", "Iron"...  $112.00
#
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# 7                   5              90                     5.0
# 1628                5            1124                     5.0
# 2147                5            1125                     5.0
# 14186               5            1123                     5.0
# 14190               5            1124                     5.0
# 15356               5            1123                     5.0
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 7                         5.0                  1125.0                  1125.0
# 1628                      5.0                  1124.0                  1124.0
# 2147                      5.0                  1125.0                  1125.0
# 14186                     5.0                  1123.0                  1123.0
# 14190                     5.0                  1124.0                  1124.0
# 15356                     5.0                  1123.0                  1123.0
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 7                         5.0                  1125.0               NaN
# 1628                      5.0                  1124.0               NaN
# 2147                      5.0                  1125.0               NaN
# 14186                     5.0                  1123.0               NaN
# 14190                     5.0                  1124.0               NaN
# 15356                     5.0                  1123.0               NaN
#
#       has_availability  availability_30  availability_60  availability_90  \
# 7                    t                0                0                0
# 1628                 t                0                0                0
# 2147                 t                0                0                0
# 14186                t                0                0                0
# 14190                t                0                0                0
# 15356                t                0                0                0
#
#        availability_365 calendar_last_scraped  number_of_reviews  \
# 7                     0            2023-06-10                218
# 1628                  0            2023-06-10                 52
# 2147                  0            2023-06-10                119
# 14186                 0            2023-06-10                 28
# 14190                 0            2023-06-10                 31
# 15356                 0            2023-06-10                 24
#
#        number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 7                          0                       0   2012-02-06  2020-02-29
# 1628                       0                       0   2013-12-25  2019-08-18
# 2147                       0                       0   2014-08-28  2020-01-02
# 14186                      0                       0   2017-01-22  2019-07-03
# 14190                      0                       0   2017-07-18  2019-12-28
# 15356                      0                       0   2017-02-18  2019-12-13
#
#        review_scores_rating  review_scores_accuracy  \
# 7                      4.56                    4.72
# 1628                   4.52                    4.73
# 2147                   4.42                    4.62
# 14186                  4.43                    4.75
# 14190                  4.52                    4.65
# 15356                  4.58                    4.67
#
#        review_scores_cleanliness  review_scores_checkin  \
# 7                           4.64                   4.72
# 1628                        4.63                   4.64
# 2147                        4.47                   4.60
# 14186                       4.71                   4.30
# 14190                       4.71                   4.68
# 15356                       4.33                   4.83
#
#        review_scores_communication  review_scores_location  \
# 7                             4.78                    4.41
# 1628                          4.76                    4.58
# 2147                          4.74                    4.34
# 14186                         4.86                    4.74
# 14190                         4.94                    4.60
# 15356                         4.88                    4.50
#
#        review_scores_value  license instant_bookable  \
# 7                     4.55      NaN                t
# 1628                  4.59      NaN                t
# 2147                  4.44      NaN                t
# 14186                 4.44      NaN                t
# 14190                 4.66      NaN                t
# 15356                 4.71      NaN                t
#
#        calculated_host_listings_count  \
# 7                                   6
# 1628                                6
# 2147                                6
# 14186                               6
# 14190                               6
# 15356                               6
#
#        calculated_host_listings_count_entire_homes  \
# 7                                                6
# 1628                                             6
# 2147                                             6
# 14186                                            6
# 14190                                            6
# 15356                                            6
#
#        calculated_host_listings_count_private_rooms  \
# 7                                                 0
# 1628                                              0
# 2147                                              0
# 14186                                             0
# 14190                                             0
# 15356                                             0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 7                                                0               1.58
# 1628                                             0               0.45
# 2147                                             0               1.11
# 14186                                            0               0.36
# 14190                                            0               0.43
# 15356                                            0               0.31

# %% [markdown]
# >**Observation**:
#
#     - `calculated_host_listings_count are the number of times the 'host_id' appear in the dataset and seems reliable
#     - `host_listings_count` and `host_total_listings_count` are much higher, it's unclear what is the meaning and should be dropped
#     - 'host' characteristics are repeated for each listing, these fields could be extracted into a seperated host dataset

# %% [markdown]
# #### Display summary statistics

# %%
listing.describe([0.25, 0.5, 0.75, 0.9, 0.999]).T
# Out:
#                                                 count          mean  \
# id                                            81791.0  2.974091e+17
# scrape_id                                     81791.0  2.023061e+13
# host_id                                       81791.0  1.491610e+08
# host_listings_count                           81786.0  4.318001e+01
# host_total_listings_count                     81786.0  7.708025e+01
# neighbourhood_group_cleansed                      0.0           NaN
# latitude                                      81791.0  5.150964e+01
# longitude                                     81791.0 -1.280938e-01
# accommodates                                  81791.0  3.138793e+00
# bathrooms                                         0.0           NaN
# bedrooms                                      50991.0  1.780040e+00
# beds                                          80646.0  1.792153e+00
# minimum_nights                                81791.0  5.649790e+00
# maximum_nights                                81791.0  7.780196e+02
# minimum_minimum_nights                        81790.0  5.291038e+00
# maximum_minimum_nights                        81790.0  9.268884e+00
# minimum_maximum_nights                        81790.0  2.109402e+05
# maximum_maximum_nights                        81790.0  5.260312e+05
# minimum_nights_avg_ntm                        81790.0  7.955558e+00
# maximum_nights_avg_ntm                        81790.0  5.228174e+05
# calendar_updated                                  0.0           NaN
# availability_30                               81791.0  6.412882e+00
# availability_60                               81791.0  1.620124e+01
# availability_90                               81791.0  2.824391e+01
# availability_365                              81791.0  1.193007e+02
# number_of_reviews                             81791.0  1.794194e+01
# number_of_reviews_ltm                         81791.0  5.907447e+00
# number_of_reviews_l30d                        81791.0  6.214987e-01
# review_scores_rating                          61189.0  4.591683e+00
# review_scores_accuracy                        60252.0  4.715681e+00
# review_scores_cleanliness                     60264.0  4.622722e+00
# review_scores_checkin                         60222.0  4.779497e+00
# review_scores_communication                   60249.0  4.797183e+00
# review_scores_location                        60222.0  4.725277e+00
# review_scores_value                           60220.0  4.598984e+00
# license                                           0.0           NaN
# calculated_host_listings_count                81791.0  1.684573e+01
# calculated_host_listings_count_entire_homes   81791.0  1.271453e+01
# calculated_host_listings_count_private_rooms  81791.0  3.945911e+00
# calculated_host_listings_count_shared_rooms   81791.0  5.066572e-02
# reviews_per_month                             61189.0  9.706276e-01
#
#                                                        std           min  \
# id                                            3.792207e+17  1.391300e+04
# scrape_id                                     0.000000e+00  2.023061e+13
# host_id                                       1.611307e+08  2.594000e+03
# host_listings_count                           2.610847e+02  1.000000e+00
# host_total_listings_count                     4.719514e+02  1.000000e+00
# neighbourhood_group_cleansed                           NaN           NaN
# latitude                                      4.854172e-02  5.129594e+01
# longitude                                     9.924022e-02 -4.978000e-01
# accommodates                                  1.957191e+00  0.000000e+00
# bathrooms                                              NaN           NaN
# bedrooms                                      1.026755e+00  1.000000e+00
# beds                                          1.237519e+00  1.000000e+00
# minimum_nights                                2.300302e+01  1.000000e+00
# maximum_nights                                4.704150e+04  1.000000e+00
# minimum_minimum_nights                        2.248618e+01  1.000000e+00
# maximum_minimum_nights                        3.438096e+01  1.000000e+00
# minimum_maximum_nights                        2.123768e+07  1.000000e+00
# maximum_maximum_nights                        3.357721e+07  1.000000e+00
# minimum_nights_avg_ntm                        3.136309e+01  1.000000e+00
# maximum_nights_avg_ntm                        3.337276e+07  1.000000e+00
# calendar_updated                                       NaN           NaN
# availability_30                               9.319544e+00  0.000000e+00
# availability_60                               1.999355e+01  0.000000e+00
# availability_90                               3.162324e+01  0.000000e+00
# availability_365                              1.338657e+02  0.000000e+00
# number_of_reviews                             4.224343e+01  0.000000e+00
# number_of_reviews_ltm                         1.296664e+01  0.000000e+00
# number_of_reviews_l30d                        1.405326e+00  0.000000e+00
# review_scores_rating                          7.606644e-01  0.000000e+00
# review_scores_accuracy                        4.958804e-01  0.000000e+00
# review_scores_cleanliness                     5.494896e-01  0.000000e+00
# review_scores_checkin                         4.524858e-01  0.000000e+00
# review_scores_communication                   4.528932e-01  0.000000e+00
# review_scores_location                        4.180774e-01  0.000000e+00
# review_scores_value                           5.284382e-01  0.000000e+00
# license                                                NaN           NaN
# calculated_host_listings_count                5.864581e+01  1.000000e+00
# calculated_host_listings_count_entire_homes   4.261216e+01  0.000000e+00
# calculated_host_listings_count_private_rooms  2.407001e+01  0.000000e+00
# calculated_host_listings_count_shared_rooms   7.094979e-01  0.000000e+00
# reviews_per_month                             1.331133e+00  1.000000e-02
#
#                                                        25%           50%  \
# id                                            2.105345e+07  4.312004e+07
# scrape_id                                     2.023061e+13  2.023061e+13
# host_id                                       2.102925e+07  7.416739e+07
# host_listings_count                           1.000000e+00  2.000000e+00
# host_total_listings_count                     1.000000e+00  3.000000e+00
# neighbourhood_group_cleansed                           NaN           NaN
# latitude                                      5.148360e+01  5.151384e+01
# longitude                                    -1.891659e-01 -1.265700e-01
# accommodates                                  2.000000e+00  2.000000e+00
# bathrooms                                              NaN           NaN
# bedrooms                                      1.000000e+00  2.000000e+00
# beds                                          1.000000e+00  1.000000e+00
# minimum_nights                                1.000000e+00  2.000000e+00
# maximum_nights                                5.000000e+01  3.650000e+02
# minimum_minimum_nights                        1.000000e+00  2.000000e+00
# maximum_minimum_nights                        2.000000e+00  3.000000e+00
# minimum_maximum_nights                        9.000000e+01  9.990000e+02
# maximum_maximum_nights                        1.200000e+02  1.125000e+03
# minimum_nights_avg_ntm                        1.300000e+00  2.800000e+00
# maximum_nights_avg_ntm                        1.185500e+02  1.102950e+03
# calendar_updated                                       NaN           NaN
# availability_30                               0.000000e+00  1.000000e+00
# availability_60                               0.000000e+00  6.000000e+00
# availability_90                               0.000000e+00  1.400000e+01
# availability_365                              0.000000e+00  5.900000e+01
# number_of_reviews                             0.000000e+00  4.000000e+00
# number_of_reviews_ltm                         0.000000e+00  1.000000e+00
# number_of_reviews_l30d                        0.000000e+00  0.000000e+00
# review_scores_rating                          4.500000e+00  4.820000e+00
# review_scores_accuracy                        4.660000e+00  4.880000e+00
# review_scores_cleanliness                     4.500000e+00  4.800000e+00
# review_scores_checkin                         4.750000e+00  4.940000e+00
# review_scores_communication                   4.790000e+00  4.970000e+00
# review_scores_location                        4.630000e+00  4.850000e+00
# review_scores_value                           4.500000e+00  4.740000e+00
# license                                                NaN           NaN
# calculated_host_listings_count                1.000000e+00  1.000000e+00
# calculated_host_listings_count_entire_homes   0.000000e+00  1.000000e+00
# calculated_host_listings_count_private_rooms  0.000000e+00  0.000000e+00
# calculated_host_listings_count_shared_rooms   0.000000e+00  0.000000e+00
# reviews_per_month                             1.400000e-01  5.000000e-01
#
#                                                        75%           90%  \
# id                                            7.293143e+17  8.556881e+17
# scrape_id                                     2.023061e+13  2.023061e+13
# host_id                                       2.470515e+08  4.473470e+08
# host_listings_count                           6.000000e+00  3.700000e+01
# host_total_listings_count                     1.000000e+01  5.700000e+01
# neighbourhood_group_cleansed                           NaN           NaN
# latitude                                      5.153947e+01  5.156556e+01
# longitude                                    -6.839000e-02 -1.339000e-02
# accommodates                                  4.000000e+00  6.000000e+00
# bathrooms                                              NaN           NaN
# bedrooms                                      2.000000e+00  3.000000e+00
# beds                                          2.000000e+00  3.000000e+00
# minimum_nights                                4.000000e+00  7.000000e+00
# maximum_nights                                1.125000e+03  1.125000e+03
# minimum_minimum_nights                        4.000000e+00  7.000000e+00
# maximum_minimum_nights                        5.000000e+00  1.400000e+01
# minimum_maximum_nights                        1.125000e+03  1.125000e+03
# maximum_maximum_nights                        1.125000e+03  1.125000e+03
# minimum_nights_avg_ntm                        5.000000e+00  1.000000e+01
# maximum_nights_avg_ntm                        1.125000e+03  1.125000e+03
# calendar_updated                                       NaN           NaN
# availability_30                               1.000000e+01  2.400000e+01
# availability_60                               3.000000e+01  5.200000e+01
# availability_90                               5.500000e+01  8.100000e+01
# availability_365                              2.450000e+02  3.420000e+02
# number_of_reviews                             1.600000e+01  4.600000e+01
# number_of_reviews_ltm                         6.000000e+00  1.700000e+01
# number_of_reviews_l30d                        1.000000e+00  2.000000e+00
# review_scores_rating                          5.000000e+00  5.000000e+00
# review_scores_accuracy                        5.000000e+00  5.000000e+00
# review_scores_cleanliness                     5.000000e+00  5.000000e+00
# review_scores_checkin                         5.000000e+00  5.000000e+00
# review_scores_communication                   5.000000e+00  5.000000e+00
# review_scores_location                        5.000000e+00  5.000000e+00
# review_scores_value                           4.960000e+00  5.000000e+00
# license                                                NaN           NaN
# calculated_host_listings_count                5.000000e+00  3.100000e+01
# calculated_host_listings_count_entire_homes   3.000000e+00  2.300000e+01
# calculated_host_listings_count_private_rooms  1.000000e+00  4.000000e+00
# calculated_host_listings_count_shared_rooms   0.000000e+00  0.000000e+00
# reviews_per_month                             1.230000e+00  2.510000e+00
#
#                                                      99.9%           max
# id                                            9.084665e+17  9.092815e+17
# scrape_id                                     2.023061e+13  2.023061e+13
# host_id                                       5.177139e+08  5.187276e+08
# host_listings_count                           2.747000e+03  2.747000e+03
# host_total_listings_count                     4.724000e+03  5.225000e+03
# neighbourhood_group_cleansed                           NaN           NaN
# latitude                                      5.166000e+01  5.168150e+01
# longitude                                     2.153121e-01  2.885700e-01
# accommodates                                  1.600000e+01  1.600000e+01
# bathrooms                                              NaN           NaN
# bedrooms                                      7.000000e+00  5.000000e+01
# beds                                          1.000000e+01  3.800000e+01
# minimum_nights                                3.650000e+02  1.125000e+03
# maximum_nights                                1.125000e+03  1.000000e+07
# minimum_minimum_nights                        3.650000e+02  1.125000e+03
# maximum_minimum_nights                        3.660000e+02  1.125000e+03
# minimum_maximum_nights                        1.125000e+03  2.147484e+09
# maximum_maximum_nights                        1.125000e+03  2.147484e+09
# minimum_nights_avg_ntm                        3.650000e+02  1.125000e+03
# maximum_nights_avg_ntm                        1.125000e+03  2.147484e+09
# calendar_updated                                       NaN           NaN
# availability_30                               3.000000e+01  3.000000e+01
# availability_60                               6.000000e+01  6.000000e+01
# availability_90                               9.000000e+01  9.000000e+01
# availability_365                              3.650000e+02  3.650000e+02
# number_of_reviews                             4.430000e+02  1.425000e+03
# number_of_reviews_ltm                         1.052100e+02  5.310000e+02
# number_of_reviews_l30d                        1.100000e+01  3.600000e+01
# review_scores_rating                          5.000000e+00  5.000000e+00
# review_scores_accuracy                        5.000000e+00  5.000000e+00
# review_scores_cleanliness                     5.000000e+00  5.000000e+00
# review_scores_checkin                         5.000000e+00  5.000000e+00
# review_scores_communication                   5.000000e+00  5.000000e+00
# review_scores_location                        5.000000e+00  5.000000e+00
# review_scores_value                           5.000000e+00  5.000000e+00
# license                                                NaN           NaN
# calculated_host_listings_count                5.430000e+02  5.430000e+02
# calculated_host_listings_count_entire_homes   2.910000e+02  2.910000e+02
# calculated_host_listings_count_private_rooms  2.790000e+02  2.790000e+02
# calculated_host_listings_count_shared_rooms   1.400000e+01  1.400000e+01
# reviews_per_month                             9.990600e+00  5.050000e+01

# %% [markdown]
# >**Observations:**
# >- Maximum number of nights have some crazy maximum values

# %% [markdown]
# ### 2.3 Assessing `review` dataset

# %%
# visual inspection of reviews
review.sample(5)
# Out:
#                  listing_id                  id        date  reviewer_id  \
# 371217             10589925           151302673  2017-05-12     10311910
# 1408937  741908970895517031  815074527401147138  2023-01-29      6079991
# 232015              5211045            58303948  2016-01-02     14606176
# 1218272            51631153  449034769205760485  2021-09-11     69775563
# 799774             24578158           461275844  2019-05-31     52243037
#
#         reviewer_name                                           comments
# 371217         Stefan  Wir konnten per Self-Service hinein und das Ha...
# 1408937          Nate  Notting Hill is an incredible neighborhood to ...
# 232015         Álvaro  Me and my family had a great time in Kostas' h...
# 1218272        Joelle  We enjoyed our stay in this comfy and well dec...
# 799774      Gjylijete  Ein super freundlicher Typ der Mario 😊 Die näc...

# %%
# does all listings have reviews ?
review.nunique()
# Out:
# listing_id         61190
# id               1467496
# date                4541
# reviewer_id      1241267
# reviewer_name     147325
# comments         1409481
# dtype: int64

# %%
# what is the maximum reviews per listing?
review.groupby('listing_id')['id'].count().sort_values(ascending=False)[:20]
# Out:
# listing_id
# 30760930    1425
# 19670926    1302
# 47408549    1202
# 43120947    1076
# 1436172     1004
# 2126708      896
# 1436177      844
# 3855375      817
# 45006692     811
# 21438138     808
# 42081759     782
# 2659707      774
# 46233904     771
# 14518189     743
# 5266466      742
# 4748665      733
# 9046849      711
# 2025844      697
# 42081840     680
# 5869526      668
# Name: id, dtype: int64

# %% [markdown]
# **Observations**:
#
# - Not all properties have ratings
# - review dataset will not be used further for this project

# %% [markdown]
# <a id='summary_of_assessment'></a>
# ## Summary of assessment
#
# Below is a summary of cleaning activities for dataset `listing` and `calendar`.  Only features of interest to answer above business questions will be cleaned. All other datasets and features not needed will be dropped or ignored.
#
# ### Quality issues
# Do we have all the records that we should? Do we have missing records or not? Are there specific rows, columns, or cells missing?
#
# <blockquote>
#
# #### [Completeness Issues (e.g. missing data)](#completeness)
#
#
# 1. `bathroom` feature have all values missing, whilst the number of bathrooms are present in a text field `bathrooms_text`
# 1. `bedrooms` have 40% missing values, whilst the number of bedrooms are sometimes present in the `name` feature
# 1. `bedrooms` is missing if it is a studio, as studios normally have no bedrooms it's an open plan space
# 1. Some columns have all values missing
# 1. There are rows with over 30% missing values caused by missing review and/or host data
# 1. There are listings in the dataset that seems inactive (not rented out anymore), causing a lot of missing values in rows
# 1. columns `host_about` and `neighborhood_overview` contains long free text descriptions and have missing values exceeding 40%
#
#
# #### [Validity Issues (incorrect entries, data types)](#validity)
#
# 8. `host_since` is a date with type string
# 1. boolean fields have values 'f' and 't' (host_is_superhost, instant_bookable, has_availability, host_has_profile_pic, host_verified, instant_bookable)
# 1. `host_response_rate` and `host_acceptance_rate` and `price` are numeric fields as type string with prefix '%' or '$' present
# 1. calendar: `date` field is a date not a string
# 1. calendar: `available` is a boolean field with values 'f' and 't'
# 1. convert float columns to integer (`host_total_listings_count`, `minimum_minimum_nights`, `minimum_maximum_nights`, `number_of_reviews`)
#
#
# #### [Consistency (e.g. same rules for data content full vs abbreviation) ](#consistency)
# 14. `id` column in the `listing` should be called `listing_id` to be consistent with `calendar` table
#
# #### [Accuracy (e.g. wrong data)](#accuracy)
#
# 15. There are listings in the calendar dataset where prices increase significantly from one day to the next, e.g. £100 one day, £24,000 the next
# 1. daily price in listings is not always the average mean price from the calendar dataset
# 1. `minimum_maximum_nights` have some crazy maximum values > 90 mil !
#
#
# </blockquote>
#
#
# ### [Tidiness issues](#tidiness)
#
# </blockquote>
#
# 18. `bathroom_text` contains multiple pieces of information: number of baths and weather it's shared vs private
# 1. Drop unneeded variables
#
#
# </blockquote>

# %% [markdown]
# <a id='clean'></a>
# <span style="color:blue; font-size:25px; line-height:30px; font-family: Calibri;">Step 2: Cleaning</span>

# %%
# Make a copy of the original data
calendar_clean = calendar.copy() 
listing_clean = listing.copy()

# %%
# clear the garbage to free memory
gc.collect()
# Out:
# 31747

# %% [markdown]
# <a id='completeness'></a>
# <span style="color:blue; font-size:20px; font-family: Calibri;">Completeness Issues</span>
#
# <span style="color:blue; font-size:16px; font-family: Calibri;"> Issue #1: **bathroom**  feature have all values missing, whilst the number of bathrooms are present in a text field **bathrooms_text**</span>

# %% [markdown]
# **Define:** Extract first number from `bathroom_text` column using regex extract() method and store the result in feature `bathroom` as a float data type

# %% [markdown]
# #### Code

# %%
# visual inspection before
listing_clean[['bathrooms', 'bathrooms_text']][:10]
# Out:
#    bathrooms bathrooms_text
# 0        NaN         1 bath
# 1        NaN      1.5 baths
# 2        NaN  1 shared bath
# 3        NaN         1 bath
# 4        NaN         1 bath
# 5        NaN  1 shared bath
# 6        NaN        0 baths
# 7        NaN         1 bath
# 8        NaN        2 baths
# 9        NaN         1 bath

# %%
# how many missing values does bathroom_text have ?
missing_entries = sum(listing_clean.bathrooms_text.isna())
print('bathrooms_text contain {} missing entries'.format(missing_entries))
# Out:
# bathrooms_text contain 102 missing entries

# %%
# convert bathroom text to lower case and replace text 'half-bath' with 0.5
listing_clean['bathrooms_text'] = listing_clean['bathrooms_text'].str.lower().str.replace('half-bath', '0.5')

# %%
# extract the numeric number of baths from the string
listing_clean['bathrooms'] = listing_clean['bathrooms_text'].str.extract(r"([-+]?\d*\.*\d+)")

# %%
pd.options.display.float_format = '{:,.1f}'.format
listing_clean['bathrooms'] = listing_clean['bathrooms'].astype('float')

# %% [markdown]
# #### Test

# %%
# visually inspection after
listing_clean[['bathrooms', 'bathrooms_text']][:10]
# Out:
#    bathrooms bathrooms_text
# 0        1.0         1 bath
# 1        1.5      1.5 baths
# 2        1.0  1 shared bath
# 3        1.0         1 bath
# 4        1.0         1 bath
# 5        1.0  1 shared bath
# 6        0.0        0 baths
# 7        1.0         1 bath
# 8        2.0        2 baths
# 9        1.0         1 bath

# %%
listing_clean.bathrooms_text.value_counts()[:5]
# Out:
# bathrooms_text
# 1 bath            36300
# 1 shared bath     12062
# 2 baths            9838
# 1 private bath     6690
# 1.5 baths          6236
# Name: count, dtype: int64

# %%
# number of entries with 1 bathroom matches the 3 records above containing 1 bathroom
listing_clean.bathrooms.value_counts()
# Out:
# bathrooms
# 1.0     55052
# 2.0     11076
# 1.5      9596
# 2.5      2774
# 3.0      1435
# 3.5       702
# 4.0       251
# 0.5       222
# 0.0       191
# 4.5       148
# 5.0       126
# 5.5        36
# 6.0        21
# 6.5        15
# 12.0        9
# 7.0         6
# 7.5         5
# 9.0         4
# 23.0        3
# 8.5         3
# 8.0         3
# 10.5        2
# 12.5        2
# 10.0        2
# 17.0        1
# 13.0        1
# 22.0        1
# 50.0        1
# 9.5         1
# Name: count, dtype: int64

# %%
# check that datatype is a float
assert listing_clean.bathrooms.dtype.name == 'float64'

# %%
# check that bathrooms now only a few missing values, same that is present in bathroom_text
assert sum(listing_clean.bathrooms.isna()) == missing_entries

# %% [markdown]
# <span style="color:blue; font-size:16px; font-family: Calibri;">Issue #2: **bedrooms** have 40% missing values, whilst the number of bedrooms are sometimes present in **name** feature**</span>

# %% [markdown]
# **Define**: Extract the float number infront of strings containing 'bedroom' using extract() method in the name and description feature. Fill missing values with extracted values

# %% [markdown]
# #### Code

# %%
# Number of missing values prior cleaning
sum(listing_clean['bedrooms'].isna())
# Out:
# 30800

# %%
# first, lets extract number of bathrooms from text if it is present
l = ["bedroom", "-bedroom"]

pat = f"(\d+)[\s-](?:{'|'.join(l)})"
listing_clean['extracted_bedrooms_name'] = listing_clean['name'].str.lower().str.extract(pat)

# %%
# first convert bedrooms to float
listing_clean['bedrooms'] = listing_clean['bedrooms'].astype(float)
listing_clean['bedrooms'] = listing_clean['extracted_bedrooms_name'].astype(float)
listing_clean['bedrooms'].fillna(listing_clean['extracted_bedrooms_name'], inplace=True)
# Out:
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/3129752190.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[nan nan nan ... nan nan nan]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   listing_clean['bedrooms'].fillna(listing_clean['extracted_bedrooms_name'], inplace=True)

# %% [markdown]
# #### Test:

# %%
# remaining missing values should be less
len(listing_clean[listing_clean.bedrooms.isna()])
# Out:
# 3463

# %%
# visually inspect if number of bedrooms was correctly extracted
listing_clean[listing_clean['extracted_bedrooms_name'] > '2'][['name', 'extracted_bedrooms_name', 'bedrooms']].sample(10)
# Out:
#                                                     name  \
# 1969   Home in London · ★4.89 · 4 bedrooms · 4 beds ·...
# 22302  Rental unit in Greater London · 3 bedrooms · 3...
# 64043  Rental unit in Greater London · 3 bedrooms · 3...
# 61113  Home in Greater London · 3 bedrooms · 5 beds ·...
# 13274  Rental unit in London · ★5.0 · 3 bedrooms · 3 ...
# 56315  Condo in Greater London · ★4.90 · 3 bedrooms ·...
# 71511  Home in Greater London · 4 bedrooms · 4 beds ·...
# 65044  Home in Greater London · ★4.92 · 3 bedrooms · ...
# 74672  Rental unit in Greater London · ★3.67 · 3 bedr...
# 56037  Home in Greater London · 4 bedrooms · 4 beds ·...
#
#       extracted_bedrooms_name  bedrooms
# 1969                        4       4.0
# 22302                       3       3.0
# 64043                       3       3.0
# 61113                       3       3.0
# 13274                       3       3.0
# 56315                       3       3.0
# 71511                       4       4.0
# 65044                       3       3.0
# 74672                       3       3.0
# 56037                       4       4.0

# %%
# check that datatype is a float
assert listing_clean.bedrooms.dtype.name == 'float64'

# %% [markdown]
# <span style="color:blue; font-size:16px; font-family: Calibri;">Issue #3: **bedrooms** is missing if it is a studio, as studios normally have no bedrooms it's an open plan space</span>

# %% [markdown]
# **Define**: set bedrooms = 0 if text 'studio' appear in `name` feature

# %% [markdown]
# #### Code:

# %%
# before we start, how many bedrooms have value = 0?
bedrooms_zero = sum(listing_clean['bedrooms'] == 0)
print('Records with 0 bedrooms: {}'.format(bedrooms_zero))
# Out:
# Records with 0 bedrooms: 0

# %%
sum(listing_clean['bedrooms'].isna())
# Out:
# 3463

# %%
# how many studio's do we have ?
len(listing_clean[listing_clean.name.str.lower().str.contains('studio')])
# Out:
# 3399

# %%
# extract the word studio from 'name' feature
listing_clean['studio_name'] = listing_clean['name'].str.extract('([Ss]tudio)')

# %%
# set bedrooms = 0 when it's a studio apartment
listing_clean['bedrooms'] = np.where(listing_clean['studio_name'].str.lower() == 'studio', 0, listing_clean['bedrooms'])

# %% [markdown]
# #### Test:

# %%
# how many records now have bedrooms == 0?
sum(listing_clean['bedrooms'] == 0)
# Out:
# 3399

# %%
# how many bedrooms are still missing ?
sum(listing_clean['bedrooms'].isna())
# Out:
# 64

# %%
# check that datatype is a float
assert listing_clean.bedrooms.dtype.name == 'float64'

# %%
# # Impute numerical fields with default strategy mean
# imputed_df = fit_imputer(df.copy(deep=True),
#                                  tolerance=0.0000001, 
#                                  verbose=2, 
#                                  max_iter=20, 
#                                  nearest_features=10,
#                                  imputation_order='descending',
#                                  initial_strategy='most_frequent')

# df_imputed = pd.DataFrame(imputed_df, columns=df.columns)
# df_imputed['bedrooms'] = df_imputed['bedrooms'].round(0).astype(np.int16, copy=False, errors='raise') 
# df_imputed.head()

# %% [markdown]
# <span style="color:blue; font-size:16px; font-family: Calibri;">Issue #4: Some columns have all values missing</span>

# %% [markdown]
# **Define:** Drop columns where all values are missing with pandas dropna()

# %% [markdown]
# #### Code

# %%
listing_clean.dropna(how='all', axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
# make sure we have no columns with all values missing
assert sum(listing_clean.columns[listing_clean.isnull().mean() == 1]) == 0

# %% [markdown]
# <span style="color:blue; font-size:16px; font-family: Calibri;">Issue #5: There are rows with over 30% missing values caused by missing review and/or host data</span>

# %% [markdown]
# **Define:** Drop rows with missing values exceeding 30%

# %% [markdown]
# #### Code

# %%
# number of records before we start
records_before = listing_clean.shape[0]
print('Number of records before row drop: {}'.format(records_before))
# Out:
# Number of records before row drop: 81791

# %%
# Drop all rows with more that 30% missing data
listing_clean = listing_clean.loc[listing_clean.isna().mean(axis=1) < 0.3, :]

# %% [markdown]
# #### Test

# %%
# how many records were dropped
print('Number of records after row drop: {}'.format(listing_clean.shape[0]))

assert listing_clean.shape[0] < records_before
# Out:
# Number of records after row drop: 81780

# %%
# plot to make sure all rows with missing values > 30% were dropped
assert len(listing_clean.loc[listing_clean.isna().mean(axis=1) > 0.3]) == 0

# %% [markdown]
# <span style="color:blue; font-size:16px; font-family: Calibri;">Issue #6: There are a lot of listings in the dataset that seems inactive (not rented out anymore), causing a lot of missing values in rows</span>

# %% [markdown]
# **Define**: Remove inactive listings from the dataset as the prices are old no longer reflect the current market.
#
# Rules:
# - Remove rentals that have no availability in the next year, yet has_availability is true
# - Host was active in the past, but not anymore (reviews exist but not any in the last year, great star ratings in the past)
# - Avoid removing long term rentals as they will indeed have no availability in the next year (minimum nights < 30 days)
# - Remove holiday rentals only, a sign of this is number of listings per host < 3 and minimum nights to rent is < 30 days

# %% [markdown]
# #### Code:

# %%
# make a note of number of listings before cleaning
listing_clean.shape
# Out:
# (81780, 74)

# %%
listing_clean['host_response_time'].value_counts(dropna=False)
# Out:
# host_response_time
# within an hour        34549
# NaN                   29029
# within a few hours    10241
# within a day           6255
# a few days or more     1706
# Name: count, dtype: int64

# %%
# get inactive listings
inactive_test = listing_clean[(listing_clean['has_availability'] == 't') & 
                                (listing_clean['availability_365'] == 0) & 
                                (listing_clean['number_of_reviews'] > 0) & 
                                (listing_clean['review_scores_rating'] > 4) &
                                (listing_clean['number_of_reviews_ltm'] == 0) &
                                (listing_clean['host_listings_count'] <= 3) &
                                (listing_clean['minimum_nights_avg_ntm'] <= 30)]

# %%
# drop inactive listings
listing_clean.drop(labels=inactive_test.index, axis=0, inplace=True)

# %% [markdown]
# #### Test

# %%
listing_clean.shape
# Out:
# (69578, 74)

# %%
listing_clean['host_response_time'].value_counts(dropna=False)
# Out:
# host_response_time
# within an hour        34259
# NaN                   17391
# within a few hours    10111
# within a day           6133
# a few days or more     1684
# Name: count, dtype: int64

# %% [markdown]
# <span style="color:blue; font-size:16px; font-family: Calibri;">Issue #7: columns **host_about** and **neighborhood_overview** contains long free text descriptions and have missing values > 40%</span>

# %% [markdown]
# **Define**: Convert `host_about` and `neighborhood_overview` into boolean fields to indicate if a description was present or not

# %% [markdown]
# #### Code:

# %%
# spot check column content before clean-up
listing_clean[['host_about', 'neighborhood_overview']][120:130]
# Out:
#                                             host_about  \
# 148  We are a family of four, who live in North Lon...
# 149  \nI  have just read some of my reviews and am ...
# 150  Adventurous,\nI am always on the go, I love to...
# 151  I love to travel and see new places and meet n...
# 152  Professional Londoner who regularly travels fo...
# 153  Hi my name is Karen and I am listing some love...
# 154  I am an outgoing, qualified teacher and I spea...
# 155                              I love lovehearts :)
# 156  We're kind and helpful hosts. I'm originally f...
# 157  You're renting my beautiful home where I have ...
#
#                                  neighborhood_overview
# 148                                                NaN
# 149  It is a short walk to the local Sainsbury's su...
# 150  Neatly tucked away between the wealth of Maryl...
# 151                                                NaN
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155  Crystal Palace is a vibrant suburb, many resta...
# 156                                                NaN
# 157  I cycle everywhere - it's flat and takes 8 min...

# %%
listing_clean['host_has_about'] = np.where(listing_clean['host_about'].isna(), False, True)
listing_clean['host_has_neighborhood_overview'] = np.where(listing_clean['neighborhood_overview'].isna(), False, True)

# %% [markdown]
# #### Test

# %%
# compare column content with above
listing_clean[['host_has_about', 'host_has_neighborhood_overview']][120:130]
# Out:
#      host_has_about  host_has_neighborhood_overview
# 148            True                           False
# 149            True                            True
# 150            True                            True
# 151            True                           False
# 152            True                           False
# 153            True                           False
# 154            True                           False
# 155            True                            True
# 156            True                           False
# 157            True                            True

# %%
listing_clean[['host_has_about', 'host_has_neighborhood_overview']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 69578 entries, 1 to 81790
# Data columns (total 2 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   host_has_about                  69578 non-null  bool
#  1   host_has_neighborhood_overview  69578 non-null  bool
# dtypes: bool(2)
# memory usage: 679.5 KB

# %%
# make sure not more missing values are present
assert sum(listing_clean['host_has_about'].isna()) == 0
assert sum(listing_clean['host_has_neighborhood_overview'].isna()) == 0

# %% [markdown]
# <a id='validity'></a>
# <span style="color:blue; font-size:20px; font-family: Calibri;">Validity Issues</span>
#
# [click here to go back to summary of assessment](#sum_assessment)

# %% [markdown]
# <span style="color:blue; font-size:16px; font-family: Calibri;">Issue #8: **host_since** is a date with type string</span>

# %% [markdown]
# **Define**: Convert host_since to a date field using pandas method `to_datetime()`, keeping only the year. Create a new feature called 'host_years_active' to record how long the listing is on the market and store as integer field

# %% [markdown]
# #### Code

# %%
# get current year
today = int(datetime.today().strftime('%Y'))

# %%
listing_clean['host_since'] = pd.to_datetime(listing_clean['host_since']).dt.year.astype(int)

# %%
listing_clean['host_years_active'] = today - listing_clean['host_since']

# %% [markdown]
# #### Test

# %%
listing_clean[['host_since', 'host_years_active']].head()
# Out:
#    host_since  host_years_active
# 1        2011                 12
# 2        2009                 14
# 3        2009                 14
# 4        2012                 11
# 5        2011                 12

# %% [markdown]
# <span style="color:blue; font-size:16px; font-family: Calibri;">Issue #9: boolean fields have values 'f' and 't' (host_is_superhost, instant_bookable, host_has_profile_pic, host_identity_verified)</span>

# %% [markdown]
# **Define:** Replace value 'f' with False and 't with True using pandas replace()

# %% [markdown]
# #### Code

# %%
cols = ['host_is_superhost', 'instant_bookable', 'host_has_profile_pic', 'host_identity_verified']

# %%
listing_clean[cols] = listing_clean[cols].replace({'t': True, 'f': False, np.nan: False}).astype('bool')

# %% [markdown]
# #### Test

# %%
# check columns are converted to boolean
for col in cols:
    assert listing_clean[col].dtype.name == 'bool'

# %%
# check unique values per column
# print column unique values in a subplot grid
ncols = 4
nrows = len(cols) // ncols

fig, axs = plt.subplots(nrows, ncols, constrained_layout=True, figsize=(8,4))
for col, ax in zip(cols, axs.T.ravel()):
    sns.countplot(data=listing_clean, x=col, ax=ax, color=BASE_COLOR, orient='h')
    
    # rotate the xtick labels
    labels = ax.get_xticklabels()
    ax.set_xticklabels(labels, rotation=90)
    ax.set_title(col)
    ax.set_xlabel('')

plt.suptitle('UNIQUE VALUES FOR BOOLEAN FEATURES')
plt.show()
# Out:
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/82196324.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/82196324.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/82196324.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)
# /var/folders/4p/r9m3gynn3wj6h4yh4_lwz5fw0000gn/T/ipykernel_34993/82196324.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=90)

# %% [markdown]
# <span style="color:blue; font-size:16px; font-family: Calibri;">Issue #10: **host_response_rate**, **host_acceptance_rate** and **price** are numeric fields as type string with prefix '%' or '$' present</span>

# %% [markdown]
# **Define**: Remove '%' or '¢' from string and convert to integer using python method astype() and regex replace() methods

# %% [markdown]
# #### Code

# %%
cols = ['host_response_rate', 'host_acceptance_rate', 'price']

# %%
# snapshot before we start
listing_clean[cols][:10]
# Out:
#    host_response_rate host_acceptance_rate    price
# 1                 90%                  68%   $69.00
# 2                100%                  78%   $79.00
# 3                100%                  47%  $100.00
# 4                100%                 100%  $156.00
# 5                100%                  68%   $65.00
# 6                 NaN                  NaN   $41.00
# 7                 NaN                  NaN  $132.00
# 8                100%                  98%  $550.00
# 9                100%                 100%   $60.00
# 10               100%                  50%  $250.00

# %%
# first fill missing values with a 0 response rate
listing_clean[cols] = listing_clean[cols].fillna('0')

# %%
# remove % and convert to integer type
for col in cols:
    listing_clean[col] = listing_clean[col].str.replace('[%$,]','', regex=True).astype('float32')
    listing_clean[col] = listing_clean[col].astype('int32')

# %% [markdown]
# #### Test

# %%
# no more missing values are present
assert listing_clean[cols].isna().any().any() == False

# %%
# columns are now numeric
for col in cols:
    assert listing_clean[col].dtype == 'int32'

# %%
# visual check to compare shapshots before and after
listing_clean[cols][:10]
# Out:
#     host_response_rate  host_acceptance_rate  price
# 1                   90                    68     69
# 2                  100                    78     79
# 3                  100                    47    100
# 4                  100                   100    156
# 5                  100                    68     65
# 6                    0                     0     41
# 7                    0                     0    132
# 8                  100                    98    550
# 9                  100                   100     60
# 10                 100                    50    250

# %% [markdown]
# <span style="color:blue; font-size:16px; font-family: Calibri;">Issue #11: dataset **calendar**: **date** field is a string</span>

# %% [markdown]
# **Define:** Convert `date` to type datetime using `to_datetime` method

# %% [markdown]
# #### Code

# %%
calendar['date'] = pd.to_datetime(calendar['date'])

# %% [markdown]
# #### Test

# %%
assert calendar.date.dtype == 'datetime64[ns]'

# %% [markdown]
# <span style="color:blue; font-size:16px; font-family: Calibri;">Issue #12: dataset **calendar**: **price** is a numeric field presented as type string with prefix '$'</span>

# %% [markdown]
# **Define**: Remove '$' from string and convert to integer using python methods astype() and regex replace()

# %% [markdown]
# #### Code

# %%
# snapshot before we start
calendar_clean.head()
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0       13913  2023-06-09         f  $79.00         $79.00             1.0
# 1       13913  2023-06-10         f  $79.00         $79.00             1.0
# 2       13913  2023-06-11         f  $79.00         $79.00             1.0
# 3       13913  2023-06-12         t  $79.00         $79.00             1.0
# 4       13913  2023-06-13         t  $79.00         $79.00             1.0
#
#    maximum_nights
# 0            29.0
# 1            29.0
# 2            29.0
# 3            29.0
# 4            29.0

# %%
# remove prefix '$'' and convert to integer type
calendar_clean['price']= calendar_clean['price'].str.replace('[$,]','', regex=True).astype('float32')

# %% [markdown]
# #### Test

# %%
assert calendar_clean['price'].dtype == 'float32'

# %% [markdown]
# <span style="color:blue; font-size:16px; font-family: Calibri;">Issue #13: convert float columns to integer (host_total_listings_count, minimum_minimum_nights, maximum_minimum_nights, number_of_reviews, number_of_reviews_ltm, number_of_reviews_l30d)</span>

# %% [markdown]
# **Define**: convert float to integer datatype using pandas method astype(), by first setting np.nan values to 0 using fillna() method

# %% [markdown]
# #### Code

# %%
cols = ['host_total_listings_count', 'minimum_minimum_nights', 'minimum_maximum_nights', 'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d']
listing_clean[cols] = round(listing_clean[cols],0).fillna(0).astype(int)

# %% [markdown]
# #### Test

# %%
for col in cols:
    assert listing_clean[col].dtype == 'int64'

# %% [markdown]
# <a id='consistency'></a>
# <span style="color:blue; font-size:20px; font-family: Calibri;">Consistency Issues</span>
#
# [click here to go back to summary of assessment](#sum_assessment)

# %% [markdown]
# <span style="color:blue; font-size:16px; font-family: Calibri;">Issue #14: **id** column in **listing** should be called **listing_id** to be consistent with **calendar** dataset</span>

# %% [markdown]
# **Define**: rename column `id` to `listing_id` using pandas method `rename()`

# %% [markdown]
# #### Code:

# %%
listing_clean.rename(columns={'id':'listing_id'}, inplace=True)

# %% [markdown]
# #### Test:

# %%
assert listing_clean.columns.str.contains('listing_id').any() == True

# %% [markdown]
# <a id='accuracy'></a>
# <span style="color:blue; font-size:20px; font-family: Calibri;">Accuracy Issues</span>
#
# [click here to go back to summary of assessment](#sum_assessment)

# %% [markdown]
# <span style="color:blue; font-size:16px; font-family: Calibri;">Issue #15: There are listings in the **calendar** dataset where prices increase significantly from one day to the next, e.g. £100 one day, £24,000 the next</span>

# %% [markdown]
# #### Define: find extreme jump in prices and replace these prices with np.nan. Fill missing prices using pandas first ffill() then bfill() methods

# %% [markdown]
# #### Code:

# %%
calendar_clean2 = calendar_clean.copy()

# %%
# sort now so we can keep index stable
calendar_clean.sort_values(by=['listing_id', 'date'], inplace=True)

# %%
# Example 1 - follow the listing with most extreme price over $80k - snapshot before we start
calendar_clean[calendar_clean['listing_id'] == 38452677]
# Out:
#           listing_id        date available    price adjusted_price  \
# 13320335    38452677  2023-06-08         f    100.0        $100.00
# 13320336    38452677  2023-06-09         f    100.0        $100.00
# 13320337    38452677  2023-06-10         f    100.0        $100.00
# 13320338    38452677  2023-06-11         f    100.0        $100.00
# 13320339    38452677  2023-06-12         f    100.0        $100.00
# 13320340    38452677  2023-06-13         f    100.0        $100.00
# 13320341    38452677  2023-06-14         f    100.0        $100.00
# 13320342    38452677  2023-06-15         f    100.0        $100.00
# 13320343    38452677  2023-06-16         f    100.0        $100.00
# 13320344    38452677  2023-06-17         f    100.0        $100.00
# 13320345    38452677  2023-06-18         f    100.0        $100.00
# 13320346    38452677  2023-06-19         f    100.0        $100.00
# 13320347    38452677  2023-06-20         f    100.0        $100.00
# 13320348    38452677  2023-06-21         f    100.0        $100.00
# 13320349    38452677  2023-06-22         f    100.0        $100.00
# 13320350    38452677  2023-06-23         f    100.0        $100.00
# 13320351    38452677  2023-06-24         f    100.0        $100.00
# 13320352    38452677  2023-06-25         f    100.0        $100.00
# 13320353    38452677  2023-06-26         f    100.0        $100.00
# 13320354    38452677  2023-06-27         f    100.0        $100.00
# 13320355    38452677  2023-06-28         f    100.0        $100.00
# 13320356    38452677  2023-06-29         f    100.0        $100.00
# 13320357    38452677  2023-06-30         f    100.0        $100.00
# 13320358    38452677  2023-07-01         f    100.0        $100.00
# 13320359    38452677  2023-07-02         f    100.0        $100.00
# 13320360    38452677  2023-07-03         f    100.0        $100.00
# 13320361    38452677  2023-07-04         f    100.0        $100.00
# 13320362    38452677  2023-07-05         f    100.0        $100.00
# 13320363    38452677  2023-07-06         f    100.0        $100.00
# 13320364    38452677  2023-07-07         f    100.0        $100.00
# 13574952             2.0             7.0
# 13574953             1.0             7.0
# 13574954             1.0             7.0
# 13574955             1.0             7.0
# 13574956             1.0             7.0
# 13574957             1.0             7.0
# 13574958             1.0             7.0
# 13574959             3.0             7.0
# 13574960             2.0             7.0
# 13574961             1.0             7.0
# 13574962             1.0             7.0
# 13574963             1.0             7.0
# 13574964             1.0             7.0
# 13574965             1.0             7.0
# 13574966             2.0             7.0
# 13574967             1.0             7.0
# 13574968             1.0             7.0
# 13574969             1.0             7.0
# 13574970             1.0             7.0
# 13574971             1.0             7.0
# 13574972             1.0             7.0
# 13574973             3.0             7.0
# 13574974             2.0             7.0
# 13574975             1.0             7.0
# 13574976             1.0             7.0
# 13574977             1.0             7.0
# 13574978             1.0             7.0
# 13574979             1.0             7.0
# 13574980             2.0             7.0
# 13574981             1.0             7.0
# 13574982             1.0             7.0
# 13574983             1.0             7.0
# 13574984             1.0             7.0
# 13574985             1.0             7.0
# 13574986             1.0             7.0
# 13574987             2.0             7.0
# 13574988             1.0             7.0
# 13574989             1.0             7.0
# 13574990             1.0             7.0
# 13574991             1.0             7.0
# 13574992             1.0             7.0
# 13574993             1.0             7.0
# 13574994             3.0             7.0
# 13574995             2.0             7.0
# 13574996             1.0             7.0
# 13574997             1.0             7.0
# 13574998             1.0             7.0
# 13574999             1.0             7.0
# 13575000             1.0             7.0
# 13575001             2.0             7.0
# 13575002             1.0             7.0
# 13575003             1.0             7.0
# 13575004             1.0             7.0
# 13575005             1.0             7.0
# 13575006             1.0             7.0
# 13575007             1.0             7.0

# %%
# calculate the mean and standard deviation for each listing
calendar_stats = calendar_clean.groupby(['listing_id']).agg(mean=('price', 'mean'), 
                                                            std=('price', 'std'), 
                                                            min=('price', 'min'),
                                                            max=('price', 'max')).reset_index()
calendar_clean = calendar_clean.merge(calendar_stats, how='inner', on='listing_id')

# %%
# get listing id's with errors 
df_only_errors = calendar_clean[((calendar_clean['std'] >= calendar_clean['mean']) & 
                                 (calendar_clean['price'] > 100) &
                                 (calendar_clean['price'] > calendar_clean['min']*10)) | 
                                 ((calendar_clean['price'] > 100) &
                                 (calendar_clean['price'] > calendar_clean['min']*15))]
df_only_errors.head()
# Out:
#        listing_id        date available   price adjusted_price  \
# 16227       79129  2023-11-23         f 3,841.0      $3,841.00
# 16228       79129  2023-11-24         f 3,841.0      $3,841.00
# 16229       79129  2023-11-25         f 3,841.0      $3,841.00
# 16230       79129  2023-11-26         f 3,841.0      $3,841.00
# 16231       79129  2023-11-27         f 3,841.0      $3,841.00
#
#        minimum_nights  maximum_nights  mean   std  min     max
# 16227             1.0           120.0 132.7 555.9 35.0 3,841.0
# 16228             1.0           120.0 132.7 555.9 35.0 3,841.0
# 16229             1.0           120.0 132.7 555.9 35.0 3,841.0
# 16230             1.0           120.0 132.7 555.9 35.0 3,841.0
# 16231             1.0           120.0 132.7 555.9 35.0 3,841.0

# %%
calendar_clean[calendar_clean.listing_id == 42419808]
# Out:
#           listing_id        date available   price adjusted_price  \
# 14676679    42419808  2023-06-09         f    79.0         $79.00
# 24564621                100.0    1,500.0
# 704760860683904782       76.0    1,570.0
# 681007106364518960       35.0    1,570.0
# 644111825864153815      350.0    7,000.0
# 39798195                174.0   10,000.0
# 681012650236628942       43.0    1,570.0
# 823089097152362720       19.0    1,300.0
# 37039101                127.0    2,440.0
# 52195962                120.0    2,440.0
# 546975263383722688       90.0    9,095.0
# 49188381                142.0    2,370.0
# 48579410                 76.0    1,570.0
# 24672257                127.0    2,440.0
# 39798190                269.0   10,000.0
# 49299081                199.0   30,989.0
# 54377833                137.0    2,260.0
# 28838351                125.0    1,750.0
# 42662303                 34.0    1,000.0

# %%
# fill excessive prices with null
calendar_clean.loc[df_only_errors.index, 'price'] = np.nan

# %%
# # fill missing prices using ffill, then bfill
calendar_clean['key'] = calendar_clean['listing_id']
calendar_clean = calendar_clean.groupby('key').ffill().bfill()

# %%
#### Test:

# %%
# follow the listing with most extreme price over $80k
calendar_clean[calendar_clean.listing_id == 38452677]
# Out:
#           listing_id        date available  price adjusted_price  \
# 13346249    38452677  2023-06-08         f  100.0        $100.00
# 13346250    38452677  2023-06-09         f  100.0        $100.00
# 13346251    38452677  2023-06-10         f  100.0        $100.00
# 13346252    38452677  2023-06-11         f  100.0        $100.00
# 13346253    38452677  2023-06-12         f  100.0        $100.00
# 13346254    38452677  2023-06-13         f  100.0        $100.00
# 13346255    38452677  2023-06-14         f  100.0        $100.00
# 13346256    38452677  2023-06-15         f  100.0        $100.00
# 13346257    38452677  2023-06-16         f  100.0        $100.00
# 13346258    38452677  2023-06-17         f  100.0        $100.00
# 13346259    38452677  2023-06-18         f  100.0        $100.00
# 13346260    38452677  2023-06-19         f  100.0        $100.00
# 13346261    38452677  2023-06-20         f  100.0        $100.00
# 13346262    38452677  2023-06-21         f  100.0        $100.00
# 13346263    38452677  2023-06-22         f  100.0        $100.00
# 13346264    38452677  2023-06-23         f  100.0        $100.00
# 13346265    38452677  2023-06-24         f  100.0        $100.00
# 13346266    38452677  2023-06-25         f  100.0        $100.00
# 13346267    38452677  2023-06-26         f  100.0        $100.00
# 13346268    38452677  2023-06-27         f  100.0        $100.00
# 13346269    38452677  2023-06-28         f  100.0        $100.00
# 13346270    38452677  2023-06-29         f  100.0        $100.00
# 13346271    38452677  2023-06-30         f  100.0        $100.00
# 13346272    38452677  2023-07-01         f  100.0        $100.00
# 13346273    38452677  2023-07-02         f  100.0        $100.00
# 13346274    38452677  2023-07-03         f  100.0        $100.00
# 13346275    38452677  2023-07-04         f  100.0        $100.00
# 13346276    38452677  2023-07-05         f  100.0        $100.00
# 13346277    38452677  2023-07-06         f  100.0        $100.00
# 13346278    38452677  2023-07-07         f  100.0        $100.00
# 13346279    38452677  2023-07-08         f  100.0        $100.00
# 13346280    38452677  2023-07-09         f  100.0        $100.00
# 13346281    38452677  2023-07-10         f  100.0        $100.00
# 13346282    38452677  2023-07-11         f  100.0        $100.00
# 13346283    38452677  2023-07-12         f  100.0        $100.00
# 13346284    38452677  2023-07-13         f  100.0        $100.00
# 13346285    38452677  2023-07-14         f  100.0        $100.00
1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676807             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676808             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676809             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676810             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676811             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676812             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676813             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676814             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676815             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676816             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676817             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676818             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676819             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676820             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676821             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676822             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676823             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676824             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676825             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676826             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676827             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676828             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676829             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676830             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676831             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676832             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676833             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676834             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676835             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676836             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676837             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676838             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676839             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676840             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676841             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676842             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676843             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676844             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676845             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676846             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676847             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676848             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676849             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676850             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676851             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676852             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676853             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676854             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676855             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676856             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676857             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676858             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676859             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676860             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676861             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676862             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676863             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676864             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676865             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676866             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676867             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676868             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676869             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676870             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676871             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676872             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676873             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676874             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676875             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676876             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676877             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676878             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676879             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676880             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676881             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676882             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676883             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676884             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676885             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676886             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676887             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676888             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676889             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676890             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676891             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676892             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676893             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676894             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676895             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676896             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676897             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676898             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676899             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676900             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676901             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676902             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676903             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676904             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676905             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676906             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676907             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676908             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676909             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676910             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676911             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676912             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676913             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676914             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676915             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676916             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676917             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676918             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676919             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676920             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676921             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676922             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676923             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676924             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676925             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676926             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676927             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676928             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676929             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676930             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676931             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676932             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676933             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676934             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676935             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676936             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676937             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676938             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676939             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676940             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676941             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676942             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676943             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676944             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676945             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676946             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676947             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676948             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676949             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676950             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676951             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676952             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676953             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676954             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676955             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676956             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676957             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676958             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676959             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676960             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676961             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676962             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676963             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676964             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676965             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676966             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676967             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676968             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676969             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676970             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676971             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676972             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676973             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676974             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676975             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676976             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676977             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676978             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676979             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676980             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676981             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676982             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676983             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676984             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676985             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676986             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676987             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676988             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676989             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676990             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676991             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676992             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676993             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676994             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676995             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676996             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676997             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676998             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14676999             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677000             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677001             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677002             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677003             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677004             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677005             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677006             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677007             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677008             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677009             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677010             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677011             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677012             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677013             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677014             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677015             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677016             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677017             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677018             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677019             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677020             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677021             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677022             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677023             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677024             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677025             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677026             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677027             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677028             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677029             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677030             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677031             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677032             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677033             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677034             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677035             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677036             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677037             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677038             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677039             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677040             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677041             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677042             1.0           365.0 704.9 438.8 37.0 1,000.0
# 14677043             1.0           365.0 704.9 438.8 37.0 1,000.0

# %%
# make sure there are no missing price values
assert calendar_clean.price.isna().any() == False

# %% [markdown]
# <span style="color:blue; font-size:16px; font-family: Calibri;">Issue #16: daily price in listings is not always the average mean price from the calendar dataset</span>

# %% [markdown]
# **Define:** Recalculate listing base price to be mean calendar price and save as new column `price_mean`

# %% [markdown]
# #### Code:

# %%
calendar_mean = calendar_clean.groupby('listing_id', as_index=False).agg(price_mean=('price','mean')).round(0).astype(int)
calendar_mean.head()
# Out:
#    listing_id  price_mean
# 0       13913          79
# 1       15400         107
# 2       17402         527
# 3       24328         250
# 4       25123          29

# %%
# add mean price to lising dataset
listing_clean = listing_clean.merge(calendar_mean, on='listing_id', how='inner')

# %% [markdown]
# #### Test:

# %%
# compare orginal base price to new mean base price
listing_clean[['listing_id', 'price', 'price_mean']].sample(10)
# Out:
#                listing_id  price  price_mean
# 6680             11122508    150         150
# 20547            30499158     32          32
# 37696            54156715    495         840
# 61238  855533965923740022     45          42
# 66926  893190935134398509     80          80
# 4095              7048016     53          50
# 13128            20004091    158         158
# 68349  901856875324592663    154         189
# 23441            35367083     75          75
# 55508  805717776686280470    850         968

# %%
# compare original price to new mean price after cleaning for listings with the biggest inconsistencies
listing_clean[listing_clean.listing_id.isin(calendar_grouped[:5]['listing_id'])][['listing_id', 'price', 'price_mean']]
# Out:
#                listing_id  price  price_mean
# 21158            31622680   7580          78
# 25592            38452677    100          92
# 30125            44696103   8583         115
# 35030            51839279  24000         256
# 43547  658361293784718707  27579         139

# %% [markdown]
# <span style="color:blue; font-size:16px; font-family: Calibri;"> Issue #17: `minimum_maximum_nights` have some crazy maximum values > 90 mil !</span>

# %% [markdown]
# **Define:** Override values in feature minimum_maximum_nights >= 90000 with 1125 (value from percentile 0.999)

# %% [markdown]
# **Code**:

# %%
# get rows that needs to be changed
df_max_nights_error = listing_clean[listing_clean['minimum_maximum_nights'] >= 9000000]
df_max_nights_error.shape
# Out:
# (9, 78)

# %%
# fill excessive prices with 1125
listing_clean.loc[df_max_nights_error.index, 'minimum_maximum_nights'] = 1125

# %% [markdown]
# **Test**:

# %%
assert len(listing_clean[listing_clean['minimum_maximum_nights'] >= 9000000]) == 0

# %% [markdown]
# <a id='tidiness'></a>
# <span style="color:blue; font-size:20px; font-family: Calibri;">Tidiness Issues</span>
#
# [click here to go back to summary of assessment](#sum_assessment)

# %% [markdown]
# <span style="color:blue; font-size:16px; font-family: Calibri;"> Issue #18: **bathroom_text** contains more than one meaning: number of baths and shared vs private</span>

# %% [markdown]
# **Define:** Create new boolean feature called 'private_bathroom' with rules:
#
# - when room_type = 'Entire home/apt' set to True
# - when word 'shared' is found within bathroom_text, set to False
# - when number of bathrooms = 0, set to False
# - when number of bathrooms is missing, set to False
# - otherwise True

# %% [markdown]
# **Code**:

# %%
# extract the word private or shared from bathroom_text
listing_clean['private_bathroom'] = listing_clean['bathrooms_text'].str.extract('([Ss]hared|[Pp]rivate)', expand=True)

# %%
# create boolean feature to indicate if listing have a private bathroom or not
listing_clean['private_bathroom'] = np.where((listing_clean['room_type'] == 'Entire home/apt'), True, 
                                    np.where((listing_clean['bathrooms'] == 0), False,     
                                    np.where((listing_clean['bathrooms'].isna()), False,  
                                    np.where((listing_clean['private_bathroom'] == 'shared'), False, True))))

# %% [markdown]
# **Test**:

# %%
# visual inspection destination
listing_clean['private_bathroom'][:10]
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# 9     True
# Name: private_bathroom, dtype: bool

# %%
# visual inspection source
listing_clean['bathrooms_text'][:10]
# Out:
# 0        1.5 baths
# 1    1 shared bath
# 2           1 bath
# 3           1 bath
# 4    1 shared bath
# 5          0 baths
# 6           1 bath
# 7          2 baths
# 8           1 bath
# 9        1.5 baths
# Name: bathrooms_text, dtype: object

# %%
# make sure no records exist where bathrooms_text contain the string 'shared' and new feature 'private_bathroom'
assert len(listing_clean[(listing_clean['bathrooms_text'].str.contains('shared', regex=False)) & 
                  (listing_clean['private_bathroom'] == True)]) == 0

# %%
listing_clean['private_bathroom'].value_counts()
# Out:
# private_bathroom
# True     54988
# False    14589
# Name: count, dtype: int64

# %%
# make sure private bathrooms have no null values
assert listing_clean['private_bathroom'].isna().sum() == 0

# %%
# how many records have 0 bathrooms ?
len(listing_clean[listing_clean['bathrooms'] == 0])
# Out:
# 173

# %% [markdown]
# <span style="color:blue; font-size:16px; font-family: Calibri;"> Issue #19: Drop unneeded variables</span>

# %% [markdown]
# **Define**: Drop fields not needed for this project by using pandas method drop()

# %% [markdown]
# #### Code

# %%
cols_to_drop = ['scrape_id', 'last_scraped', 'source', 'description', 'host_url',
                'picture_url', 'host_since', 'host_location', 'host_thumbnail_url', 'host_picture_url', 
                'neighbourhood', 'bathrooms_text', 'host_verifications',
                'neighborhood_overview', 'host_about',
                'minimum_nights', 'maximum_minimum_nights', 'minimum_nights_avg_ntm',
                'maximum_nights', 'maximum_maximum_nights', 'maximum_nights_avg_ntm',                
                'has_availability', 'host_listings_count', 'host_total_listings_count',
#                 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 
#                 'review_scores_communication', 'review_scores_location', 'review_scores_value',
                'amenities', 'calendar_last_scraped', 'extracted_bedrooms_name', 'studio_name']

# %%
listing_clean.drop(cols_to_drop, inplace=True, axis=1, errors='ignore')

# %% [markdown]
# #### Test

# %%
# check that all specified columns were removed
assert listing_clean.columns.isin(cols_to_drop).any() == False

# %% [markdown]
# <a id='save'></a>
# <span style="color:blue; font-size:25px; line-height:30px; font-family: Calibri;">Step 4: Save cleaned data</span>

# %%
listing_clean.shape
# Out:
# (69577, 51)

# %%
listing_clean.head()
# Out:
#    listing_id                          listing_url  \
# 0      157714  https://www.airbnb.com/rooms/157714
# 1       13913   https://www.airbnb.com/rooms/13913
# 2       15400   https://www.airbnb.com/rooms/15400
# 3      306333  https://www.airbnb.com/rooms/306333
# 4      159736  https://www.airbnb.com/rooms/159736
#
#                                                 name  host_id host_name  \
# 0  Townhouse in Hammersmith · ★4.71 · 1 bedroom ·...   757377    Eilinn
# 1  Rental unit in Islington · ★4.80 · 1 bedroom ·...    54730     Alina
# 2  Rental unit in London · ★4.80 · 1 bedroom · 1 ...    60302  Philippa
# 3  Rental unit in London · ★4.32 · 2 bedrooms · 3...  1573870    Robert
# 4  Rental unit in Lambeth · ★4.72 · 1 bedroom · 1...   766056    Trevor
#
#    host_response_time  host_response_rate  host_acceptance_rate  \
# 0  within a few hours                  90                    68
# 1      within an hour                 100                    78
# 2        within a day                 100                    47
# 3        within a day                 100                   100
# 4      within an hour                 100                    68
#
#    host_is_superhost host_neighbourhood  host_has_profile_pic  \
# 0              False        Hammersmith                  True
# 1              False    LB of Islington                  True
# 2              False            Chelsea                  True
# 3              False         Shoreditch                  True
# 4              False          Stockwell                  True
#
#    host_identity_verified  neighbourhood_cleansed  latitude  longitude  \
# 0                    True  Hammersmith and Fulham      51.5       -0.2
# 1                    True               Islington      51.6       -0.1
# 2                    True  Kensington and Chelsea      51.5       -0.2
# 3                    True                 Hackney      51.5       -0.1
# 4                    True                 Lambeth      51.5       -0.1
#
#                  property_type        room_type  accommodates  bathrooms  \
# 0    Private room in townhouse     Private room             3        1.5
# 1  Private room in rental unit     Private room             1        1.0
# 2           Entire rental unit  Entire home/apt             2        1.0
# 3           Entire rental unit  Entire home/apt             5        1.0
# 4  Private room in rental unit     Private room             2        1.0
#
#    bedrooms  beds  price  minimum_minimum_nights  minimum_maximum_nights  \
# 0       1.0   1.0     69                       4                      21
# 1       1.0   1.0     79                       1                      29
# 2       1.0   1.0    100                       7                      30
# 3       2.0   3.0    156                       2                      60
# 4       1.0   1.0     65                       4                    1125
#
#    availability_30  availability_60  availability_90  availability_365  \
# 0               10               37               67                67
# 1               23               48               78               353
# 2                0                2                2                70
# 3                4                4                4                 4
# 4                1                1                2               160
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                175                     10                       0
# 1                 41                     15                       0
# 2                 94                      5                       0
# 3                 20                      0                       0
# 4                 96                      4                       0
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2011-07-13  2023-05-02                   4.7                     4.7
# 1   2010-08-18  2022-12-11                   4.8                     4.7
# 2   2009-12-21  2023-05-01                   4.8                     4.8
# 3   2016-12-18  2017-05-31                   4.3                     4.7
# 4   2011-07-16  2023-04-29                   4.7                     4.8
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        4.8                    4.8
# 1                        4.7                    4.7
# 2                        4.9                    4.9
# 3                        4.0                    4.3
# 4                        4.7                    4.8
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          4.8                     4.8                  4.7
# 1                          4.8                     4.7                  4.7
# 2                          4.8                     4.9                  4.7
# 3                          4.8                     4.9                  4.5
# 4                          4.9                     4.3                  4.7
#
#    instant_bookable  calculated_host_listings_count  \
# 0             False                               1
# 1             False                               2
# 2             False                               1
# 3             False                               1
# 4             False                               4
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             1
# 2                                             0
# 3                                             0
# 4                                             4
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 0                                            0                1.2
# 1                                            0                0.3
# 2                                            0                0.6
# 3                                            0                0.2
# 4                                            0                0.7
#
#    host_has_about  host_has_neighborhood_overview  host_years_active  \
# 0            True                            True                 12
# 1            True                            True                 14
# 2            True                            True                 14
# 3            True                            True                 11
# 4            True                            True                 12
#
#    price_mean  private_bathroom
# 0          70              True
# 1          79             False
# 2         107              True
# 3         198              True
# 4          62             False

# %%
# final look at data types and missing values
listing_clean.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69577 entries, 0 to 69576
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   listing_id                                    69577 non-null  int64
#  1   listing_url                                   69577 non-null  object
#  2   name                                          69577 non-null  object
#  3   host_id                                       69577 non-null  int64
#  4   host_name                                     69577 non-null  object
#  5   host_response_time                            52186 non-null  object
#  6   host_response_rate                            69577 non-null  int32
#  7   host_acceptance_rate                          69577 non-null  int32
#  8   host_is_superhost                             69577 non-null  bool
#  9   host_neighbourhood                            37903 non-null  object
#  10  host_has_profile_pic                          69577 non-null  bool
#  11  host_identity_verified                        69577 non-null  bool
#  12  neighbourhood_cleansed                        69577 non-null  object
#  13  latitude                                      69577 non-null  float64
#  14  longitude                                     69577 non-null  float64
#  15  property_type                                 69577 non-null  object
#  16  room_type                                     69577 non-null  object
#  17  accommodates                                  69577 non-null  int64
#  18  bathrooms                                     69487 non-null  float64
#  19  bedrooms                                      69521 non-null  float64
#  20  beds                                          68533 non-null  float64
#  21  price                                         69577 non-null  int32
#  22  minimum_minimum_nights                        69577 non-null  int64
#  23  minimum_maximum_nights                        69577 non-null  int64
#  24  availability_30                               69577 non-null  int64
#  25  availability_60                               69577 non-null  int64
#  26  availability_90                               69577 non-null  int64
#  27  availability_365                              69577 non-null  int64
#  28  number_of_reviews                             69577 non-null  int64
#  29  number_of_reviews_ltm                         69577 non-null  int64
#  30  number_of_reviews_l30d                        69577 non-null  int64
#  31  first_review                                  48986 non-null  object
#  32  last_review                                   48986 non-null  object
#  33  review_scores_rating                          48986 non-null  float64
#  34  review_scores_accuracy                        48058 non-null  float64
#  35  review_scores_cleanliness                     48067 non-null  float64
#  36  review_scores_checkin                         48055 non-null  float64
#  37  review_scores_communication                   48060 non-null  float64
#  38  review_scores_location                        48054 non-null  float64
#  39  review_scores_value                           48053 non-null  float64
#  40  instant_bookable                              69577 non-null  bool
#  41  calculated_host_listings_count                69577 non-null  int64
#  42  calculated_host_listings_count_entire_homes   69577 non-null  int64
#  43  calculated_host_listings_count_private_rooms  69577 non-null  int64
#  44  calculated_host_listings_count_shared_rooms   69577 non-null  int64
#  45  reviews_per_month                             48986 non-null  float64
#  46  host_has_about                                69577 non-null  bool
#  47  host_has_neighborhood_overview                69577 non-null  bool
#  48  host_years_active                             69577 non-null  int64
#  49  price_mean                                    69577 non-null  int64
#  50  private_bathroom                              69577 non-null  bool
# dtypes: bool(7), float64(13), int32(3), int64(18), object(10)
# memory usage: 23.0+ MB

# %%
# save the consolidated cleaned file as pickle file to preserve the datatype corrections
create_folder(FILE_PATH_CLEAN)
listing_clean.to_pickle(FILE_NAME_CLEAN)

# %% [markdown]
# <a id='summary'></a>
# <span style="color:blue; font-size:30px; line-height:40px; font-family: Calibri;">Summary</span>

# %% [markdown]
# For a summary of cleaning activities performed, click [here](#summary_of_assessment).
#
# Overall, data needed a lot of correction. A special shout out to issues 6 and 15.
#
# 6) There are around 12,000 listings in the dataset that seems inactive (not rented out anymore), causing a lot of missing values in rows. It happens where hosts were active in the past, had lots of reviews and then suddenly it stops. No reviews, no availability. Spot checking on Airbnb direclty, it's not possible to book these listings.
#
# 15) Airbnb hosts can switch on smart pricing, you can read more about it [here](https://www.airbnb.co.uk/help/article/1168)
#
# It means prices are automatically increased, if demand increases due to world cups, concerts, etc.
# However, there listings in the calendar dataset where prices increase significantly from one day to the next, e.g. £100 one day, £24,000 the next, inflating the mean average price to abnormal levels.
#
# No model can predict such prices, therefore such entries were detected, adjusted and mean average price recalculated.

# %% [markdown]
# <a id='references'></a>
# <span style="color:blue; font-size:30px; line-height:40px; font-family: Calibri;">References</span>

# %% [markdown]
# - [how to plot side by side](https://stackoverflow.com/questions/71521800/how-to-iterate-subplots-by-columns-instead-of-rows-in-matplotlib)
# - [mixing missingno bug](https://stackoverflow.com/questions/75525029/msno-matrix-shows-an-error-when-i-use-any-venv-using-pyenv)
# - [extract number before a list of words](https://stackoverflow.com/questions/73298502/use-regex-to-extract-number-before-a-list-of-words-in-pandas-dataframe)

# %% [markdown]
# <a id='submission'></a>
# <span style="color:blue; font-size:30px; line-height:40px; font-family: Calibri;">Submission</span>

# %%
# convert notebook to html
os.system('jupyter nbconvert --to html 1_data_wrangling.ipynb')
# Out:
# [NbConvertApp] WARNING | Config option `kernel_spec_manager_class` not recognized by `NbConvertApp`.
# [NbConvertApp] Converting notebook 1_data_wrangling.ipynb to html
# [NbConvertApp] Writing 2189053 bytes to 1_data_wrangling.html
# 0
